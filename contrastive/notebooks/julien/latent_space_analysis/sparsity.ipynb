# %%
import pandas as pd
import umap
import numpy as np
import matplotlib.pyplot as plt

# %%
#model_path = "/volatile/jl277509/Runs/02_STS_babies/Program/Output/BT_ORBITAL/BT_L256_0"
#model_path="/volatile/jl277509/Runs/02_STS_babies/Program/Output/CINGULATE_ANTOINE/10-50-27_36"
#troiani_emb_file = "/volatile/jl277509/Runs/02_STS_babies/Program/Output/CINGULATE_ANTOINE/10-50-27_36/ACC_custom_embeddings/custom_cross_val_embeddings.csv"
#troiani_emb_file = "/volatile/jl277509/Runs/02_STS_babies/Program/Output/BT_CINGULATE_L10/16-27-48_23/ACC_custom_embeddings/custom_cross_val_embeddings.csv"
troiani_emb_file = "/volatile/jl277509/Runs/02_STS_babies/Program/Output/CINGULATE_ANTOINE/10-50-27_36/UKB_random_embeddings/full_embeddings.csv"
troiani_emb = pd.read_csv(troiani_emb_file, index_col=0)

# %%
norm = troiani_emb.apply(np.linalg.norm, axis=1)
troiani_emb = troiani_emb.div(norm, axis=0)

# %%
p = plt.hist(troiani_emb.values.ravel(), bins=np.arange(-0.1,0.4,0.01), density=True)

# %%
model_path = "/neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Output/2024-05-07/17-26-21_154"
ukb_emb_file = f"{model_path}/ukb_embeddings/full_embeddings.csv"
schiz_emb_file = f"{model_path}/schiz_embeddings/full_embeddings.csv"
schiz_label_file = "/neurospin/dico/data/deep_folding/current/datasets/schiz/used_schiz_subjects_with-sub.csv"

# %%
ukb_emb = pd.read_csv(ukb_emb_file, index_col=0)
ukb_emb
# Out:
#                    dim1        dim2        dim3        dim4        dim5  \
# ID
# sub-1000021   -2.868891   -0.368058   -1.639071   -2.702636   24.760350
# sub-1000458  350.711150  617.962900   -0.825832  596.073800  529.344000
# sub-1000575   -1.104033   -1.135052  197.595890   -1.355339   -1.100050
# sub-1000606  495.236240  418.357300   -3.859657   -3.189036   -0.870604
# sub-1000963   -0.056359   -4.783603   -2.625467   -2.323882   -0.663136
# ...                 ...         ...         ...         ...         ...
# sub-6023469   -3.009088   -5.747623   11.596108   -1.390614   -4.433293
# sub-6023808  472.054800   -0.323073  194.695340   -1.420399  237.451390
# sub-6023847  339.040040   -1.187755   -5.104610   -0.675336   -3.489315
# sub-6024038  239.999970  153.781540  214.609250  138.757200   96.675960
# sub-6024754   -3.802464   -1.826463   33.420250   -2.222388   -4.176336
#
#                     dim6         dim7        dim8        dim9       dim10  \
# ID
# sub-1000021   328.251430    -6.155386   -4.852545   99.105545   -3.770058
# sub-1000458  1022.099100   823.217470   -2.054950  499.170230   -8.092382
# sub-1000575   248.516080   106.344150   -2.823939   -0.934918   -1.918464
# sub-1000606    -1.511794   955.534900   -4.644189  227.792850   -9.538205
# sub-1000963    -1.010007    -5.149221   -5.310495  328.255980  551.753360
# ...                  ...          ...         ...         ...         ...
# sub-6023469    -1.640884    -0.769012  178.704540   -4.444595   -2.204452
# sub-6023808   246.436900    -3.683970   -4.143352   91.998930  892.884400
# sub-6023847    -3.171868  1075.686500   -0.940386   -0.648224  -10.649032
# sub-6024038   376.832820   607.446900   -3.455508    7.513393   -0.002848
# sub-6024754    79.415220   277.891800   -1.541116   -4.346584   -8.701014
#
#              ...      dim247     dim248      dim249      dim250      dim251  \
# ID           ...
# sub-1000021  ...  196.726580  -8.370437  481.835630  393.393340   89.449700
# sub-1000458  ...   -1.643544  -0.960263   -5.636589  469.697940   -0.945099
# sub-1000575  ...   -2.010498  -5.832932   22.096544  756.573000   59.482470
# sub-1000606  ...   -5.546790  -2.642187   -1.296834    6.311005   -1.075276
# sub-1000963  ...   -4.675682  -2.282285   28.887999   -3.652923   -3.460225
# ...          ...         ...        ...         ...         ...         ...
# sub-6023469  ...   -1.903193  -7.743419  149.730160  354.984220  156.440540
# sub-6023808  ...   -1.379239  -1.633720    1.292973  321.070370  266.444760
# sub-6023847  ...   -5.900459  -1.483151   -6.001945   -4.548874   -1.909666
# sub-6024038  ...   -5.859507  -2.266010   -6.761948  575.765140   -2.979827
# sub-6024754  ...   -2.028181 -10.015537   -1.212723  706.531100   -0.026126
#
#                  dim252       dim253       dim254      dim255      dim256
# ID
# sub-1000021  635.032000   325.938050    70.105156   -0.378246  483.235400
# sub-1000458   -4.329172    -7.507878  1066.472900   -2.173929  263.600700
# sub-1000575  461.017800   530.015870    -1.566568   -1.512872   -0.042711
# sub-1000606   -3.946515    -2.080509    -1.802815   -2.851882   -3.384521
# sub-1000963  668.517400  1018.194400    -9.200782   -5.979842   -4.713279
# ...                 ...          ...          ...         ...         ...
# sub-6023469  599.004200   829.532400    -6.547669  138.618070   -3.003732
# sub-6023808  226.789580  1149.253200    -4.308256   -1.946643   84.841380
# sub-6023847   -4.589243    -3.878112    -2.582579   -0.476821   -7.649068
# sub-6024038   21.597443   296.318760    -1.505555   -4.293943   -2.004733
# sub-6024754  380.027600    81.238075    -0.623096   45.528890   -0.218963
#
# [21051 rows x 256 columns]

# %%
schiz_emb = pd.read_csv(schiz_emb_file, index_col=0)
schiz_emb
# Out:
#                       dim1        dim2        dim3        dim4        dim5  \
# ID
# sub-INV056VJPL6  442.55650  430.862500  217.760530   -1.756982  198.297680
# sub-INV05AFGN2Z   20.52209   -3.971420   -5.820910   -6.163883   -3.289176
# sub-INV07WT2ZL3  380.91373   -1.786476   -3.375857   -5.686321   -2.907711
# sub-INV0AL14J6U  512.72943  234.177230   -4.628723  465.975040  275.990230
# sub-INV0CF8E46F  494.28275   -5.176065   -4.110297   -6.103733   -3.246993
# ...                    ...         ...         ...         ...         ...
# sub-INVZNPKMUDE  598.11210    0.256693   -1.340300   -1.688881   -0.769008
# sub-INVZRR5UA6P  287.76110   -5.470191   -4.723291  361.479220   44.974342
# sub-INVZTBFRT07  171.15306    6.584053  172.592220  190.922090  151.583900
# sub-INVZVZDT24E  339.87057   -3.877215  122.054240   51.638718   -0.200092
# sub-INVZWA8D8B2  665.04560  344.925230   -3.095629   -0.054929  234.331650
#
#                        dim6         dim7      dim8        dim9       dim10  \
# ID
# sub-INV056VJPL6  355.377600   378.534300 -5.736830    3.541795    9.719282
# sub-INV05AFGN2Z   -4.204477   -10.236280 -5.553584   33.977486  285.997770
# sub-INV07WT2ZL3   -6.458592    81.778060 -4.037345   85.423850   99.732080
# sub-INV0AL14J6U  533.495360  1101.822600 -1.402843  639.555300  -11.518138
# sub-INV0CF8E46F   -8.228590    -4.837236 -4.799842  117.057770  895.357400
# ...                     ...          ...       ...         ...         ...
# sub-INVZNPKMUDE   -2.803487   506.380200 -3.391280   -0.617042  340.557430
# sub-INVZRR5UA6P  141.535400   147.192410 -0.147988  659.926300   46.292786
# sub-INVZTBFRT07  346.470280   301.209170 -0.226397  474.613250   -0.321550
# sub-INVZVZDT24E  129.417770    50.985786 -1.271011   -0.262581  500.114070
# sub-INVZWA8D8B2  281.902220   482.647800 -6.055279  235.025940   -0.918364
#
#                  ...     dim247      dim248      dim249      dim250  \
# ID               ...
# sub-INV056VJPL6  ...  -4.004776   -4.422100   -4.782725  687.117200
# sub-INV05AFGN2Z  ...  37.484970   -4.149294  727.812740   -4.676159
# sub-INV07WT2ZL3  ...  -5.460279   -2.510245  289.139600   -3.041569
# sub-INV0AL14J6U  ...  -2.642292  329.719100   -5.096258   -3.005507
# sub-INV0CF8E46F  ...  -5.494958   88.698830  115.950680   -8.680335
# ...              ...        ...         ...         ...         ...
# sub-INVZNPKMUDE  ...  -7.911313   -1.471802   -4.693616   -0.919858
# sub-INVZRR5UA6P  ...  -3.313802  532.847000   -0.448092   -7.596501
# sub-INVZTBFRT07  ...  -1.542709  180.096980  369.354100  520.292600
# sub-INVZVZDT24E  ...  -2.659200   -0.054186   -1.760301  245.720980
# sub-INVZWA8D8B2  ...  -5.291407   -1.170150   -6.388062   -1.842957
#
#                      dim251      dim252       dim253      dim254    dim255  \
# ID
# sub-INV056VJPL6   -0.911598   -1.201702   296.314360   27.047308 -3.605955
# sub-INV05AFGN2Z   28.449541  878.390750  1123.255900   -9.519300 -0.679935
# sub-INV07WT2ZL3   -0.107665  172.583720   992.376000  -11.707168 -2.945908
# sub-INV0AL14J6U   -0.679167   -6.253643    -9.894746  748.422900 -2.337394
# sub-INV0CF8E46F   -0.248257  259.375150  1380.965700  -14.511691 -4.087863
# ...                     ...         ...          ...         ...       ...
# sub-INVZNPKMUDE   -2.111819   -0.936929   921.066960  -10.115491 -3.732598
# sub-INVZRR5UA6P   -0.737039  182.754530   341.124150   -3.605024 -3.923866
# sub-INVZTBFRT07  224.000410  231.249070   437.647740   -0.348887 -2.886138
# sub-INVZVZDT24E  107.512000  369.125240  1007.747400   -5.048741 -1.109860
# sub-INVZWA8D8B2   -2.070288   -3.589989   102.222500   -1.346674 -3.917537
#
#                      dim256
# ID
# sub-INV056VJPL6  184.538940
# sub-INV05AFGN2Z  110.755684
# sub-INV07WT2ZL3   -6.404649
# sub-INV0AL14J6U   -3.228967
# sub-INV0CF8E46F   -8.695777
# ...                     ...
# sub-INVZNPKMUDE   -6.530766
# sub-INVZRR5UA6P   -7.363599
# sub-INVZTBFRT07   -1.729166
# sub-INVZVZDT24E   -2.633493
# sub-INVZWA8D8B2   -1.250930
#
# [385 rows x 256 columns]

# %%
schiz_label = pd.read_csv(schiz_label_file, index_col=0)
schiz_label
# Out:
#                 sex   age      diagnosis   study    site
# participant_id
# sub-INV07WT2ZL3   M  29.0        control   BSNIP  Dallas
# sub-INV0AL14J6U   M  43.0  schizophrenia   BSNIP  Dallas
# sub-INV14XK7P6E   M  30.0        control   BSNIP  Dallas
# sub-INV1HXNTXYF   F  18.0        control   BSNIP  Dallas
# sub-INV1XCNF4J5   F  25.0        control   BSNIP  Dallas
# ...              ..   ...            ...     ...     ...
# sub-ESOC10060     F  26.0        control  PRAGUE  PRAGUE
# sub-ESOC10019     F  28.0        control  PRAGUE  PRAGUE
# sub-ESOC10063     M  31.0        control  PRAGUE  PRAGUE
# sub-ESOC10098     F  27.0        control  PRAGUE  PRAGUE
# sub-ESOC10106     F  23.0        control  PRAGUE  PRAGUE
#
# [1292 rows x 5 columns]

# %%
np.unique(schiz_label.diagnosis)
# Out:
# array(['control', 'schizophrenia'], dtype=object)

# %% [markdown]
# # UKBioBank

# %%
norm = ukb_emb.apply(np.linalg.norm, axis=1)
ukb_emb = ukb_emb.div(norm, axis=0)

# %%
ukb_emb
# Out:
#                  dim1      dim2      dim3      dim4      dim5      dim6  \
# ID
# sub-1000021 -0.000739 -0.000095 -0.000422 -0.000696  0.006377  0.084542
# sub-1000458  0.056852  0.100175 -0.000134  0.096627  0.085810  0.165688
# sub-1000575 -0.000347 -0.000357  0.062086 -0.000426 -0.000346  0.078086
# sub-1000606  0.119092  0.100605 -0.000928 -0.000767 -0.000209 -0.000364
# sub-1000963 -0.000015 -0.001310 -0.000719 -0.000637 -0.000182 -0.000277
# ...               ...       ...       ...       ...       ...       ...
# sub-6023469 -0.000725 -0.001385  0.002795 -0.000335 -0.001069 -0.000396
# sub-6023808  0.119385 -0.000082  0.049239 -0.000359  0.060052  0.062325
# sub-6023847  0.068396 -0.000240 -0.001030 -0.000136 -0.000704 -0.000640
# sub-6024038  0.062446  0.040013  0.055839  0.036103  0.025154  0.098049
# sub-6024754 -0.000983 -0.000472  0.008640 -0.000575 -0.001080  0.020531
#
#                  dim7      dim8      dim9         dim10  ...    dim247  \
# ID                                                       ...
# sub-1000021 -0.001585 -0.001250  0.025525 -9.709911e-04  ...  0.050668
# sub-1000458  0.133448 -0.000333  0.080918 -1.311822e-03  ... -0.000266
# sub-1000575  0.033414 -0.000887 -0.000294 -6.027991e-04  ... -0.000632
# sub-1000606  0.229783 -0.001117  0.054779 -2.293702e-03  ... -0.001334
# sub-1000963 -0.001410 -0.001455  0.089916  1.511371e-01  ... -0.001281
# ...               ...       ...       ...           ...  ...       ...
# sub-6023469 -0.000185  0.043077 -0.001071 -5.313830e-04  ... -0.000459
# sub-6023808 -0.000932 -0.001048  0.023267  2.258140e-01  ... -0.000349
# sub-6023847  0.217001 -0.000190 -0.000131 -2.148261e-03  ... -0.001190
# sub-6024038  0.158052 -0.000899  0.001955 -7.409793e-07  ... -0.001525
# sub-6024754  0.071843 -0.000398 -0.001124 -2.249469e-03  ... -0.000524
#
#                dim248    dim249    dim250    dim251    dim252    dim253  \
# ID
# sub-1000021 -0.002156  0.124098  0.101320  0.023038  0.163555  0.083946
# sub-1000458 -0.000156 -0.000914  0.076141 -0.000153 -0.000702 -0.001217
# sub-1000575 -0.001833  0.006943  0.237722  0.018690  0.144856  0.166536
# sub-1000606 -0.000635 -0.000312  0.001518 -0.000259 -0.000949 -0.000500
# sub-1000963 -0.000625  0.007913 -0.001001 -0.000948  0.183121  0.278905
# ...               ...       ...       ...       ...       ...       ...
# sub-6023469 -0.001867  0.036092  0.085569  0.037710  0.144390  0.199959
# sub-6023808 -0.000413  0.000327  0.081200  0.067385  0.057356  0.290651
# sub-6023847 -0.000299 -0.001211 -0.000918 -0.000385 -0.000926 -0.000782
# sub-6024038 -0.000590 -0.001759  0.149809 -0.000775  0.005619  0.077100
# sub-6024754 -0.002589 -0.000314  0.182659 -0.000007  0.098248  0.021002
#
#                dim254    dim255    dim256
# ID
# sub-1000021  0.018056 -0.000097  0.124459
# sub-1000458  0.172881 -0.000352  0.042731
# sub-1000575 -0.000492 -0.000475 -0.000013
# sub-1000606 -0.000434 -0.000686 -0.000814
# sub-1000963 -0.002520 -0.001638 -0.001291
# ...               ...       ...       ...
# sub-6023469 -0.001578  0.033414 -0.000724
# sub-6023808 -0.001090 -0.000492  0.021457
# sub-6023847 -0.000521 -0.000096 -0.001543
# sub-6024038 -0.000392 -0.001117 -0.000522
# sub-6024754 -0.000161  0.011771 -0.000057
#
# [21051 rows x 256 columns]

# %%
p = plt.hist(ukb_emb.values.ravel(), bins=np.arange(-0.1,0.4,0.01), density=True)

# %%
Z = ukb_emb.values.ravel()
N = len(Z)
X2 = np.sort(Z)
F2 = np.array(range(N))/float(N)

plt.plot(X2, F2)

# %%
X2[int(N*0.59)]
# Out:
# -2.1919540569670475e-06

# %%
len(ukb_emb)
# Out:
# 21051

# %%
ukb_positive = (ukb_emb>0).sum(axis=0)/len(ukb_emb)
ukb_positive = ukb_positive.sort_values(ascending=False)

# %%
ukb_positive
# Out:
# dim83     0.985986
# dim26     0.961665
# dim113    0.951736
# dim22     0.943661
# dim65     0.875113
#             ...
# dim73     0.000000
# dim155    0.000000
# dim104    0.000000
# dim173    0.000000
# dim188    0.000000
# Length: 256, dtype: float64

# %%
ukb_positive[10:50]
# Out:
# dim91     0.825899
# dim48     0.822859
# dim66     0.807610
# dim93     0.799249
# dim253    0.793454
# dim180    0.778538
# dim111    0.777825
# dim252    0.770415
# dim98     0.767992
# dim41     0.763194
# dim206    0.759299
# dim196    0.756971
# dim33     0.756211
# dim238    0.751271
# dim237    0.743433
# dim220    0.739110
# dim39     0.738825
# dim14     0.738635
# dim96     0.734359
# dim177    0.725904
# dim50     0.719586
# dim88     0.717971
# dim70     0.715453
# dim208    0.713363
# dim74     0.711795
# dim82     0.690799
# dim17     0.686476
# dim217    0.680538
# dim58     0.676690
# dim28     0.672462
# dim186    0.669849
# dim232    0.664101
# dim32     0.663674
# dim76     0.662914
# dim68     0.660444
# dim110    0.651275
# dim163    0.650895
# dim85     0.649518
# dim149    0.647570
# dim78     0.638782
# dtype: float64

# %%
plt.plot(ukb_positive)

# %%
p = plt.hist(ukb_emb.loc[:,"dim83"], bins=100, density=True)

# %%
p = plt.hist(ukb_emb.loc[:,"dim65"], bins=100, density=True)

# %%
p = plt.hist(ukb_emb.loc[:,"dim188"], bins=100, density=True)

# %%
p = plt.hist(ukb_emb.loc[:,"dim10"], bins=100, density=True)

# %% [markdown]
# # Schizophrene

# %%
norm = schiz_emb.apply(np.linalg.norm, axis=1)
schiz_emb = schiz_emb.div(norm, axis=0)

# %%
def compute_umap(df, n_neighbors=15):
    # apply umap
    reducer = umap.UMAP(n_neighbors=n_neighbors)
    visual_embs = reducer.fit_transform(df)
    return visual_embs, reducer

# %%
visual_ukb_emb, reducer = compute_umap(ukb_emb, n_neighbors=15)

# %%
plt.scatter(visual_ukb_emb[:,0], visual_ukb_emb[:,1], c='black', s=1, alpha=0.6)

# %%
visual_schiz_emb = reducer.transform(schiz_emb)

# %%
plt.scatter(visual_ukb_emb[:,0], visual_ukb_emb[:,1], c='black', s=1, alpha=0.6)
plt.scatter(visual_schiz_emb[:,0], visual_schiz_emb[:,1], c='red', s=20, alpha=1)

# %%
ukb_positive = (ukb_emb>0).sum(axis=0)/len(ukb_emb)
# Out:
# dim1      0.579212
# dim2      0.361456
# dim3      0.286067
# dim4      0.374804
# dim5      0.388913
#             ...
# dim252    0.770415
# dim253    0.793454
# dim254    0.292195
# dim255    0.269821
# dim256    0.366586
# Length: 256, dtype: float64

# %%
schiz_order = schiz_emb.copy()
schiz_order.loc["ukb_positive",:] = ukb_positive
schiz_order
# Out:
#                      dim1      dim2      dim3      dim4      dim5      dim6  \
# ID
# sub-INV056VJPL6  0.104678  0.101912  0.051507 -0.000416  0.046903  0.084057
# sub-INV05AFGN2Z  0.004041 -0.000782 -0.001146 -0.001214 -0.000648 -0.000828
# sub-INV07WT2ZL3  0.092168 -0.000432 -0.000817 -0.001376 -0.000704 -0.001563
# sub-INV0AL14J6U  0.089917  0.041067 -0.000812  0.081718  0.048400  0.093559
# sub-INV0CF8E46F  0.082765 -0.000867 -0.000688 -0.001022 -0.000544 -0.001378
# ...                   ...       ...       ...       ...       ...       ...
# sub-INVZRR5UA6P  0.068995 -0.001312 -0.001132  0.086670  0.010783  0.033935
# sub-INVZTBFRT07  0.037863  0.001457  0.038182  0.042237  0.033534  0.076648
# sub-INVZVZDT24E  0.097856 -0.001116  0.035142  0.014868 -0.000058  0.037262
# sub-INVZWA8D8B2  0.157811  0.081849 -0.000735 -0.000013  0.055605  0.066894
# ukb_positive     0.579212  0.361456  0.286067  0.374804  0.388913  0.585198
#
#                      dim7      dim8      dim9     dim10  ...    dim247  \
# ID                                                       ...
# sub-INV056VJPL6  0.089535 -0.001357  0.000838  0.002299  ... -0.000947
# sub-INV05AFGN2Z -0.002016 -0.001094  0.006691  0.056322  ...  0.007382
# sub-INV07WT2ZL3  0.019787 -0.000977  0.020670  0.024132  ... -0.001321
# sub-INV0AL14J6U  0.193225 -0.000246  0.112158 -0.002020  ... -0.000463
# sub-INV0CF8E46F -0.000810 -0.000804  0.019601  0.149922  ... -0.000920
# ...                   ...       ...       ...       ...  ...       ...
# sub-INVZRR5UA6P  0.035292 -0.000035  0.158227  0.011099  ... -0.000795
# sub-INVZTBFRT07  0.066635 -0.000050  0.104996 -0.000071  ... -0.000341
# sub-INVZVZDT24E  0.014680 -0.000366 -0.000076  0.143994  ... -0.000766
# sub-INVZWA8D8B2  0.114529 -0.001437  0.055770 -0.000218  ... -0.001256
# ukb_positive     0.489573  0.105981  0.565911  0.345304  ...  0.200656
#
#                    dim248    dim249    dim250    dim251    dim252    dim253  \
# ID
# sub-INV056VJPL6 -0.001046 -0.001131  0.162524 -0.000216 -0.000284  0.070087
# sub-INV05AFGN2Z -0.000817  0.143328 -0.000921  0.005603  0.172982  0.221203
# sub-INV07WT2ZL3 -0.000607  0.069962 -0.000736 -0.000026  0.041759  0.240120
# sub-INV0AL14J6U  0.057823 -0.000894 -0.000527 -0.000119 -0.001097 -0.001735
# sub-INV0CF8E46F  0.014852  0.019415 -0.001453 -0.000042  0.043431  0.231234
# ...                   ...       ...       ...       ...       ...       ...
# sub-INVZRR5UA6P  0.127758 -0.000107 -0.001821 -0.000177  0.043818  0.081790
# sub-INVZTBFRT07  0.039842  0.081710  0.115102  0.049554  0.051158  0.096819
# sub-INVZVZDT24E -0.000016 -0.000507  0.070748  0.030955  0.106279  0.290152
# sub-INVZWA8D8B2 -0.000278 -0.001516 -0.000437 -0.000491 -0.000852  0.024257
# ukb_positive     0.193387  0.472709  0.572609  0.334758  0.770415  0.793454
#
#                    dim254    dim255    dim256
# ID
# sub-INV056VJPL6  0.006397 -0.000853  0.043649
# sub-INV05AFGN2Z -0.001875 -0.000134  0.021811
# sub-INV07WT2ZL3 -0.002833 -0.000713 -0.001550
# sub-INV0AL14J6U  0.131250 -0.000410 -0.000566
# sub-INV0CF8E46F -0.002430 -0.000684 -0.001456
# ...                   ...       ...       ...
# sub-INVZRR5UA6P -0.000864 -0.000941 -0.001766
# sub-INVZTBFRT07 -0.000077 -0.000638 -0.000383
# sub-INVZVZDT24E -0.001454 -0.000320 -0.000758
# sub-INVZWA8D8B2 -0.000320 -0.000930 -0.000297
# ukb_positive     0.292195  0.269821  0.366586
#
# [386 rows x 256 columns]

# %%
schiz_order = schiz_order.sort_values(schiz_order.last_valid_index(), ascending=False, axis=1)

# %%
schiz_order
# Out:
#                     dim83     dim26    dim113     dim22     dim65     dim81  \
# ID
# sub-INV056VJPL6  0.139777  0.118342  0.149448  0.111462  0.168637  0.126520
# sub-INV05AFGN2Z  0.137581  0.066705  0.083986 -0.000005 -0.000847  0.079497
# sub-INV07WT2ZL3  0.115364  0.098253  0.145476  0.109614  0.009220  0.010403
# sub-INV0AL14J6U  0.050486  0.242150 -0.000157  0.175615  0.164483 -0.000519
# sub-INV0CF8E46F  0.053790  0.008066  0.094125  0.011309 -0.001083  0.028893
# ...                   ...       ...       ...       ...       ...       ...
# sub-INVZRR5UA6P  0.015040  0.122614  0.088725  0.112021  0.057035 -0.000017
# sub-INVZTBFRT07  0.080408  0.069525  0.162097  0.130471  0.180776  0.012430
# sub-INVZVZDT24E  0.099616  0.093923  0.278158  0.160227  0.119946  0.104962
# sub-INVZWA8D8B2  0.079625  0.163884  0.077108  0.108569  0.113701  0.078801
# ukb_positive     0.985986  0.961665  0.951736  0.943661  0.875113  0.868747
#
#                    dim127    dim239    dim121     dim23  ...     dim51  \
# ID                                                       ...
# sub-INV056VJPL6  0.058045 -0.000272  0.001489  0.019701  ... -0.000209
# sub-INV05AFGN2Z  0.054162  0.166000  0.007273 -0.000779  ... -0.000175
# sub-INV07WT2ZL3  0.003797  0.308100  0.050705  0.067927  ... -0.000240
# sub-INV0AL14J6U  0.114722  0.016299  0.007264  0.173516  ... -0.000078
# sub-INV0CF8E46F -0.000774  0.241062 -0.000259 -0.000081  ... -0.000117
# ...                   ...       ...       ...       ...  ...       ...
# sub-INVZRR5UA6P -0.000030  0.269593  0.047856  0.176926  ... -0.000122
# sub-INVZTBFRT07  0.036520  0.148744  0.084162  0.095201  ... -0.000139
# sub-INVZVZDT24E -0.000313  0.233572 -0.000032  0.135526  ... -0.000203
# sub-INVZWA8D8B2  0.038103  0.025777 -0.000354  0.056397  ... -0.000157
# ukb_positive     0.864377  0.847276  0.842098  0.836825  ...  0.000095
#
#                     dim35     dim72    dim173    dim155     dim73    dim104  \
# ID
# sub-INV056VJPL6 -0.000144 -0.000219 -0.000128 -0.000147 -0.000118 -0.000231
# sub-INV05AFGN2Z -0.000049 -0.000131 -0.000078 -0.000087 -0.000053 -0.000124
# sub-INV07WT2ZL3 -0.000125 -0.000185 -0.000159 -0.000129 -0.000121 -0.000275
# sub-INV0AL14J6U -0.000171 -0.000036 -0.000093 -0.000074 -0.000081 -0.000165
# sub-INV0CF8E46F -0.000043 -0.000113 -0.000084 -0.000086 -0.000070 -0.000196
# ...                   ...       ...       ...       ...       ...       ...
# sub-INVZRR5UA6P -0.000191 -0.000112 -0.000126 -0.000143 -0.000128 -0.000281
# sub-INVZTBFRT07 -0.000183 -0.000147 -0.000145 -0.000101 -0.000095 -0.000180
# sub-INVZVZDT24E -0.000240 -0.000265 -0.000149 -0.000200 -0.000184 -0.000365
# sub-INVZWA8D8B2 -0.000140 -0.000170 -0.000132 -0.000143 -0.000135 -0.000280
# ukb_positive     0.000048  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                     dim18    dim144    dim188
# ID
# sub-INV056VJPL6 -0.000135 -0.000092 -0.000186
# sub-INV05AFGN2Z -0.000060 -0.000054 -0.000157
# sub-INV07WT2ZL3 -0.000165 -0.000136 -0.000154
# sub-INV0AL14J6U -0.000076 -0.000062 -0.000158
# sub-INV0CF8E46F -0.000085 -0.000088 -0.000061
# ...                   ...       ...       ...
# sub-INVZRR5UA6P -0.000148 -0.000090 -0.000156
# sub-INVZTBFRT07 -0.000147 -0.000073 -0.000131
# sub-INVZVZDT24E -0.000189 -0.000120 -0.000203
# sub-INVZWA8D8B2 -0.000140 -0.000090 -0.000226
# ukb_positive     0.000000  0.000000  0.000000
#
# [386 rows x 256 columns]
