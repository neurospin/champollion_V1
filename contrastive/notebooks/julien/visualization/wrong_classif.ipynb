# %%
import numpy as np
import pandas as pd
import os
# Out:
# /tmp/ipykernel_370010/2443873611.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
labels = pd.read_csv('/neurospin/dico/data/deep_folding/current/datasets/hcp/hcp_OFC_labels_from_0.csv', usecols=['Subject', 'Left_OFC'])

# %%
model_pred = pd.read_csv('/volatile/jl277509/Runs/02_STS_babies/Program/Output/ORBITAL_12-layer_k7/16-19-26_238/troiani_custom_embeddings/Left_OFC/test_probas_pred_0.csv')

# %%
true_vs_pred = pd.merge(model_pred, labels)

# %%
preds_cl
# Out:
#      Subject         1         2         3         4  Left_OFC
# 70    129937  0.562519  0.092642  0.331970  0.012868         3
# 361   654552  0.623588  0.149268  0.210162  0.016982         3
# 49    123521  0.453436  0.076772  0.442459  0.027333         3
# 219   205220  0.423278  0.489431  0.049728  0.037563         3
# 404   779370  0.552913  0.242965  0.159713  0.044409         3
# 48    122822  0.349874  0.307954  0.297110  0.045062         3
# 132   161327  0.473659  0.354079  0.114961  0.057301         3
# 237   239136  0.267680  0.544235  0.115736  0.072349         3
# 268   329844  0.238079  0.605548  0.082667  0.073705         3
# 100   144226  0.107885  0.780330  0.035586  0.076199         3
# 430   885975  0.182934  0.583631  0.139466  0.093969         3
# 221   207426  0.121553  0.724036  0.050627  0.103785         3
# 421   852455  0.109037  0.627234  0.159796  0.103933         3
# 19    108323  0.339359  0.202897  0.333090  0.124655         3
# 126   158136  0.111081  0.685021  0.063332  0.140567         3
# 31    114217  0.210441  0.576981  0.070264  0.142315         3
# 220   205826  0.097854  0.671995  0.076474  0.153677         3
# 309   492754  0.106543  0.664124  0.056762  0.172571         3
# 262   310621  0.137023  0.652607  0.029071  0.181299         3
# 413   825654  0.299474  0.109212  0.406065  0.185249         3
# 216   203418  0.182760  0.509729  0.106133  0.201378         3
# 244   257542  0.147818  0.461625  0.173122  0.217435         3
# 456   969476  0.074611  0.563162  0.069194  0.293033         3
# 368   677968  0.114284  0.308387  0.267166  0.310163         3
# 185   189652  0.104764  0.492583  0.085323  0.317330         3
# 120   153934  0.057785  0.454995  0.036985  0.450235         3
# 383   725751  0.064392  0.455393  0.019666  0.460549         3
# 71    130417  0.053910  0.342466  0.052767  0.550857         3

# %%
crops_dir = '/neurospin/dico/data/deep_folding/current/datasets/hcp/crops/2mm/ORBITAL/mask/Lcrops'
worst_subs_dict = {}
for cl in range(4):
    preds_cl = true_vs_pred.loc[true_vs_pred['Left_OFC']==cl]
    preds_cl = preds_cl.sort_values(by=str(cl+1))
    worst_subs = preds_cl['Subject'].tolist()[:5]
    print(f'class {cl} : {worst_subs}')
    worst_subs_dict[str(cl)] = worst_subs
# Out:
# class 0 : [159239, 111312, 613538, 177140, 314225]
# class 1 : [249947, 550439, 233326, 115825, 196952]
# class 2 : [183337, 385046, 362034, 849264, 203923]
# class 3 : [129937, 654552, 123521, 205220, 779370]

# %%
cl=0
preds_cl = true_vs_pred.loc[true_vs_pred['Left_OFC']==cl]
preds_cl = preds_cl.sort_values(by=str(cl+1))
preds_cl
