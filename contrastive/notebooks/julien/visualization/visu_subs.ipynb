# %%
import anatomist.api as ana
from soma.qt_gui.qtThread import QtThreadCall
from soma.qt_gui.qt_backend import Qt
from soma import aims
import numpy as np
import os

# %%
a = ana.Anatomist()
# Out:
# global modules: /casa/host/build/share/anatomist-5.2/python_plugins
# home   modules: /casa/home/.anatomist/python_plugins
# loading module gltf_io
# loading module palettecontrols
# loading module measure
# loading module paletteViewer
# loading module meshsplit
# loading module profilewindow
# loading module ana_image_math
# loading module anacontrolmenu
# loading module foldsplit
# loading module modelGraphs
# loading module bsa_proba
# loading module histogram
# loading module gradientpalette
# loading module infowindow
# loading module simple_controls
# loading module volumepalettes
# loading module statsplotwindow
# loading module save_resampled
# loading module valuesplotwindow
# loading module selection
# all python modules loaded
# Anatomist started.

# %%
# random subs to visu one region
dataset = 'UkBioBank40'
side = "L"
region = "F.C.L.p.-subsc.-F.C.L.a.-INSULA./"
# first subs
list_subjects=['sub-1000021',
 'sub-1000325',
 'sub-1000575',
 'sub-1000606',
 'sub-1000715',
 'sub-1000963',
 'sub-1001107',
 'sub-1001393',
 'sub-1001444',
 'sub-1001692',
 'sub-1001942',
 'sub-1002188',
 'sub-1002539',
 'sub-1002584',
 'sub-1002622']

# %%
side = "R"
region = 'CINGULATE.'

# %%
dataset = 'UkBioBank'
list_subjects = ['sub-1778253', 'sub-3343267', 'sub-3999349', 'sub-1024948', # cosine farthest
       'sub-2387205', 'sub-1406912', 'sub-4201150', 'sub-1313297',
       'sub-3429791', 'sub-4814576', 'sub-5542529', 'sub-2078993']
list_subjects = ['sub-4830095',
 'sub-3174845',
 'sub-1313297',
 'sub-1347557',
 'sub-3552064',
 'sub-3309423',
 'sub-2078993',
 'sub-3945959',
 'sub-1024948',
 'sub-3343267',
 'sub-1566664',
 'sub-3999349'] # cosine 1st neighbour
#list_subjects = ['sub-2078993', 'sub-4378660', 'sub-2804664', 'sub-2149845',
#       'sub-2154500', 'sub-1024948', 'sub-4520895', 'sub-5264927',
#       'sub-4036145', 'sub-3742022', 'sub-2491351', 'sub-5542529'] # chebyshev
list_subjects = ['sub-2711476',
 'sub-3377257',
 'sub-4556181',
 'sub-3920439',
 'sub-5751320',
 'sub-3552064',
 'sub-3172477',
 'sub-1566664',
 'sub-4830095',
 'sub-3429791',
 'sub-3174845',
 'sub-3999349'] # cosine 5th neighbour
list_subjects = ['sub-1166456',
 'sub-2928978',
 'sub-2889071',
 'sub-1758091',
 'sub-1903469',
 'sub-5372169',
 'sub-1059142',
 'sub-2569891',
 'sub-1963424',
 'sub-1091648',
 'sub-1545946',
 'sub-2909909',
 'sub-4945099',
 'sub-3082253',
 'sub-1945921'] ## intersection with neighbours !
#list_subjects = ['sub-4603158', 'sub-4643773', 'sub-5335094', 'sub-1002188', 'sub-4706238', 'sub-2158071', 'sub-1096682', 'sub-4171004', 'sub-1921308',
#'sub-4091566', 'sub-1489362', 'sub-4359267', 'sub-5210463', 'sub-5838136', 'sub-1270546'] ## intersection 15:30
#list_subjects = ['sub-4827346', 'sub-2717128', 'sub-4106264', 'sub-5112813', 'sub-4087404', 'sub-1275722',
#'sub-3271608', 'sub-2442557', 'sub-4756052', 'sub-1396937', 'sub-1087571', 'sub-1066680', 'sub-4625766', 'sub-1245608', 'sub-1010220'] # intersection 10000:10015
#list_subjects = ['sub-2353834', 'sub-3974161', 'sub-3862932', 'sub-1873747', 'sub-5731708', 'sub-4097462', 'sub-1485567', 'sub-4706505',
#'sub-1885089', 'sub-3538950', 'sub-4112397', 'sub-3897958', 'sub-3662863', 'sub-4602321', 'sub-4989927'] # intersection -15:
list_subjects = ['sub-1903469',
 'sub-2889071', 'sub-4989927', 'sub-1945921', 'sub-4107177', 'sub-1310920', 'sub-5838136', 'sub-5782466',
 'sub-1005290', 'sub-2501331', 'sub-1946263', 'sub-4389685', 'sub-1002188', 'sub-5980436', 'sub-4772993'] ## intersection with neighbours / size
list_subjects = [
 'sub-1903469',
 'sub-2889071',
 'sub-1945921',
 'sub-4107177',
 'sub-1310920',
 'sub-4989927',
 'sub-5838136',
 'sub-2501331',
 'sub-1005290',
 'sub-5782466',
 'sub-1002188',
 'sub-4389685',
 'sub-1946263',
 'sub-1085241',
 'sub-5980436',
 'sub-1113217',
 'sub-1091648',
 'sub-1166456',
 'sub-1096682']
list_subjects=['sub-4989927'] ## weird segmentation
"""
list_subjects = ['sub-5896229',
 'sub-3491711',
 'sub-1959785',
 'sub-2969452',
 'sub-1567166',
 'sub-3824165',
 'sub-2898042',
 'sub-4849550',
 'sub-4389587',
 'sub-5423345',
 'sub-1023965',
 'sub-5924099',
 'sub-2791091',
 'sub-5945132',
 'sub-5297941',
 'sub-5510712',
 'sub-1683899',
 'sub-2177718',
 'sub-1213518',
 'sub-1028481']
list_subjects = ['sub-5907151',
 'sub-4059839',
 'sub-1228669',
 'sub-1195108',
 'sub-5584356',
 'sub-3664042',
 'sub-2080129',
 'sub-3866422',
 'sub-1334564',
 'sub-1064312',
 'sub-2628215',
 'sub-2535341',
 'sub-1014504',
 'sub-4567398',
 'sub-5093679']
list_subjects=['sub-3284441', 'sub-4451328',
 'sub-3144578',
 'sub-1492012',
 'sub-2970923',
 'sub-5422858',
 'sub-3386523',
 'sub-3640419',
 'sub-2295385',
 'sub-1514975',
 'sub-2623007',
 'sub-2313287',
 'sub-1677108',
 'sub-3401476',
 'sub-4534724']
list_subjects=['sub-2851287',
 'sub-2183517',
 'sub-1159141',
 'sub-3368561',
 'sub-2275112',
 'sub-4584267',
 'sub-5736350',
 'sub-4959888',
 'sub-5889327',
 'sub-2108098',
 'sub-1442280',
 'sub-3453786',
 'sub-4539313',
 'sub-4789052',
 'sub-4466883']
list_subjects=['sub-1346786',
 'sub-3201373',
 'sub-3905368',
 'sub-5988906',
 'sub-1405097',
 'sub-4979584',
 'sub-4483151',
 'sub-1603417',
 'sub-5801777',
 'sub-5331726',
 'sub-1211314',
 'sub-5785530',
 'sub-5778506',
 'sub-5807833',
 'sub-3120561']
list_subjects = ['sub-3630327',
 '104012',
 'sub-4987473',
 'sub-3462570',
 'sub-5971085',
 'sub-4088865',
 'sub-2765667',
 'sub-1098739',
 'sub-1174776',
 'sub-1018758',
 'sub-5377968',
 'sub-5825997',
 'sub-4678815',
 'sub-5608155',
 'sub-5161805',
 'sub-4590682']

list_subjects=['sub-2512500',
 'sub-1943335',
 'sub-2535255',
 'sub-1095233',
 '751348',
 'sub-2457064',
 'sub-5902047',
 'sub-3626310',
 'sub-5567161',
 'sub-3440134',
 'sub-4647587',
 'sub-1232331',
 'sub-1646846',
 'sub-2619231',
 'sub-3742022',
 'sub-2964392']

list_subjects=['sub-2223750',
 '360030',
 'sub-4773054',
 'sub-4192477',
 'sub-5714152',
 'sub-1018758',
 'sub-4883692',
 'sub-4997656',
 'sub-4487108',
 'sub-4391070',
 'sub-5079960',
 'sub-4674301',
 'sub-4094345',
 'sub-3890336',
 'sub-2039056',
 'sub-1356295']
 """
# Out:
# "\nlist_subjects = ['sub-5896229',\n 'sub-3491711',\n 'sub-1959785',\n 'sub-2969452',\n 'sub-1567166',\n 'sub-3824165',\n 'sub-2898042',\n 'sub-4849550',\n 'sub-4389587',\n 'sub-5423345',\n 'sub-1023965',\n 'sub-5924099',\n 'sub-2791091',\n 'sub-5945132',\n 'sub-5297941',\n 'sub-5510712',\n 'sub-1683899',\n 'sub-2177718',\n 'sub-1213518',\n 'sub-1028481']\nlist_subjects = ['sub-5907151',\n 'sub-4059839',\n 'sub-1228669',\n 'sub-1195108',\n 'sub-5584356',\n 'sub-3664042',\n 'sub-2080129',\n 'sub-3866422',\n 'sub-1334564',\n 'sub-1064312',\n 'sub-2628215',\n 'sub-2535341',\n 'sub-1014504',\n 'sub-4567398',\n 'sub-5093679']\nlist_subjects=['sub-3284441', 'sub-4451328',\n 'sub-3144578',\n 'sub-1492012',\n 'sub-2970923',\n 'sub-5422858',\n 'sub-3386523',\n 'sub-3640419',\n 'sub-2295385',\n 'sub-1514975',\n 'sub-2623007',\n 'sub-2313287',\n 'sub-1677108',\n 'sub-3401476',\n 'sub-4534724']\nlist_subjects=['sub-2851287',\n 'sub-2183517',\n 'sub-1159141',\n 'sub-3368561',\n 'sub-2275112',\n 'sub-4584267',\n 'sub-5736350',\n 'sub-4959888',\n 'sub-5889327',\n 'sub-2108098',\n 'sub-1442280',\n 'sub-3453786',\n 'sub-4539313',\n 'sub-4789052',\n 'sub-4466883']\nlist_subjects=['sub-1346786',\n 'sub-3201373',\n 'sub-3905368',\n 'sub-5988906',\n 'sub-1405097',\n 'sub-4979584',\n 'sub-4483151',\n 'sub-1603417',\n 'sub-5801777',\n 'sub-5331726',\n 'sub-1211314',\n 'sub-5785530',\n 'sub-5778506',\n 'sub-5807833',\n 'sub-3120561']\nlist_subjects = ['sub-3630327',\n '104012',\n 'sub-4987473',\n 'sub-3462570',\n 'sub-5971085',\n 'sub-4088865',\n 'sub-2765667',\n 'sub-1098739',\n 'sub-1174776',\n 'sub-1018758',\n 'sub-5377968',\n 'sub-5825997',\n 'sub-4678815',\n 'sub-5608155',\n 'sub-5161805',\n 'sub-4590682']\n\nlist_subjects=['sub-2512500',\n 'sub-1943335',\n 'sub-2535255',\n 'sub-1095233',\n '751348',\n 'sub-2457064',\n 'sub-5902047',\n 'sub-3626310',\n 'sub-5567161',\n 'sub-3440134',\n 'sub-4647587',\n 'sub-1232331',\n 'sub-1646846',\n 'sub-2619231',\n 'sub-3742022',\n 'sub-2964392']\n\nlist_subjects=['sub-2223750',\n '360030',\n 'sub-4773054',\n 'sub-4192477',\n 'sub-5714152',\n 'sub-1018758',\n 'sub-4883692',\n 'sub-4997656',\n 'sub-4487108',\n 'sub-4391070',\n 'sub-5079960',\n 'sub-4674301',\n 'sub-4094345',\n 'sub-3890336',\n 'sub-2039056',\n 'sub-1356295']\n "

# %%
dataset = 'CCD'
list_subjects = ['ca090293', 'cr070055', 'gd070065', 'lc110410', 'np090301', 'pa080037','pz080261'] # anomaly
#list_subjects = ['ag080048', 'bt080019', 'cd100556', 'fb070174', 'md110095', 'mm080047','vp100400'] # control


list_subjects=['gd070065',
 'pz080261',
 'pa080037',
 'cr070055',
 'ca090293',
 'lc110410',
 'np090301'] + ['mm080047',
 'fb070174',
 'cd100556',
 'md110095',
 'bt080019',
 'vp100400',
 'ag080048']

# %%
# FIP
dataset='UkBioBank40'
side = "R"
region = 'F.I.P.'

# first subs

list_subjects=['sub-1000021',
 'sub-1000325',
 'sub-1000575',
 'sub-1000606',
 'sub-1000715',
 'sub-1000963',
 'sub-1001107',
 'sub-1001393',
 'sub-1001444',
 'sub-1001692',
 'sub-1001942',
 'sub-1002188',
 'sub-1002539',
 'sub-1002584',
 'sub-1002622']

# abnormal
"""
list_subjects=['sub-1574171',
 'sub-1468988',
 'sub-1292245',
 'sub-1190100',
 'sub-1317787',
 'sub-1473302',
 'sub-1197764',
 'sub-1311713',
 'sub-1179978',
 'sub-1220650']
"""
# Out:
# "\nlist_subjects=['sub-1574171',\n 'sub-1468988',\n 'sub-1292245',\n 'sub-1190100',\n 'sub-1317787',\n 'sub-1473302',\n 'sub-1197764',\n 'sub-1311713',\n 'sub-1179978',\n 'sub-1220650']\n"

# %%
# cingulate
dataset='UkBioBank'
side = "R"
region = 'CINGULATE.'

# max
list_subjects =['sub-1360883',
 'sub-1541828',
 'sub-1025328',
 'sub-1485555',
 'sub-1324506',
 'sub-1566483',
 'sub-1247553',
 'sub-1516310',
 'sub-1539310',
 'sub-1513646',
 'sub-1595140',
 'sub-1467659',
 'sub-1035065',
 'sub-1413647',
 'sub-1567394',
 'sub-1313087',
 'sub-1498296',
 'sub-1030632',
 'sub-1273534',
 'sub-1601969',
 'sub-1195890',
 'sub-1265987',
 'sub-1257810',
 'sub-1411954',
 'sub-1655832',
 'sub-1555004',
 'sub-1314348',
 'sub-1422325',
 'sub-1610788',
 'sub-1053608']

# avg
list_subjects=['sub-2219278',
 'sub-1921185',
 'sub-1473379',
 'sub-1587802',
 'sub-2046568',
 'sub-1513646',
 'sub-2097213',
 'sub-1446951',
 'sub-1698640',
 'sub-1265987',
 'sub-2040124',
 'sub-2202452',
 'sub-1551502',
 'sub-1401546',
 'sub-2223597',
 'sub-2021559',
 'sub-2043972',
 'sub-1918349',
 'sub-1524141',
 'sub-1190602',
 'sub-1793228',
 'sub-1025328',
 'sub-2320277',
 'sub-2144673',
 'sub-1545511',
 'sub-1360883',
 'sub-2235283',
 'sub-2323853',
 'sub-1817429',
 'sub-2057411']

# %%
dataset='hcp'
side = "L"
region = 'S.Or.'

# highest std of the augmentations embeddings
list_subjects = [907656,
 107422,
 200210,
 943862,
 724446,
 205826,
 187547,
 617748,
 586460,
 111211]

# median
list_subjects=[557857,
 143426,
 698168,
 814649,
 627549,
 131217,
 126931,
 352132,
 987983,
 884064]

# %%
# same with UKB
dataset='UkBioBank'
side='R'
region='CINGULATE.'
list_subjects=['sub-4934262',
 'sub-2264204',
 'sub-4968366',
 'sub-6018271',
 'sub-5379858',
 'sub-4379665',
 'sub-4096389',
 'sub-4290059',
 'sub-1658370',
 'sub-4933964',
 'sub-5777016',
 'sub-5258060',
 'sub-5989005',
 'sub-1793689',
 'sub-4239849',
 'sub-1575678',
 'sub-2901014',
 'sub-3419526',
 'sub-3792987',
 'sub-5750564']

list_subjects=['sub-1375165',
 'sub-3084967',
 'sub-5027004',
 'sub-1476490',
 'sub-3172102',
 'sub-5189828',
 'sub-4252387',
 'sub-1593503',
 'sub-5359898',
 'sub-3130442',
 'sub-2455185',
 'sub-3585875',
 'sub-1755914',
 'sub-4658752',
 'sub-5129869',
 'sub-3015437',
 'sub-2046568',
 'sub-4262718',
 'sub-1955878',
 'sub-1918061',
 'sub-2255348',
 'sub-4270544',
 'sub-2696554',
 'sub-3845376',
 'sub-1426454',
 'sub-3934608',
 'sub-3882660',
 'sub-2803011',
 'sub-3342747',
 'sub-5966558',
 'sub-5038918',
 'sub-4847539',
 'sub-2318976',
 'sub-1093396',
 'sub-2217995',
 'sub-1473379',
 'sub-5258060',
 'sub-5159616',
 'sub-3955717',
 'sub-3353931']

# %% [markdown]
# # Visu graphs

# %%
block = a.createWindowsBlock(5) # 4 columns
dic_windows = {}
for subject in list_subjects:
    path_to_t1mri = f'/volatile/jl277509/data/graphs_ukb/{subject}/ses-2/anat/t1mri/default_acquisition'
    dic_windows[f'w{subject}'] = a.createWindow("3D", block=block)
    dic_windows[f'white_{subject}'] = a.loadObject(f'{path_to_t1mri}/default_analysis/segmentation/mesh/{subject}_{side}white.gii')
    dic_windows[f'white_{subject}'].loadReferentialFromHeader()
    dic_windows[f'sulci_{subject}'] = a.loadObject(f'{path_to_t1mri}/default_analysis/folds/3.1/{side}{subject}.arg')
    dic_windows[f'sulci_{subject}'].loadReferentialFromHeader()
    dic_windows[f'w{subject}'].addObjects([dic_windows[f'white_{subject}'], dic_windows[f'sulci_{subject}']])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-2e3d3fb69adb> in <module>
#       5     dic_windows[f'w{subject}'] = a.createWindow("3D", block=block)
#       6     dic_windows[f'white_{subject}'] = a.loadObject(f'{path_to_t1mri}/default_analysis/segmentation/mesh/{subject}_{side}white.gii')
# ----> 7     dic_windows[f'white_{subject}'].loadReferentialFromHeader()
#       8     dic_windows[f'sulci_{subject}'] = a.loadObject(f'{path_to_t1mri}/default_analysis/folds/3.1/{side}{subject}.arg')
#       9     dic_windows[f'sulci_{subject}'].loadReferentialFromHeader()
#
# AttributeError: 'NoneType' object has no attribute 'loadReferentialFromHeader'

# %% [markdown]
# # Visu crop buckets

# %%
bucket_files = []

for subject_id in list_subjects:
    if dataset.lower() in ['ukb', 'ukbiobank', 'ukbiobank40']:
        dataset = 'UkBioBank'
        path = f'/neurospin/dico/data/deep_folding/current/datasets/{dataset}/crops/2mm/{region}/mask/{side}buckets'

    if dataset.lower() in ['hcp']:
        path = f'/neurospin/dico/data/deep_folding/current/datasets/{dataset.lower()}/crops/2mm/{region}/mask/{side}buckets'

    if dataset.lower() in ['ccd']:
        path = f'/neurospin/dico/data/deep_folding/current/datasets/CCD/crops/2mm/{region}/mask/{side}buckets'

    filename = f'{path}/{subject_id}_cropped_skeleton.bck'#.minf'

    if os.path. isfile(filename):
        bucket_files.append(filename)
    else:
        print(f"{filename} is not a correct path, or the .bck doesn't exist")
bucket_files
# Out:
# /neurospin/dico/data/deep_folding/current/datasets/UkBioBank/crops/2mm/FCLp-subsc-FCLa-INSULA/mask/Lbuckets/sub-1000021_cropped_skeleton.bck is not a correct path, or the .bck doesn't exist
# /neurospin/dico/data/deep_folding/current/datasets/UkBioBank/crops/2mm/FCLp-subsc-FCLa-INSULA/mask/Lbuckets/sub-1000325_cropped_skeleton.bck is not a correct path, or the .bck doesn't exist
# /neurospin/dico/data/deep_folding/current/datasets/UkBioBank/crops/2mm/FCLp-subsc-FCLa-INSULA/mask/Lbuckets/sub-1000575_cropped_skeleton.bck is not a correct path, or the .bck doesn't exist
# /neurospin/dico/data/deep_folding/current/datasets/UkBioBank/crops/2mm/FCLp-subsc-FCLa-INSULA/mask/Lbuckets/sub-1000606_cropped_skeleton.bck is not a correct path, or the .bck doesn't exist
# /neurospin/dico/data/deep_folding/current/datasets/UkBioBank/crops/2mm/FCLp-subsc-FCLa-INSULA/mask/Lbuckets/sub-1000715_cropped_skeleton.bck is not a correct path, or the .bck doesn't exist
# /neurospin/dico/data/deep_folding/current/datasets/UkBioBank/crops/2mm/FCLp-subsc-FCLa-INSULA/mask/Lbuckets/sub-1000963_cropped_skeleton.bck is not a correct path, or the .bck doesn't exist
# /neurospin/dico/data/deep_folding/current/datasets/UkBioBank/crops/2mm/FCLp-subsc-FCLa-INSULA/mask/Lbuckets/sub-1001107_cropped_skeleton.bck is not a correct path, or the .bck doesn't exist
# /neurospin/dico/data/deep_folding/current/datasets/UkBioBank/crops/2mm/FCLp-subsc-FCLa-INSULA/mask/Lbuckets/sub-1001393_cropped_skeleton.bck is not a correct path, or the .bck doesn't exist
# /neurospin/dico/data/deep_folding/current/datasets/UkBioBank/crops/2mm/FCLp-subsc-FCLa-INSULA/mask/Lbuckets/sub-1001444_cropped_skeleton.bck is not a correct path, or the .bck doesn't exist
# /neurospin/dico/data/deep_folding/current/datasets/UkBioBank/crops/2mm/FCLp-subsc-FCLa-INSULA/mask/Lbuckets/sub-1001692_cropped_skeleton.bck is not a correct path, or the .bck doesn't exist
# /neurospin/dico/data/deep_folding/current/datasets/UkBioBank/crops/2mm/FCLp-subsc-FCLa-INSULA/mask/Lbuckets/sub-1001942_cropped_skeleton.bck is not a correct path, or the .bck doesn't exist
# /neurospin/dico/data/deep_folding/current/datasets/UkBioBank/crops/2mm/FCLp-subsc-FCLa-INSULA/mask/Lbuckets/sub-1002188_cropped_skeleton.bck is not a correct path, or the .bck doesn't exist
# /neurospin/dico/data/deep_folding/current/datasets/UkBioBank/crops/2mm/FCLp-subsc-FCLa-INSULA/mask/Lbuckets/sub-1002539_cropped_skeleton.bck is not a correct path, or the .bck doesn't exist
# /neurospin/dico/data/deep_folding/current/datasets/UkBioBank/crops/2mm/FCLp-subsc-FCLa-INSULA/mask/Lbuckets/sub-1002584_cropped_skeleton.bck is not a correct path, or the .bck doesn't exist
# /neurospin/dico/data/deep_folding/current/datasets/UkBioBank/crops/2mm/FCLp-subsc-FCLa-INSULA/mask/Lbuckets/sub-1002622_cropped_skeleton.bck is not a correct path, or the .bck doesn't exist
# []

# %%
block = a.createWindowsBlock(5) # 4 columns
d = {}

for i, file in enumerate(bucket_files):
    d[f'bck_{i}'] = a.loadObject(file)
    d[f'w_{i}'] = a.createWindow('3D', block=block)#geometry=[100+400*(i%3), 100+440*(i//3), 400, 400])
    d[f'w_{i}'].addObjects(d[f'bck_{i}'])
