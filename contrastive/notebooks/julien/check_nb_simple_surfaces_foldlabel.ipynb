# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from soma import aims

# %%
# loop over foldlabel
# arr[arr>=2000]=0
# n = np.max(arr)
# l.append(n)
# plt.plot(l)

# %%
dir_foldlabel = '/neurospin/dico/data/deep_folding/current/datasets/UkBioBank/foldlabels/raw/R/'
foldlabels = os.listdir(dir_foldlabel)
foldlabels = [fold for fold in foldlabels if fold[-1]!='f']

# %%
foldlabels[np.argmax(l)]
# Out:
# 'Lfoldlabel_sub-1415090.nii.gz'

# %%
l=[]
for (idx, foldlabel) in enumerate(foldlabels):
    vol = aims.read(dir_foldlabel+foldlabel)
    arr = vol.np
    arr[arr>=2000]=0
    n = np.max(arr)
    l.append(n-1000)

# %%
print(max(l))
# Out:
# 792

# %%
plt.hist(l)
plt.xlabel('nb of simple surfaces')
plt.show()

# %%
np.sum(np.array(l)>983)
# Out:
# 2

# %%
plt.hist(l)
plt.xlabel('nb of simple surfaces')
plt.show()
