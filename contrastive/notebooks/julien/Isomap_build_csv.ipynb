# %%
import pandas as pd
import os

# %%
df = pd.read_csv('/neurospin/dico/data/deep_folding/current/datasets/hcp/isomaps/isomapsurhcp/CingulateSulcus_isomap.txt', sep=' ')

# %%
df
# Out:
#            subject       dim1      dim2      dim3      dim4      dim5  \
# 0          L100206   2.254531  4.487012 -1.857427  2.059584  2.011947
# 1          L100307   0.271804  2.689471  2.810346  1.485902  0.797527
# 2          L100408  -3.087221 -2.509417  5.447575  0.570411  2.187741
# 3          L100610   4.672111  4.856687  1.527257 -0.033238  0.722929
# 4          L101006  11.017965 -1.182422 -4.016098 -3.912979  1.706526
# ...            ...        ...       ...       ...       ...       ...
# 1760  flip-R992673  -9.653150  2.721440 -2.660758  2.149866  1.013881
# 1761  flip-R992774  -1.531916  1.705812  1.724903 -2.827232 -4.158850
# 1762  flip-R993675  -6.252154 -2.631919 -6.633420 -1.873161 -0.724639
# 1763  flip-R994273  -2.432743  2.065159 -1.646967 -2.516347 -3.645490
# 1764  flip-R996782  -1.459313 -3.607705  3.238278  0.401763 -1.797912
#
#           dim6
# 0     3.053309
# 1    -5.502638
# 2     5.075901
# 3    -0.659395
# 4    -1.575350
# ...        ...
# ...

# %%
# get R subs
#df = df[df['subject'].str.startswith('flip')]
# get L subs
df = df[df['subject'].str.startswith('L')]

# %%
l = df['subject']
#l = [elem[6:] for elem in l]
l = [elem[1:] for elem in l]
df['subject']=l
# Out:
# /tmp/ipykernel_2088135/2316627288.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['subject']=l

# %%
df.columns = ['Subject']+[f'Isomap_cingulate_left_dim{k}' for k in range(1,7)]

# %%
df
# Out:
#     Subject  Isomap_cingulate_left_dim1  Isomap_cingulate_left_dim2  \
# 0    100206                    2.254531                    4.487012
# 1    100307                    0.271804                    2.689471
# 2    100408                   -3.087221                   -2.509417
# 3    100610                    4.672111                    4.856687
# 4    101006                   11.017965                   -1.182422
# ..      ...                         ...                         ...
# 878  992673                   -6.090316                   -2.531791
# 879  992774                    1.895446                    6.396108
# 880  993675                    8.262977                    4.142512
# 881  994273                   -4.200693                   -4.050652
# 882  996782                    7.404035                   -4.857917
#
#      Isomap_cingulate_left_dim3  Isomap_cingulate_left_dim4  \
# 0                     -1.857427                    2.059584
# ...

# %%
df.to_csv('/neurospin/dico/data/deep_folding/current/datasets/hcp/hcp_isomap_labels_LSFint-FCMant.csv', index=False)
