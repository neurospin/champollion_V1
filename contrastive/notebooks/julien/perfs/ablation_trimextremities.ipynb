# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import json
from pathlib import Path
import pandas as pd

# %%
save_dir = '/home/jl277509/Documents/Ablation/trimextremities.csv'

# %% [markdown]
# # Step 1 : recover all perf values

# %%
# instead of printing, add in table
from pathlib import Path
import pandas as pd

basedir='/neurospin/dico/jlaval/Output/9_trimextremities'

sub_dirs = {'SOr': [f'{basedir}/SOr_left_UKB40/', ['troiani_custom_embeddings/Left_OFC/test_values.json'], 'test_weighted_auc'],
            'FIP': [f'{basedir}/FIP_right_UKB40/', ['FIP_right_custom_embeddings/Right_FIP/test_values.json'], 'test_auc'],
            'SC-sylv': [f'{basedir}/SC-sylv_left_UKB40/', [f'hcp_isomap_custom_embeddings/Isomap_central_left_dim{k}/test_values.json' for k in range(1,7)], 'test_r2']}

l = os.listdir(basedir)
root_names = [elem for elem in l if 'UKB40' not in elem]

# %%
# store everything globally
l_model_glob = []
l_perf_glob = []
l_region_glob = []
l_task_glob = []


for region, (sub_dir, auc_files, metric) in sub_dirs.items(): 
    for auc_file in auc_files:
        models = os.listdir(sub_dir)
        models = [elem for elem in models if 'config' not in elem and 'multirun' not in elem]
        models.sort()
        task = Path(auc_file).parts[-2]
        for name in root_names:
            #l_models = [elem for elem in models if elem.startswith(name)]
            l_models = [elem for elem in models if name in elem]
            l_perfs = []
            for model in l_models:
                try:
                    with open(os.path.join(sub_dir, model, auc_file), 'r') as f:
                        perf = json.load(f)
                        if isinstance(perf[metric], float):
                            value = perf[metric]
                        else:
                            value = perf[metric][0]
                        l_perfs.append(value)
                except Exception:
                    print(f'{os.path.join(sub_dir, model, auc_file)} not found') ## NB : can't continue if not all files found ...
            l_model_glob.append(l_models)
            l_perf_glob.append(l_perfs)
            l_region_glob.append([region for _ in range(len(l_perfs))])
            l_task_glob.append([task for _ in range(len(l_perfs))])

# %%
# reformat lists and put inside DataFrame
def flatten_sum(matrix):
    return sum(matrix, [])
cols = ['model', 'region', 'task', 'score']
values = np.array([flatten_sum(l_model_glob), flatten_sum(l_region_glob), flatten_sum(l_task_glob), flatten_sum(l_perf_glob)]).T
df = pd.DataFrame(data=values, columns=cols)

# %%
df
# Out:
#                                               model   region  \
# 0     3_trimextremities_pepper50_p40name17-12-20_73      SOr
# 1   2_trimextremities_pepper100_p20name17-11-03_128      SOr
# 2     1_trimextremities_pepper50_p20name17-10-42_22      SOr
# 3   4_trimextremities_pepper100_p40name17-17-24_165      SOr
# 4   2_trimextremities_pepper100_p20name17-10-42_179      FIP
# 5     1_trimextremities_pepper50_p20name17-00-18_48      FIP
# 6   4_trimextremities_pepper100_p40name17-13-04_157      FIP
# 7    3_trimextremities_pepper50_p40name17-11-34_198  SC-sylv
# 8   2_trimextremities_pepper100_p20name17-11-03_245  SC-sylv
# 9     1_trimextremities_pepper50_p20name17-01-35_41  SC-sylv
# 10   4_trimextremities_pepper100_p40name17-13-03_39  SC-sylv
# 11   3_trimextremities_pepper50_p40name17-11-34_198  SC-sylv
# 12  2_trimextremities_pepper100_p20name17-11-03_245  SC-sylv
# 13    1_trimextremities_pepper50_p20name17-01-35_41  SC-sylv
# 14   4_trimextremities_pepper100_p40name17-13-03_39  SC-sylv
# 15   3_trimextremities_pepper50_p40name17-11-34_198  SC-sylv
# 16  2_trimextremities_pepper100_p20name17-11-03_245  SC-sylv
# 17    1_trimextremities_pepper50_p20name17-01-35_41  SC-sylv
# 18   4_trimextremities_pepper100_p40name17-13-03_39  SC-sylv
# 19   3_trimextremities_pepper50_p40name17-11-34_198  SC-sylv
# 20  2_trimextremities_pepper100_p20name17-11-03_245  SC-sylv
# 21    1_trimextremities_pepper50_p20name17-01-35_41  SC-sylv
# 22   4_trimextremities_pepper100_p40name17-13-03_39  SC-sylv
# 23   3_trimextremities_pepper50_p40name17-11-34_198  SC-sylv
# 24  2_trimextremities_pepper100_p20name17-11-03_245  SC-sylv
# 25    1_trimextremities_pepper50_p20name17-01-35_41  SC-sylv
# 26   4_trimextremities_pepper100_p40name17-13-03_39  SC-sylv
# 27   3_trimextremities_pepper50_p40name17-11-34_198  SC-sylv
# 28  2_trimextremities_pepper100_p20name17-11-03_245  SC-sylv
# 29    1_trimextremities_pepper50_p20name17-01-35_41  SC-sylv
# 30   4_trimextremities_pepper100_p40name17-13-03_39  SC-sylv
#
#                         task                 score
# 0                   Left_OFC    0.5563927137090607
# 1                   Left_OFC    0.5906893630062519
# 2                   Left_OFC    0.5267205532728242
# 3                   Left_OFC    0.5961930175399934
# 4                  Right_FIP    0.5848283179012346
# 5                  Right_FIP    0.6563464506172839
# 6                  Right_FIP    0.6160783179012346
# 7   Isomap_central_left_dim1  0.045793460032222066
# 8   Isomap_central_left_dim1   0.05580787650164343
# 9   Isomap_central_left_dim1   0.06917313734114816
# 10  Isomap_central_left_dim1   0.02537677769764224
# 11  Isomap_central_left_dim2   0.07471026307442763
# 12  Isomap_central_left_dim2  0.052326260917177736
# 13  Isomap_central_left_dim2   0.10649843849205087
# 14  Isomap_central_left_dim2    0.0626381456911278
# 15  Isomap_central_left_dim3   0.14546097675388392
# 16  Isomap_central_left_dim3    0.0897023796634302
# 17  Isomap_central_left_dim3   0.19238923241906103
# 18  Isomap_central_left_dim3    0.0922730631122417
# 19  Isomap_central_left_dim4   0.13273627532065746
# 20  Isomap_central_left_dim4   0.07174192086275633
# 21  Isomap_central_left_dim4   0.08099199496626697
# 22  Isomap_central_left_dim4    0.1857298725304043
# 23  Isomap_central_left_dim5  0.035622087033264305
# 24  Isomap_central_left_dim5   0.05635567840361033
# 25  Isomap_central_left_dim5  0.040619841009571944
# 26  Isomap_central_left_dim5   0.06117051694109987
# 27  Isomap_central_left_dim6   0.08399761811146911
# 28  Isomap_central_left_dim6   0.07339993483001594
# 29  Isomap_central_left_dim6   0.11697033102742105
# 30  Isomap_central_left_dim6   0.07014782783257889

# %% [markdown]
# # Step 2 : reorganize the df with the parameters

# %%
# reshape the df so that keep p is a column
# all and bottom are also in a column
list_magnitude=[]
list_proba=[]
for model in df['model'].tolist():
    if 'pepper50' in model:
        list_magnitude.append(50)
    elif 'pepper100' in model:
        list_magnitude.append(100)

    if 'p20' in model:
        list_proba.append(20) 
    elif 'p40' in model:
        list_proba.append(40)

# %%
df['Proba'] = list_proba
df['Magnitude']=list_magnitude

# %%
df_reformat = df.copy()
df_reformat = df_reformat.drop(labels='model', axis='columns')

# %%
# Pivoting the table
df_pivot = df_reformat.pivot(index=['Magnitude', 'Proba'], columns=['task', 'region'], values='score')

# Renaming columns
df_pivot.columns = [f'score_{col}' for col in df_pivot.columns]

# Resetting index to get a flat DataFrame
df_pivot = df_pivot.reset_index()

df_pivot['score_Isomap_left_global'] = df_pivot[df_pivot.columns[-6:]].astype(float).mean(axis=1)
cols = df_pivot.columns.tolist()
cols = cols[:4]+cols[-1:]+cols[4:-1] # put average Isomap before
df_pivot=df_pivot[cols] # swap cols

# %%
# *100 and keep only 1 decimal place
score_cols = df_pivot.columns[2:].tolist()
df_pivot[score_cols]=df_pivot[score_cols].apply(pd.to_numeric).mul(100).round(1)

# %%
df_pivot
# Out:
#    Magnitude  Proba  score_('Left_OFC', 'SOr')  score_('Right_FIP', 'FIP')  \
# 0          1     20                       52.7                        65.6
# 1          1     40                       55.6                         NaN
# 2          2     20                       59.1                        58.5
# 3          2     40                       59.6                        61.6
#
#    score_Isomap_left_global  score_('Isomap_central_left_dim1', 'SC-sylv')  \
# 0                      10.1                                            6.9
# 1                       8.6                                            4.6
# 2                       6.7                                            5.6
# 3                       8.3                                            2.5
#
#    score_('Isomap_central_left_dim2', 'SC-sylv')  \
# 0                                           10.6
# 1                                            7.5
# 2                                            5.2
# 3                                            6.3
#
#    score_('Isomap_central_left_dim3', 'SC-sylv')  \
# 0                                           19.2
# 1                                           14.5
# 2                                            9.0
# 3                                            9.2
#
#    score_('Isomap_central_left_dim4', 'SC-sylv')  \
# 0                                            8.1
# 1                                           13.3
# 2                                            7.2
# 3                                           18.6
#
#    score_('Isomap_central_left_dim5', 'SC-sylv')  \
# 0                                            4.1
# 1                                            3.6
# 2                                            5.6
# 3                                            6.1
#
#    score_('Isomap_central_left_dim6', 'SC-sylv')
# 0                                           11.7
# 1                                            8.4
# 2                                            7.3
# 3                                            7.0

# %%
df_pivot.to_csv(save_dir, index=False)
