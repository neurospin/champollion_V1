# %%
import pandas as pd
import umap
import numpy as np
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score

from sklearn.model_selection import PredefinedSplit, GridSearchCV, cross_val_score, cross_val_predict, LeaveOneOut, KFold
from sklearn.svm import SVC
from hypopt import GridSearch

from sklearn.preprocessing import OneHotEncoder

from umap import UMAP
import skdim
import matplotlib.colors as mcolors
import matplotlib.cm as cm
import seaborn as sns

from sklearn.neighbors import NearestNeighbors

# %%
model_path = "/neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Output/CINGULATE_right/16-18-46_176"
ukb_emb_file = f"{model_path}/ukb_random_embeddings/full_embeddings.csv"

# %%
ukb_emb = pd.read_csv(ukb_emb_file, index_col=0)
ukb_emb
# Out:
#                   dim1       dim2       dim3       dim4       dim5       dim6  \
# ID
# sub-1000021  10.861493 -25.452356 -17.722559  12.979147   2.594467  -1.966175
# sub-1000458   7.190226 -12.151340  13.057828 -23.238022   0.899635  -3.190798
# sub-1000575 -12.068229  -5.911314   0.119280  19.694944  -2.510854   4.868907
# sub-1000606  -0.489287  -1.776471  -2.362469  -6.874474   3.821494  -6.082365
# sub-1000963   5.618343  17.783830  -3.422063  -0.590644   2.910735 -25.145937
# ...                ...        ...        ...        ...        ...        ...
# sub-6023469  -6.065679 -35.818848  -3.731178   9.949704 -17.060478 -10.227982
# sub-6023808   8.528331 -26.598026  -3.990873  21.273106  -5.474471  -5.558226
# sub-6023847   8.241694 -39.948772  10.478790  -6.814939  -0.064649   0.082316
# sub-6024038   7.920410 -15.504106 -19.027002  -8.051330   1.557597  -4.806409
# sub-6024754  -8.880267 -16.442585  20.229925  -4.147468   7.976651  -4.987331
#
#                   dim7       dim8       dim9      dim10  ...     dim247  \
# ID                                                       ...
# sub-1000021 -14.811613  -8.456345  26.272303   7.550975  ...  -9.040921
# sub-1000458   4.578502   8.307644  47.748287  -9.700775  ...  -7.347115
# sub-1000575  -4.583453  -1.424402  -2.283638  -8.004563  ...  -2.371945
# sub-1000606  -3.858770 -42.311560  25.916767  17.080643  ...  -3.042417
# sub-1000963  12.805270  -4.368909  12.117447 -23.266605  ...  31.433403
# ...                ...        ...        ...        ...  ...        ...
# sub-6023469 -14.124343 -26.609734   4.927097  20.685530  ...   1.080619
# sub-6023808  -4.204331 -21.560180  23.901064   2.379967  ...  -6.669702
# sub-6023847  -5.430319 -15.905173  36.903492   7.000581  ...  -5.585844
# sub-6024038  13.209708  12.005863  -6.577943  -4.571511  ...  -2.219785
# sub-6024754  30.244593  -4.442799  31.594856 -32.455784  ...   5.731515
#
#                 dim248     dim249     dim250     dim251     dim252     dim253  \
# ID
# sub-1000021  16.948633  17.617998   0.025364   5.224460   5.073823 -16.522104
# sub-1000458 -17.076601   4.081814  -6.420259  11.714687   2.993500 -10.411158
# sub-1000575  -9.448652  -5.415300 -10.583063 -10.354674 -25.001637  10.974453
# sub-1000606  14.035638 -14.642318   8.825257 -23.739517 -17.541040 -20.637997
# sub-1000963  -1.438764 -13.278314   3.810489  -7.629683   3.309425  -2.628899
# ...                ...        ...        ...        ...        ...        ...
# sub-6023469 -21.391813  16.821564 -13.531563  -0.634192 -10.297783  10.884201
# sub-6023808  -4.496566  -5.501221  -4.301307 -11.547366 -15.228116  -6.424103
# sub-6023847  14.618613   2.537586  20.880106   1.119346  -2.977473 -24.255957
# sub-6024038   1.936932  -7.855882  21.941990  17.663527  -0.949569   2.492842
# sub-6024754   5.959386 -10.865657  10.535584  -2.296933   2.066549 -30.111000
#
#                 dim254     dim255     dim256
# ID
# sub-1000021  27.555405  -0.044473  25.957610
# sub-1000458 -13.271972 -15.340281  11.467621
# sub-1000575 -38.668430   3.171974  16.260775
# sub-1000606  32.331670   1.666823 -10.682402
# sub-1000963  -2.370109  -1.307378  12.151412
# ...                ...        ...        ...
# sub-6023469  30.552483  -6.651351   9.342092
# sub-6023808  36.320990   3.903257  25.730782
# sub-6023847  22.378622   0.549503   8.746752
# sub-6024038 -18.875217  19.757360  -4.692073
# sub-6024754  13.124407 -24.218872   9.238719
#
# [21052 rows x 256 columns]

# %% [markdown]
# # UKBioBank

# %%
# norm = ukb_emb.apply(np.linalg.norm, axis=1)
# ukb_emb = ukb_emb.div(norm, axis=0)

# %%
ukb_emb
# Out:
#                   dim1       dim2       dim3       dim4       dim5       dim6  \
# ID
# sub-1000021  10.861493 -25.452356 -17.722559  12.979147   2.594467  -1.966175
# sub-1000458   7.190226 -12.151340  13.057828 -23.238022   0.899635  -3.190798
# sub-1000575 -12.068229  -5.911314   0.119280  19.694944  -2.510854   4.868907
# sub-1000606  -0.489287  -1.776471  -2.362469  -6.874474   3.821494  -6.082365
# sub-1000963   5.618343  17.783830  -3.422063  -0.590644   2.910735 -25.145937
# ...                ...        ...        ...        ...        ...        ...
# sub-6023469  -6.065679 -35.818848  -3.731178   9.949704 -17.060478 -10.227982
# sub-6023808   8.528331 -26.598026  -3.990873  21.273106  -5.474471  -5.558226
# sub-6023847   8.241694 -39.948772  10.478790  -6.814939  -0.064649   0.082316
# sub-6024038   7.920410 -15.504106 -19.027002  -8.051330   1.557597  -4.806409
# sub-6024754  -8.880267 -16.442585  20.229925  -4.147468   7.976651  -4.987331
#
#                   dim7       dim8       dim9      dim10  ...     dim247  \
# ID                                                       ...
# sub-1000021 -14.811613  -8.456345  26.272303   7.550975  ...  -9.040921
# sub-1000458   4.578502   8.307644  47.748287  -9.700775  ...  -7.347115
# sub-1000575  -4.583453  -1.424402  -2.283638  -8.004563  ...  -2.371945
# sub-1000606  -3.858770 -42.311560  25.916767  17.080643  ...  -3.042417
# sub-1000963  12.805270  -4.368909  12.117447 -23.266605  ...  31.433403
# ...                ...        ...        ...        ...  ...        ...
# sub-6023469 -14.124343 -26.609734   4.927097  20.685530  ...   1.080619
# sub-6023808  -4.204331 -21.560180  23.901064   2.379967  ...  -6.669702
# sub-6023847  -5.430319 -15.905173  36.903492   7.000581  ...  -5.585844
# sub-6024038  13.209708  12.005863  -6.577943  -4.571511  ...  -2.219785
# sub-6024754  30.244593  -4.442799  31.594856 -32.455784  ...   5.731515
#
#                 dim248     dim249     dim250     dim251     dim252     dim253  \
# ID
# sub-1000021  16.948633  17.617998   0.025364   5.224460   5.073823 -16.522104
# sub-1000458 -17.076601   4.081814  -6.420259  11.714687   2.993500 -10.411158
# sub-1000575  -9.448652  -5.415300 -10.583063 -10.354674 -25.001637  10.974453
# sub-1000606  14.035638 -14.642318   8.825257 -23.739517 -17.541040 -20.637997
# sub-1000963  -1.438764 -13.278314   3.810489  -7.629683   3.309425  -2.628899
# ...                ...        ...        ...        ...        ...        ...
# sub-6023469 -21.391813  16.821564 -13.531563  -0.634192 -10.297783  10.884201
# sub-6023808  -4.496566  -5.501221  -4.301307 -11.547366 -15.228116  -6.424103
# sub-6023847  14.618613   2.537586  20.880106   1.119346  -2.977473 -24.255957
# sub-6024038   1.936932  -7.855882  21.941990  17.663527  -0.949569   2.492842
# sub-6024754   5.959386 -10.865657  10.535584  -2.296933   2.066549 -30.111000
#
#                 dim254     dim255     dim256
# ID
# sub-1000021  27.555405  -0.044473  25.957610
# sub-1000458 -13.271972 -15.340281  11.467621
# sub-1000575 -38.668430   3.171974  16.260775
# sub-1000606  32.331670   1.666823 -10.682402
# sub-1000963  -2.370109  -1.307378  12.151412
# ...                ...        ...        ...
# sub-6023469  30.552483  -6.651351   9.342092
# sub-6023808  36.320990   3.903257  25.730782
# sub-6023847  22.378622   0.549503   8.746752
# sub-6024038 -18.875217  19.757360  -4.692073
# sub-6024754  13.124407 -24.218872   9.238719
#
# [21052 rows x 256 columns]

# %%
p = plt.hist(ukb_emb.values.ravel(), bins=np.arange(-0.1,0.4,0.01), density=True)

# %%
Z = ukb_emb.values.ravel()
N = len(Z)
X2 = np.sort(Z)
F2 = np.array(range(N))/float(N)

plt.plot(X2, F2)

# %%
X2[int(N*0.59)]
# Out:
# 3.257717

# %%
len(ukb_emb)
# Out:
# 21052

# %%
ukb_positive = (ukb_emb>0).sum(axis=0)/len(ukb_emb)
ukb_positive = ukb_positive.sort_values(ascending=False)

# %%
ukb_positive
# Out:
# dim70     1.000000
# dim121    1.000000
# dim221    0.940006
# dim79     0.931313
# dim244    0.926183
#             ...
# dim20     0.055149
# dim197    0.053012
# dim210    0.034249
# dim66     0.013205
# dim97     0.000000
# Length: 256, dtype: float64

# %%
plt.plot(ukb_positive)

# %%
p = plt.hist(ukb_emb.loc[:,"dim83"], bins=100, density=True)

# %%
p = plt.hist(ukb_emb.loc[:,"dim65"], bins=100, density=True)

# %% [markdown]
# # UMAP

# %%
def compute_umap(df, n_neighbors=15):
    # apply umap
    reducer = umap.UMAP(n_neighbors=n_neighbors)
    visual_embs = reducer.fit_transform(df)
    return visual_embs, reducer

# %%
visual_ukb_emb, reducer = compute_umap(ukb_emb, n_neighbors=15)

# %%
umap_ukb = visual_ukb_emb

# %%
plt.scatter(visual_ukb_emb[:,0], visual_ukb_emb[:,1], c='black', s=1, alpha=0.6)

# %% [markdown]
# # UKB latent space analysis

# %%
global_id = skdim.id.MOM().fit(ukb_emb, n_neighbors=1000)

# %%
global_id.dimension_
# Out:
# 9.375196632245684

# %%
# lid_mom = skdim.id.lPCA().fit_pw(ukb_emb, n_neighbors=50, n_jobs=1)

# %%
# lid_mom.dimension_

# %%
h = plt.hist(global_id.dimension_pw_, bins=100)

# %%
plt.figure(figsize=(12,8))
q_min = np.min(global_id.dimension_pw_)
q_05 = np.quantile(global_id.dimension_pw_, 0.05) 
q_95 = np.quantile(global_id.dimension_pw_, 0.95)
q_max = np.max(global_id.dimension_pw_)
cmap, norm = mcolors.from_levels_and_colors([q_min, q_05, q_95, q_max], ['red', 'white', 'blue'])
alpha = []
plt.scatter(umap_ukb[:,0], umap_ukb[:,1], s=20, c=global_id.dimension_pw_, alpha=0.6, cmap=cmap, norm=norm)
plt.show()

# %%
nbrs = NearestNeighbors(n_neighbors=2, algorithm='ball_tree').fit(ukb_emb)

# %%
distances, indices = nbrs.kneighbors(ukb_emb)

# %%
distances.shape
# Out:
# (21052, 2)

# %%
h = plt.hist(distances[:,1], bins=100)

# %%
plt.scatter(distances[:,1], global_id.dimension_pw_, s=1)

# %%
heatmap, xedges, yedges = np.histogram2d(distances[:,1], global_id.dimension_pw_, bins=(50,50))
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.imshow(heatmap.T, origin='lower', extent=extent, aspect='auto', cmap=cm.jet)
# plt.figure(figsize=(8,100))
plt.show()
