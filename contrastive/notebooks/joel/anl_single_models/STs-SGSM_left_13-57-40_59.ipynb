# %%
import pandas as pd
import umap
import numpy as np
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score

from sklearn.model_selection import PredefinedSplit, GridSearchCV, cross_val_score, cross_val_predict, LeaveOneOut, KFold
from sklearn.svm import SVC
from hypopt import GridSearch

from sklearn.preprocessing import OneHotEncoder

from umap import UMAP
import skdim
import matplotlib.colors as mcolors
import matplotlib.cm as cm
import seaborn as sns

from sklearn.neighbors import NearestNeighbors

# %%
model_path = "/neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Output/STs-SGSM_left/13-57-40_59"
ukb_emb_file = f"{model_path}/ukb_random_embeddings/full_embeddings.csv"

# %%
ukb_emb = pd.read_csv(ukb_emb_file, index_col=0)
ukb_emb
# Out:
#                   dim1       dim2       dim3       dim4       dim5       dim6  \
# ID
# sub-1000021  -0.185868  -5.771841 -30.507610   5.606935 -42.585770 -10.557935
# sub-1000458  -7.471693  19.638063 -21.538250   2.226732  33.091873 -20.846067
# sub-1000575  38.932930  32.344160   4.402786  38.918230 -29.677853 -28.459377
# sub-1000606 -16.773706  -9.925129  19.955760  98.400540  46.628925   3.211202
# sub-1000963 -35.379436  42.459568  31.299074  28.582540  10.143468  -8.933093
# ...                ...        ...        ...        ...        ...        ...
# sub-6023469   0.063008  -8.937850  22.627310  18.903656  11.491003 -23.642395
# sub-6023808  32.198143  10.538342  11.426944  -1.569624  41.850334 -21.967106
# sub-6023847  17.887506  10.477887  -7.881521  17.285988  51.349990  30.487513
# sub-6024038  -3.885816  14.711593 -34.473743  36.307484  -6.070906 -21.437391
# sub-6024754 -30.073648  -8.566897  39.918232 -11.285641  -9.095921 -58.404120
#
#                   dim7       dim8       dim9      dim10  ...     dim247  \
# ID                                                       ...
# sub-1000021 -55.459835  -9.058824  -1.510824 -20.176199  ...  63.402214
# sub-1000458  34.400425 -21.089120  74.931366 -18.975943  ...  -7.037656
# sub-1000575 -28.141346   3.365387 -10.871907  -4.811211  ...  44.613693
# sub-1000606  26.367805 -12.522888 -27.144012 -27.185587  ...  71.512020
# sub-1000963 -17.111063 -27.134619 -22.592220 -16.000391  ...   6.450301
# ...                ...        ...        ...        ...  ...        ...
# sub-6023469  65.003160 -61.768364  30.422947 -63.957110  ... -40.263510
# sub-6023808  31.761364 -48.997280  16.628088  24.413948  ... -72.307360
# sub-6023847   3.465086 -47.053100 -43.502520  11.385506  ... -42.554592
# sub-6024038  -2.060215 -26.020640  68.749664 -11.252892  ...  18.311350
# sub-6024754  46.695423  -6.445322  23.691990   6.070988  ... -28.322618
#
#                 dim248     dim249     dim250     dim251     dim252     dim253  \
# ID
# sub-1000021   7.537055  10.882882 -46.586758 -68.655390 -19.988195  38.416927
# sub-1000458  31.910760 -36.148930  12.757924 -67.770454  -1.274911 -14.197478
# sub-1000575  30.787392  -6.355664  17.860197 -60.379490  -0.541779  14.632789
# sub-1000606  27.759762 -51.585010  18.421910 -76.338470 -56.197617  -0.121275
# sub-1000963   9.923389 -48.777775 -26.628622 -40.142610 -40.362220  39.475050
# ...                ...        ...        ...        ...        ...        ...
# sub-6023469  45.559326  -4.269194  14.793548 -46.278490  -8.482589  -8.091459
# sub-6023808 -15.866320   3.907229 -36.058796 -43.702854 -31.241480 -56.196125
# sub-6023847 -43.399270 -14.604079  -1.728864 -47.572975 -10.895531 -81.464630
# sub-6024038   2.040595 -40.357956   8.046161 -59.769604 -32.630898  47.094140
# sub-6024754  15.966464 -35.098210  29.297014 -64.597824  16.356821 -27.159777
#
#                 dim254     dim255     dim256
# ID
# sub-1000021 -91.212135   0.566699  17.191797
# sub-1000458   7.364189 -17.087570 -35.701786
# sub-1000575 -14.847200  11.621433  23.035025
# sub-1000606 -70.272194 -40.977352  11.146857
# sub-1000963 -33.237590  20.889872  -8.515278
# ...                ...        ...        ...
# sub-6023469 -20.641650  15.911405  -0.330036
# sub-6023808 -13.396384  11.197630  16.732788
# sub-6023847 -24.240149 -23.508545 -11.117872
# sub-6024038  14.416958 -16.439463   4.032476
# sub-6024754  -9.874482  39.939020  58.612225
#
# [21051 rows x 256 columns]

# %% [markdown]
# # UKBioBank

# %%
# norm = ukb_emb.apply(np.linalg.norm, axis=1)
# ukb_emb = ukb_emb.div(norm, axis=0)

# %%
ukb_emb
# Out:
#                   dim1       dim2       dim3       dim4       dim5       dim6  \
# ID
# sub-1000021  -0.185868  -5.771841 -30.507610   5.606935 -42.585770 -10.557935
# sub-1000458  -7.471693  19.638063 -21.538250   2.226732  33.091873 -20.846067
# sub-1000575  38.932930  32.344160   4.402786  38.918230 -29.677853 -28.459377
# sub-1000606 -16.773706  -9.925129  19.955760  98.400540  46.628925   3.211202
# sub-1000963 -35.379436  42.459568  31.299074  28.582540  10.143468  -8.933093
# ...                ...        ...        ...        ...        ...        ...
# sub-6023469   0.063008  -8.937850  22.627310  18.903656  11.491003 -23.642395
# sub-6023808  32.198143  10.538342  11.426944  -1.569624  41.850334 -21.967106
# sub-6023847  17.887506  10.477887  -7.881521  17.285988  51.349990  30.487513
# sub-6024038  -3.885816  14.711593 -34.473743  36.307484  -6.070906 -21.437391
# sub-6024754 -30.073648  -8.566897  39.918232 -11.285641  -9.095921 -58.404120
#
#                   dim7       dim8       dim9      dim10  ...     dim247  \
# ID                                                       ...
# sub-1000021 -55.459835  -9.058824  -1.510824 -20.176199  ...  63.402214
# sub-1000458  34.400425 -21.089120  74.931366 -18.975943  ...  -7.037656
# sub-1000575 -28.141346   3.365387 -10.871907  -4.811211  ...  44.613693
# sub-1000606  26.367805 -12.522888 -27.144012 -27.185587  ...  71.512020
# sub-1000963 -17.111063 -27.134619 -22.592220 -16.000391  ...   6.450301
# ...                ...        ...        ...        ...  ...        ...
# sub-6023469  65.003160 -61.768364  30.422947 -63.957110  ... -40.263510
# sub-6023808  31.761364 -48.997280  16.628088  24.413948  ... -72.307360
# sub-6023847   3.465086 -47.053100 -43.502520  11.385506  ... -42.554592
# sub-6024038  -2.060215 -26.020640  68.749664 -11.252892  ...  18.311350
# sub-6024754  46.695423  -6.445322  23.691990   6.070988  ... -28.322618
#
#                 dim248     dim249     dim250     dim251     dim252     dim253  \
# ID
# sub-1000021   7.537055  10.882882 -46.586758 -68.655390 -19.988195  38.416927
# sub-1000458  31.910760 -36.148930  12.757924 -67.770454  -1.274911 -14.197478
# sub-1000575  30.787392  -6.355664  17.860197 -60.379490  -0.541779  14.632789
# sub-1000606  27.759762 -51.585010  18.421910 -76.338470 -56.197617  -0.121275
# sub-1000963   9.923389 -48.777775 -26.628622 -40.142610 -40.362220  39.475050
# ...                ...        ...        ...        ...        ...        ...
# sub-6023469  45.559326  -4.269194  14.793548 -46.278490  -8.482589  -8.091459
# sub-6023808 -15.866320   3.907229 -36.058796 -43.702854 -31.241480 -56.196125
# sub-6023847 -43.399270 -14.604079  -1.728864 -47.572975 -10.895531 -81.464630
# sub-6024038   2.040595 -40.357956   8.046161 -59.769604 -32.630898  47.094140
# sub-6024754  15.966464 -35.098210  29.297014 -64.597824  16.356821 -27.159777
#
#                 dim254     dim255     dim256
# ID
# sub-1000021 -91.212135   0.566699  17.191797
# sub-1000458   7.364189 -17.087570 -35.701786
# sub-1000575 -14.847200  11.621433  23.035025
# sub-1000606 -70.272194 -40.977352  11.146857
# sub-1000963 -33.237590  20.889872  -8.515278
# ...                ...        ...        ...
# sub-6023469 -20.641650  15.911405  -0.330036
# sub-6023808 -13.396384  11.197630  16.732788
# sub-6023847 -24.240149 -23.508545 -11.117872
# sub-6024038  14.416958 -16.439463   4.032476
# sub-6024754  -9.874482  39.939020  58.612225
#
# [21051 rows x 256 columns]

# %%
p = plt.hist(ukb_emb.values.ravel(), bins=np.arange(-0.1,0.4,0.01), density=True)

# %%
Z = ukb_emb.values.ravel()
N = len(Z)
X2 = np.sort(Z)
F2 = np.array(range(N))/float(N)

plt.plot(X2, F2)

# %%
X2[int(N*0.59)]
# Out:
# 6.654205

# %%
len(ukb_emb)
# Out:
# 21051

# %%
ukb_positive = (ukb_emb>0).sum(axis=0)/len(ukb_emb)
ukb_positive = ukb_positive.sort_values(ascending=False)

# %%
ukb_positive
# Out:
# dim180    0.999952
# dim218    0.999952
# dim17     0.999287
# dim240    0.996865
# dim165    0.956724
#             ...
# dim21     0.001615
# dim26     0.000048
# dim251    0.000048
# dim82     0.000000
# dim133    0.000000
# Length: 256, dtype: float64

# %%
plt.plot(ukb_positive)

# %%
p = plt.hist(ukb_emb.loc[:,"dim83"], bins=100, density=True)

# %%
p = plt.hist(ukb_emb.loc[:,"dim65"], bins=100, density=True)

# %% [markdown]
# # UMAP

# %%
def compute_umap(df, n_neighbors=15):
    # apply umap
    reducer = umap.UMAP(n_neighbors=n_neighbors)
    visual_embs = reducer.fit_transform(df)
    return visual_embs, reducer

# %%
visual_ukb_emb, reducer = compute_umap(ukb_emb, n_neighbors=15)

# %%
umap_ukb = visual_ukb_emb

# %%
plt.scatter(visual_ukb_emb[:,0], visual_ukb_emb[:,1], c='black', s=1, alpha=0.6)

# %% [markdown]
# # UKB latent space analysis

# %%
global_id = skdim.id.MOM().fit(ukb_emb, n_neighbors=1000)

# %%
global_id.dimension_
# Out:
# 16.813179378755983

# %%
# lid_mom = skdim.id.lPCA().fit_pw(ukb_emb, n_neighbors=50, n_jobs=1)

# %%
# lid_mom.dimension_

# %%
h = plt.hist(global_id.dimension_pw_, bins=100)

# %%
plt.figure(figsize=(12,8))
q_min = np.min(global_id.dimension_pw_)
q_05 = np.quantile(global_id.dimension_pw_, 0.05) 
q_95 = np.quantile(global_id.dimension_pw_, 0.95)
q_max = np.max(global_id.dimension_pw_)
cmap, norm = mcolors.from_levels_and_colors([q_min, q_05, q_95, q_max], ['red', 'white', 'blue'])
alpha = []
plt.scatter(umap_ukb[:,0], umap_ukb[:,1], s=20, c=global_id.dimension_pw_, alpha=0.6, cmap=cmap, norm=norm)
plt.show()

# %%
nbrs = NearestNeighbors(n_neighbors=2, algorithm='ball_tree').fit(ukb_emb)

# %%
distances, indices = nbrs.kneighbors(ukb_emb)

# %%
distances.shape
# Out:
# (21051, 2)

# %%
h = plt.hist(distances[:,1], bins=100)

# %%
plt.scatter(distances[:,1], global_id.dimension_pw_, s=1)

# %%
heatmap, xedges, yedges = np.histogram2d(distances[:,1], global_id.dimension_pw_, bins=(50,50))
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.imshow(heatmap.T, origin='lower', extent=extent, aspect='auto', cmap=cm.jet)
# plt.figure(figsize=(8,100))
plt.show()
