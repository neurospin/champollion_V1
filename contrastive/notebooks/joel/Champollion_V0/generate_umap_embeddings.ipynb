# %% [markdown]
# Il s'agit de générer les UMAPs à 20 dimensions, fitter sur UKBIOBANK et ensuite transform sur UKBIOBANK et les autres bases, en l'occurence synesthete et HCP

# %%
import glob
import os
import omegaconf

import pandas as pd
import numpy as np
import random

import logging

from umap import UMAP

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_predict, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.decomposition import PCA

import statsmodels.api as sm

import matplotlib.pyplot as plt
import seaborn as sns


logging.basicConfig()
logging.getLogger().setLevel(logging.INFO)

# %%
n_neighbors = 15
n_components = 20

path_champollion = "/neurospin/dico/data/deep_folding/current/models/Champollion_V0"
synesthetes_embeddings_subpath = "synesthetes_random_embeddings"
hcp_embeddings_subpath = "hcp_random_embeddings"
syn_embeddings_subpath = "synesthetes_random_embeddings"
ukb_embeddings_subpath = "ukb_random_embeddings"
input_embeddings = "full_embeddings.csv"
output_embeddings = f"umap_c{n_components}_n{n_neighbors}_embeddings.csv"

# %%
def compute_umap(df, n_neighbors=15, n_components=2):
    # apply umap
    reducer = UMAP(n_neighbors=n_neighbors, n_components=n_components)
    visual_embs = reducer.fit_transform(df)
    return visual_embs, reducer

# %%
def is_it_a_file(sub_dir):
    if os.path.isdir(sub_dir):
        return False
    else:
        logging.debug(f"{sub_dir} is a file. Continue.")
        return True
    

def is_folder_a_model(sub_dir):
    if os.path.exists(sub_dir+'/.hydra/config.yaml'):
        return True
    else:
        logging.debug(f"\n{sub_dir} not associated to a model. Continue")
        return False

def get_model_paths(dir_path, result = None):
    """Recursively gets all models included in dir_path"""
    if result is None:  # create a new result if no intermediate was given
        result = [] 
    for name in os.listdir(dir_path):
        sub_dir = dir_path + '/' + name
        # checks if directory
        if is_it_a_file(sub_dir):
            pass
        elif not is_folder_a_model(sub_dir):
            result.extend(get_model_paths(sub_dir))
        else:
            result.append(sub_dir)
    return result

# %%
model_paths = get_model_paths(path_champollion)

# %%
model_paths
# Out:
# ['/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_left/11-43-38_2',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_left/14-00-57_116',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinter-SFsup_left/09-33-02_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/STi-STs-STpol_right/20-15-00_117',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FColl-SRh_right/09-45-57_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/STs-SGSM_left/13-57-40_59',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_right/11-43-38_3',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_right/13-19-08_28',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/Lobule_parietal_sup_left/09-48-31_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFint-SR_left/09-00-43_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_left/22-10-40_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_left/15-39-28_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_left/10-18-59_2',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_left/15-39-28_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_left/10-18-59_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_left/10-18-59_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_left/18-08-26_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinf-BROCA-SPeCinf_right/16-50-50_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinf-BROCA-SPeCinf_right/16-50-50_3',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinf-BROCA-SPeCinf_right/16-50-50_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinf-BROCA-SPeCinf_right/12-25-50_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinf-BROCA-SPeCinf_right/16-50-50_2',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SsP-SPaint_left/10-06-38_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SOr-SOlf_left/18-00-16_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinf-BROCA-SPeCinf_left/12-25-50_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFmedian-SFpoltr-SFsup_right/18-09-26_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FColl-SRh_left/09-45-57_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/STi-STs-STpol_left/14-30-34_34',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFint-FCMant_left/19-52-24_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FCLp-subsc-FCLa-INSULA_right/19-49-20_193',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/OCCIPITAL_right/18-05-00_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPeC_right/09-49-03_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SOr-SOlf_right/18-00-16_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/CINGULATE_left/2024-07-15/17-13-32_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/CINGULATE_left/2024-07-15/17-13-32_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/CINGULATE_left/2024-07-16/16-58-04_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/CINGULATE_left/2024-07-16/16-58-04_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFint-SR_right/09-00-43_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/CINGULATE_right/09-52-22_75',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FCLp-SGSM_right/11-40-20_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/fronto-parietal_medial_face_left/13-07-50_190',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/fronto-parietal_medial_face_left/10-37-44_89',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/ScCal-SLi_left/09-28-12_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FPO-SCu-ScCal_right/20-03-37_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FPO-SCu-ScCal_left/20-03-37_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/OCCIPITAL_left/18-05-00_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPeC_left/09-49-03_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/STs_right/11-43-38_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_left/14-56-46_3',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_left/14-56-46_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_left/14-56-46_2',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_left/14-56-46_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_left/14-56-46_4',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/STsbr_right/16-33-12_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/STsbr_right/16-33-12_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/STsbr_right/17-47-57_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/STsbr_right/16-33-12_3',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/STsbr_right/16-33-12_2',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPoC_right/14-55-36_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/fronto-parietal_medial_face_right/13-49-53_215',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPeC_left/12-36-31_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/STs-SGSM_right/11-40-07_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_right/18-08-26_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/STi-SOTlat_right/09-36-46_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FCLp-SGSM_left/10-57-28_18',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FCMpost-SpC_left/15-09-24_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFint-FCMant_right/19-52-24_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFmedian-SFpoltr-SFsup_left/18-09-26_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPeC_right/12-36-31_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFmarginal-SFinfant_left/17-49-19_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_right/14-24-09_213_joel',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_right/20-16-33_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_right/20-16-33_2',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_right/20-16-33_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_right/20-16-33_4',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_right/20-16-33_3',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FCLp-subsc-FCLa-INSULA_left/18-59-14_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/STsbr_left/17-47-57_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SsP-SPaint_right/10-06-38_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/ScCal-SLi_right/09-28-12_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/Lobule_parietal_sup_right/09-48-31_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_left/20-56-02_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_left/11-50-30_16',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_left/20-56-02_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_left/20-56-02_2',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_left/16-19-26_238',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_left/20-56-02_3',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFmarginal-SFinfant_right/17-49-19_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/STi-SOTlat_left/09-36-46_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinter-SFsup_right/09-33-02_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/STs_left/11-43-38_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FCMpost-SpC_right/15-09-24_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_right/15-53-41_191',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPoC_left/16-46-17_3',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPoC_left/16-46-17_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPoC_left/14-55-36_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPoC_left/16-46-17_1',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPoC_left/16-46-17_2']

# %%
def compute(model_path):
    print("Treating " + model_path)
    # Builds input file names
    ukb_embeddings = f"{model_path}/{ukb_embeddings_subpath}/{input_embeddings}"
    synesthetes_embeddings = f"{model_path}/{synesthetes_embeddings_subpath}/{input_embeddings}"
    hcp_embeddings = f"{model_path}/{hcp_embeddings_subpath}/{input_embeddings}"

    # Builds output file names
    ukb_umap_file = f"{model_path}/{ukb_embeddings_subpath}/{output_embeddings}"
    synesthetes_umap_file = f"{model_path}/{synesthetes_embeddings_subpath}/{output_embeddings}"
    hcp_umap_file = f"{model_path}/{hcp_embeddings_subpath}/{output_embeddings}" 

    # Loads embeddings
    ukb_emb = pd.read_csv(ukb_embeddings, index_col=0)
    synesthetes_emb = pd.read_csv(synesthetes_embeddings, index_col=0)
    hcp_emb = pd.read_csv(hcp_embeddings, index_col=0)

    if os.path.isfile(ukb_umap_file) and os.path.isfile(synesthetes_umap_file) and os.path.isfile(hcp_umap_file):
        pass
    else:
        # Fits umap on UkBioBank
        ukb_umap, reducer = compute_umap(ukb_emb, n_neighbors=n_neighbors, n_components=n_components)
        ukb_umap = pd.DataFrame(ukb_umap)
        ukb_umap.index = ukb_emb.index
        ukb_umap.to_csv(ukb_umap_file)

        # Transforms umap on other datasets
        synesthetes_umap = pd.DataFrame(reducer.transform(synesthetes_emb))
        synesthetes_umap.index = synesthetes_emb.index
        synesthetes_umap.to_csv(synesthetes_umap_file)

        hcp_umap = pd.DataFrame(reducer.transform(hcp_emb))
        hcp_umap.index = hcp_emb.index
        hcp_umap.to_csv(hcp_umap_file)

# %%
# Computes UMAP embeddings
for model_path in model_paths:
    compute(model_path)
# Out:
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_left/11-43-38_2
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_left/14-00-57_116
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinter-SFsup_left/09-33-02_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STi-STs-STpol_right/20-15-00_117
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FColl-SRh_right/09-45-57_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STs-SGSM_left/13-57-40_59
# /home/jc225751/Runs/70_self-supervised_two-regions/Program/venv_natif/lib/python3.10/site-packages/numba/np/ufunc/parallel.py:371: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_right/11-43-38_3
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_right/13-19-08_28
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/Lobule_parietal_sup_left/09-48-31_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFint-SR_left/09-00-43_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_left/22-10-40_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_left/15-39-28_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_left/10-18-59_2
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_left/15-39-28_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_left/10-18-59_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_left/10-18-59_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_left/18-08-26_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinf-BROCA-SPeCinf_right/16-50-50_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinf-BROCA-SPeCinf_right/16-50-50_3
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinf-BROCA-SPeCinf_right/16-50-50_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinf-BROCA-SPeCinf_right/12-25-50_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinf-BROCA-SPeCinf_right/16-50-50_2
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SsP-SPaint_left/10-06-38_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SOr-SOlf_left/18-00-16_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinf-BROCA-SPeCinf_left/12-25-50_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFmedian-SFpoltr-SFsup_right/18-09-26_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FColl-SRh_left/09-45-57_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STi-STs-STpol_left/14-30-34_34
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFint-FCMant_left/19-52-24_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FCLp-subsc-FCLa-INSULA_right/19-49-20_193
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/OCCIPITAL_right/18-05-00_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPeC_right/09-49-03_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SOr-SOlf_right/18-00-16_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/CINGULATE_left/2024-07-15/17-13-32_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/CINGULATE_left/2024-07-15/17-13-32_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/CINGULATE_left/2024-07-16/16-58-04_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/CINGULATE_left/2024-07-16/16-58-04_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFint-SR_right/09-00-43_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/CINGULATE_right/09-52-22_75
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FCLp-SGSM_right/11-40-20_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/fronto-parietal_medial_face_left/13-07-50_190
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/fronto-parietal_medial_face_left/10-37-44_89
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/ScCal-SLi_left/09-28-12_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FPO-SCu-ScCal_right/20-03-37_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FPO-SCu-ScCal_left/20-03-37_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/OCCIPITAL_left/18-05-00_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPeC_left/09-49-03_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STs_right/11-43-38_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_left/14-56-46_3
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_left/14-56-46_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_left/14-56-46_2
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_left/14-56-46_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_left/14-56-46_4
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STsbr_right/16-33-12_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STsbr_right/16-33-12_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STsbr_right/17-47-57_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STsbr_right/16-33-12_3
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STsbr_right/16-33-12_2
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPoC_right/14-55-36_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/fronto-parietal_medial_face_right/13-49-53_215
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPeC_left/12-36-31_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STs-SGSM_right/11-40-07_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_right/18-08-26_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STi-SOTlat_right/09-36-46_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FCLp-SGSM_left/10-57-28_18
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FCMpost-SpC_left/15-09-24_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFint-FCMant_right/19-52-24_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFmedian-SFpoltr-SFsup_left/18-09-26_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPeC_right/12-36-31_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFmarginal-SFinfant_left/17-49-19_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_right/14-24-09_213_joel
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_right/20-16-33_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_right/20-16-33_2
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_right/20-16-33_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_right/20-16-33_4
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_right/20-16-33_3
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FCLp-subsc-FCLa-INSULA_left/18-59-14_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STsbr_left/17-47-57_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SsP-SPaint_right/10-06-38_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/ScCal-SLi_right/09-28-12_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/Lobule_parietal_sup_right/09-48-31_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_left/20-56-02_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_left/11-50-30_16
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_left/20-56-02_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_left/20-56-02_2
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_left/16-19-26_238
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_left/20-56-02_3
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFmarginal-SFinfant_right/17-49-19_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STi-SOTlat_left/09-36-46_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinter-SFsup_right/09-33-02_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STs_left/11-43-38_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FCMpost-SpC_right/15-09-24_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_right/15-53-41_191
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPoC_left/16-46-17_3
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPoC_left/16-46-17_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPoC_left/14-55-36_0
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPoC_left/16-46-17_1
# Treating /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPoC_left/16-46-17_2
