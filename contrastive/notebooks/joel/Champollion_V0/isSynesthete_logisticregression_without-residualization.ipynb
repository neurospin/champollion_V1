# %%
import glob
import os
import omegaconf

import pandas as pd
import numpy as np
import random

import logging

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_predict, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns


logging.basicConfig()
logging.getLogger().setLevel(logging.INFO)

# %%
path_champollion = "/neurospin/dico/data/deep_folding/current/models/Champollion_V0"
participants_file = "/neurospin/dico/data/deep_folding/current/datasets/synesthetes/participants.csv"
embeddings_subpath = "synesthetes_random_embeddings/full_embeddings.csv"
ukb_embeddings_subpath = "ukb_random_embeddings/full_embeddings.csv"
output_filename = f"{path_champollion}/summary/isSynesthete_without_residualization.csv"
label = "isSynesthete"
max_iter = 2000
cv = 5

# %%
participants = pd.read_csv(participants_file, index_col=0)

# %%
participants.head()
# Out:
#                                       isSynesthete   NOM         DDN IRM name  \
# participant_id
# mv_SYNESTHEX_3-Session1_S2_T1w                   1  SARR   10/8/1996  Sujet01
# mv_SYNESTHEX_S_Session1_S2_T1w                   1  LEFR  14/12/1950  Sujet02
# mv_SYNESTHEX_M_Session1_S2_T1w                   1  FERN         NaN  Sujet03
# mv_SYNESTHEX_K_Session1_S2_T1w                   1  DERO   27/6/1997  Sujet04
# mv_SYNESTHEX_Sujet20_Session1_S2_T1w             1  DECH         NaN  Sujet05
#
#                                         Date IRM        Âge  Sexe  Latéralité  \
# participant_id
# mv_SYNESTHEX_3-Session1_S2_T1w         28/2/2023  26.569863     2           0
# mv_SYNESTHEX_S_Session1_S2_T1w          9/3/2023  72.282192     2           0
# mv_SYNESTHEX_M_Session1_S2_T1w               NaN  23.680000     1           0
# mv_SYNESTHEX_K_Session1_S2_T1w        21/10/2023  26.334247     1           0
# mv_SYNESTHEX_Sujet20_Session1_S2_T1w         NaN  21.110000     2           1
#
#                                      Remarques  Code BV  Unnamed: 9  \
# participant_id
# mv_SYNESTHEX_3-Session1_S2_T1w             NaN        3         NaN
# mv_SYNESTHEX_S_Session1_S2_T1w             NaN        S         NaN
# mv_SYNESTHEX_M_Session1_S2_T1w             NaN        M         NaN
# mv_SYNESTHEX_K_Session1_S2_T1w             NaN        K         NaN
# mv_SYNESTHEX_Sujet20_Session1_S2_T1w       NaN  Sujet20         NaN
#
#                                       2=femme – 1=homme  \
# participant_id
# mv_SYNESTHEX_3-Session1_S2_T1w                      NaN
# mv_SYNESTHEX_S_Session1_S2_T1w                      NaN
# mv_SYNESTHEX_M_Session1_S2_T1w                      NaN
# mv_SYNESTHEX_K_Session1_S2_T1w                      NaN
# mv_SYNESTHEX_Sujet20_Session1_S2_T1w                NaN
#
#                                       0=droitier – 1=gaucher
# participant_id
# mv_SYNESTHEX_3-Session1_S2_T1w                           NaN
# mv_SYNESTHEX_S_Session1_S2_T1w                           NaN
# mv_SYNESTHEX_M_Session1_S2_T1w                           NaN
# mv_SYNESTHEX_K_Session1_S2_T1w                           NaN
# mv_SYNESTHEX_Sujet20_Session1_S2_T1w                     NaN

# %%
participants = participants[["isSynesthete", "Sexe", "Latéralité"]]

# %%
# participants[:] = participants.sample(frac=1).values

# %%
participants
# Out:
#                                        isSynesthete  Sexe  Latéralité
# participant_id
# mv_SYNESTHEX_3-Session1_S2_T1w                    1     2           0
# mv_SYNESTHEX_S_Session1_S2_T1w                    1     2           0
# mv_SYNESTHEX_M_Session1_S2_T1w                    1     1           0
# mv_SYNESTHEX_K_Session1_S2_T1w                    1     1           0
# mv_SYNESTHEX_Sujet20_Session1_S2_T1w              1     2           1
# mv_SYNESTHEX_Y_Session1_S2_T1w                    1     1           0
# mv_SYNESTHEX_Sujet25_Session1_S2_T1w              1     1           1
# mv_SYNESTHEX_G_Session1_S2_T1w                    1     2           0
# mv_SYNESTHEX_D_Session1_S2_T1w                    1     2           0
# mv_SYNESTHEX_X_Session1_S2_T1w                    1     2           0
# mv_SYNESTHEX_Sujet26_Session1_S2_T1w              1     1           1
# mv_SYNESTHEX_7-Session1_S2_T1w                    1     2           0
# mv_SYNESTHEX_Z_Session1_S2_T1w                    1     2           0
# mv_SYNESTHEX_Sujet22_Session1_S2_T1w              1     2           1
# mv_SYNESTHEX_T_Session1_S2_T1w                    1     2           0
# mv_SYNESTHEX_Sujet27_Session1_S2_T1w              1     1           1
# mv_SYNESTHEX_P_Session1_S2_T1w                    1     2           0
# mv_SYNESTHEX_A_S2_T1w                             1     2           0
# mv_SYNESTHEX_Session1_R_S2_T1w                    1     2           0
# mv_SYNESTHEX_F_Session1_S2_T1w                    1     2           0
# mv_SYNESTHEX_I_Session1_S2_T1w                    1     2           0
# mv_SYNESTHEX_C_Session1_S2_T1w                    1     2           0
# mv_SYNESTHEX_Sujet11_Session2_S14_T1w             1     2           0
# mv_SYNESTHEX_Sujet12_Session2_S12_T1w             1     2           0
# mv_SYNESTHEX_Sujet13_Session2_S13_T1w             1     2           0
# mv_SYNESTHEX_Sujet14_Session2_S12_T1w             1     2           0
# mv_SYNESTHEX_H_Session1_S2_T1w                    0     1           0
# mv_SYNESTHEX_Sujet09_Session1_S2_T1w              0     1           0
# mv_SYNESTHEX_2-Session1_S2_T1w                    0     2           0
# mv_SYNESTHEX_Sujet16_Session1_S2_T1w              0     1           0
# mv_SYNESTHEX_U_Session1_S2_T1w                    0     2           0
# mv_SYNESTHEX_5-Session1_S2_T1w                    0     1           0
# mv_SYNESTHEX_Sujet17_session1_S2_T1w              0     2           0
# mv_SYNESTHEX_J_Session1_S2_T1w                    0     1           0
# mv_SYNESTHEX_O_S2_T1w                             0     2           0
# mv_SYNESTHEX_N_Session1_S2_T1w                    0     2           0
# mv_SYNESTHEX_V_Session1_S2_T1w                    0     2           0
# mv_SYNESTHEX_B_Session1_S2_T1w                    0     2           0
# mv_SYNESTHEX_6-Session1_S2_T1w                    0     2           0
# mv_SYNESTHEX_W_Session1_S2_T1w                    0     2           0
# mv_SYNESTHEX_1-Session1_S2_T1w                    0     2           0
# mv_SYNESTHEX_Q_Session1_S4_T1w                    0     2           0
# mv_SYNESTHEX_Sujet18_Session1_S4_T1w              0     1           0
# mv_SYNESTHEX_4-Session1_S2_T1w                    0     1           0
# mv_SYNESTHEX_8-Session1_S2_T1w                    0     2           0
# mv_SYNESTHEX_L_Session1_S2_T1w                    0     2           0
# mv_SYNESTHEX_E_Session1_S2_T1w                    0     2           0
# mv_SYNESTHEX_Sujet19_Session1_S3_T1w              0     2           1
# mv_SYNESTHEX_Sujet23_Session1_S3_T1w              0     1           1
# mv_SYNESTHEX_Sujet24_Session1_S2_T1w              0     2           1
# mv_SYNESTHEX_Sujet28_Session1_S2_T1w              0     1           1
# mv_SYNESTHEX_Sujet21_Session1_S2_T1w              0     1           1
# mv_SYNESTHEX_Sujet10_Session2_S14_T1w             0     2           0
# mv_SYNESTHEX_Sujet15_Session2_S13_T1w             0     2           0

# %%
participants.hist()
# Out:
# array([[<Axes: title={'center': 'isSynesthete'}>,
#         <Axes: title={'center': 'Sexe'}>],
#        [<Axes: title={'center': 'Latéralité'}>, <Axes: >]], dtype=object)

# %%
def is_it_a_file(sub_dir):
    if os.path.isdir(sub_dir):
        return False
    else:
        logging.debug(f"{sub_dir} is a file. Continue.")
        return True
    

def is_folder_a_model(sub_dir):
    if os.path.exists(sub_dir+'/.hydra/config.yaml'):
        return True
    else:
        logging.debug(f"\n{sub_dir} not associated to a model. Continue")
        return False

def get_model_paths(dir_path, result = None):
    """Recursively gets all models included in dir_path"""
    if result is None:  # create a new result if no intermediate was given
        result = [] 
    for name in os.listdir(dir_path):
        sub_dir = dir_path + '/' + name
        # checks if directory
        if is_it_a_file(sub_dir):
            pass
        elif not is_folder_a_model(sub_dir):
            result.extend(get_model_paths(sub_dir))
        else:
            result.append(sub_dir)
    return result

# %%
model_paths = get_model_paths(path_champollion)

# %%
model_paths[:5]
# Out:
# ['/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_left/11-43-38_2',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_left/14-00-57_116',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinter-SFsup_left/09-33-02_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/STi-STs-STpol_right/20-15-00_117',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FColl-SRh_right/09-45-57_1']

# %%
# df = pd.read_csv(f"{model_path}/{embeddings_subpath}", index_col=0)
# pca = PCA(n_components=1)
# df2 = pd.DataFrame(pca.fit_transform(df))
# df2.index = df.index
# df2

# %%
def compute(model_path, random_state):
    global embeddings
    global participants
    # Gets region name
    cfg = omegaconf.OmegaConf.load(model_path+'/.hydra/config.yaml')
    region = cfg['dataset'][next(iter(cfg['dataset']))]['crop_dir'].split('/')[-3]
    side = next(iter(cfg['dataset'])).split('_')[-1]
    region = region + '_' + side
    model_name = model_path.split('/')[-1]
    region_path = '/'.join(model_path.split('/')[-2:])
    print(f"Treating {region}: {region_path} : {model_path}")
    
    # Loads embeddings
    embeddings = pd.read_csv(f"{model_path}/{embeddings_subpath}", index_col=0)
    merged = participants[[label, "folds"]].merge(embeddings, left_index=True, right_index=True)
    ukb_emb = pd.read_csv(f"{model_path}/{ukb_embeddings_subpath}", index_col=0)
    
    # Set up possible values of parameters to optimize over
    # p_grid = {"C": [0.000001, 0.00001, 0.0001, 0.001, 0.01, 0.1, 1.0, 10.0]}
          
    # Classifies
    X = merged.drop([label, "folds"], axis=1)
    Y = merged[label]
    groups = merged["folds"]
    df2 = X.copy()

    # pca = PCA(n_components=3)
    # pca.fit(ukb_emb)
    # df2 = pd.DataFrame(pca.transform(X))
    # df2.index = X.index
    df2 = X.copy()
    scaler = StandardScaler()
    df2[df2.columns] = scaler.fit_transform(df2)
    model = LogisticRegression(max_iter=max_iter, class_weight='balanced', C=0.000001, random_state=random_state)
    logo = LeaveOneGroupOut()
    cv = logo.split(df2, Y, groups)
    # clf = GridSearchCV(estimator=model, param_grid=p_grid, cv=3)
    res = cross_val_score(model, df2, Y, cv=cv, scoring='roc_auc')
    
    # Gets result
    # roc_auc = roc_auc_score(Y, proba_pred[:,1])
    print(res)
    
    # Returns result
    return (region, res.mean(), res.std(), model_name, region_path, model_path)

# %%
def iterative_split_through_sorting_shuffle(df, n_splits, stratify_columns, random_state):
    """Custom iterative train test split which
    maintains balanced representation.
    """
    # Dataframe random row shuffle + sorting according to stratify_columns
    sorted = df.sample(frac=1, random_state=random_state).sort_values(stratify_columns)
    # for each fold, we take one row every n_splits rows
    folds = [sorted.iloc[i::n_splits, :] for i in range(n_splits)]
    # Further shuffling
    folds = [fold.sample(frac=1, random_state=random_state) for fold in folds]
    random.Random(random_state).shuffle(folds)
    return folds

# %%
def print_results(parent, folds, col, verbose=True):

    # For each conbination of labels, prints the number of rows for each fold
    # having this combination
    total_errors = 0
    n_splits = len(folds)
    if verbose:
        print("query   : #rows      : #rows per fold\n")

    for col0 in parent[col[0]].unique():
        for col1 in parent[col[1]].unique():
            for col2 in parent[col[2]].unique():
                df = parent.query(f"{col[0]}==@col0 and {col[1]}==@col1 and {col[2]}==@col2")
                len_query = len(df)
                print(f"{col0}, {col1}, {col2} : total = {len_query} : per fold =", end = ' ')
                for fold in folds:
                    df0 = fold.query(f"{col[0]}==@col0 and {col[1]}==@col1 and {col[2]}==@col2")
                    len_query_fold = len(df0)
                    if abs(len_query_fold-len_query/n_splits) >= 1:
                        total_errors += 1
                    print(f"{len_query_fold} -", end= ' ')
                print("")

    # Prints the statistics and the number of stratification errors
    expected_total_length = len(parent)
    total_length = 0
    total_mismatches = 0
    print("\nlengths of folds : ", end = ' ')
    for fold in folds:
        len_fold = len(fold)
        print(len_fold, end=' ')
        total_length += len_fold
        if abs(len_fold-expected_total_length/n_splits) >= 2:
            total_mismatches += 1
    print(f"\nExpected total_length = {expected_total_length}")
    print(f"Effective total_length = {total_length}")

    print(f"total number of stratification errors: {total_errors}")
    print(f"total number of mismatched fold sizes : {total_mismatches}")

# %%
participants.dtypes
# Out:
# isSynesthete    int64
# Sexe            int64
# Latéralité      int64
# dtype: object

# %%
result = []
for random_state in range(5):
    # Creates folds
    folds = iterative_split_through_sorting_shuffle(participants, cv, ["isSynesthete", "Sexe", "Latéralité"], random_state)

    # Creates folds column
    participants["folds"] = -1
    for i, fold in enumerate(folds):
        participants.loc[fold.index, "folds"] = i
    
    # Computes AUC
    for model_path in model_paths:
        result.append(compute(model_path, random_state))
# Out:
# Treating S.C.-sylv._left: SC-sylv_left/11-43-38_2 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_left/11-43-38_2
# [0.8        0.66666667 0.33333333 0.72       0.7       ]
# Treating S.C.-sylv._left: SC-sylv_left/14-00-57_116 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_left/14-00-57_116
# [0.6        0.63333333 0.4        0.72       0.83333333]
# Treating S.F.inter.-S.F.sup._left: SFinter-SFsup_left/09-33-02_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinter-SFsup_left/09-33-02_0
# [0.36666667 0.46666667 0.4        0.36       0.5       ]
# Treating S.T.i.-S.T.s.-S.T.pol._right: STi-STs-STpol_right/20-15-00_117 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STi-STs-STpol_right/20-15-00_117
# [0.43333333 0.56666667 0.8        0.56       0.83333333]
# Treating F.Coll.-S.Rh._right: FColl-SRh_right/09-45-57_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FColl-SRh_right/09-45-57_1
# [0.46666667 0.53333333 0.5        0.08       0.33333333]
# Treating S.T.s.-S.GSM._left: STs-SGSM_left/13-57-40_59 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STs-SGSM_left/13-57-40_59
# [0.43333333 0.7        0.56666667 0.32       0.7       ]
# Treating S.C.-sylv._right: SC-sylv_right/11-43-38_3 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_right/11-43-38_3
# [0.46666667 0.43333333 0.56666667 0.36       0.7       ]
# Treating S.C.-sylv._right: SC-sylv_right/13-19-08_28 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_right/13-19-08_28
# [0.5        0.46666667 0.5        0.44       0.63333333]
# Treating Lobule_parietal_sup._left: Lobule_parietal_sup_left/09-48-31_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/Lobule_parietal_sup_left/09-48-31_0
# [0.33333333 0.26666667 0.63333333 0.44       0.46666667]
# Treating S.F.int.-S.R._left: SFint-SR_left/09-00-43_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFint-SR_left/09-00-43_0
# [0.3        0.46666667 0.53333333 0.6        0.63333333]
# Treating S.Po.C._left: SPoC_left/22-10-40_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_left/22-10-40_0
# [0.7        0.4        0.43333333 0.48       0.43333333]
# Treating S.Po.C._left: SPoC_left/15-39-28_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_left/15-39-28_1
# [0.76666667 0.36666667 0.46666667 0.52       0.53333333]
# Treating S.Po.C._left: SPoC_left/10-18-59_2 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_left/10-18-59
1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFmarginal-SFinfant_right/17-49-19_1
# [0.4        0.36       0.56666667 0.53333333 0.43333333]
# Treating S.T.i.-S.O.T.lat._left: STi-SOTlat_left/09-36-46_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STi-SOTlat_left/09-36-46_0
# [0.26666667 0.64       0.36666667 0.63333333 0.5       ]
# Treating S.F.inter.-S.F.sup._right: SFinter-SFsup_right/09-33-02_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinter-SFsup_right/09-33-02_1
# [0.63333333 0.24       0.56666667 0.56666667 0.53333333]
# Treating S.T.s._left: STs_left/11-43-38_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STs_left/11-43-38_0
# [0.5        0.56       0.73333333 0.4        0.46666667]
# Treating F.C.M.post.-S.p.C._right: FCMpost-SpC_right/15-09-24_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FCMpost-SpC_right/15-09-24_1
# [0.5        0.68       0.36666667 0.36666667 0.6       ]
# Treating ORBITAL_right: ORBITAL_right/15-53-41_191 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_right/15-53-41_191
# [0.13333333 0.2        0.2        0.26666667 0.5       ]
# Treating S.C.-S.Po.C._left: SC-SPoC_left/16-46-17_3 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPoC_left/16-46-17_3
# [0.46666667 0.6        0.46666667 0.46666667 0.5       ]
# Treating S.C.-S.Po.C._left: SC-SPoC_left/16-46-17_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPoC_left/16-46-17_0
# [0.63333333 0.64       0.43333333 0.6        0.46666667]
# Treating S.C.-S.Po.C._left: SC-SPoC_left/14-55-36_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPoC_left/14-55-36_0
# [0.66666667 0.68       0.46666667 0.63333333 0.46666667]
# Treating S.C.-S.Po.C._left: SC-SPoC_left/16-46-17_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPoC_left/16-46-17_1
# [0.56666667 0.6        0.5        0.5        0.46666667]
# Treating S.C.-S.Po.C._left: SC-SPoC_left/16-46-17_2 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPoC_left/16-46-17_2
# [0.6        0.56       0.5        0.56666667 0.5       ]

# %%
folds[0].dtypes
# Out:
# isSynesthete    int64
# Sexe            int64
# Latéralité      int64
# folds           int64
# dtype: object

# %%
print_results(participants, folds, ["isSynesthete", "Sexe", "Latéralité"])
# Out:
# query   : #rows      : #rows per fold
#
# 1, 2, 0 : total = 18 : per fold = 3 - 4 - 4 - 3 - 4 -
# 1, 2, 1 : total = 2 : per fold = 1 - 0 - 0 - 1 - 0 -
# 1, 1, 0 : total = 3 : per fold = 1 - 1 - 1 - 0 - 0 -
# 1, 1, 1 : total = 3 : per fold = 1 - 0 - 0 - 1 - 1 -
# 0, 2, 0 : total = 16 : per fold = 3 - 3 - 4 - 3 - 3 -
# 0, 2, 1 : total = 2 : per fold = 0 - 0 - 0 - 1 - 1 -
# 0, 1, 0 : total = 7 : per fold = 1 - 1 - 2 - 1 - 2 -
# 0, 1, 1 : total = 3 : per fold = 1 - 1 - 0 - 1 - 0 -
#
# lengths of folds :  11 10 11 11 11
# Expected total_length = 54
# Effective total_length = 54
# total number of stratification errors: 0
# total number of mismatched fold sizes : 0

# %%
df = pd.DataFrame(result, columns=['region', 'roc_auc', 'roc_auc_std', 'model_name', 'region_path', 'model_path'])

# %%
df
# Out:
#                            region   roc_auc  roc_auc_std    model_name  \
# 0                 S.C.-sylv._left  0.644000     0.161416    11-43-38_2
# 1                 S.C.-sylv._left  0.637333     0.143518  14-00-57_116
# 2        S.F.inter.-S.F.sup._left  0.418667     0.055522    09-33-02_0
# 3    S.T.i.-S.T.s.-S.T.pol._right  0.638667     0.153270  20-15-00_117
# 4             F.Coll.-S.Rh._right  0.382667     0.165870    09-45-57_1
# ..                            ...       ...          ...           ...
# 485             S.C.-S.Po.C._left  0.500000     0.051640    16-46-17_3
# 486             S.C.-S.Po.C._left  0.554667     0.087168    16-46-17_0
# 487             S.C.-S.Po.C._left  0.582667     0.095926    14-55-36_0
# 488             S.C.-S.Po.C._left  0.526667     0.048990    16-46-17_1
# 489             S.C.-S.Po.C._left  0.545333     0.039418    16-46-17_2
#
#                           region_path  \
# 0             SC-sylv_left/11-43-38_2
# 1           SC-sylv_left/14-00-57_116
# 2       SFinter-SFsup_left/09-33-02_0
# 3    STi-STs-STpol_right/20-15-00_117
# 4          FColl-SRh_right/09-45-57_1
# ..                                ...
# 485           SC-SPoC_left/16-46-17_3
# 486           SC-SPoC_left/16-46-17_0
# 487           SC-SPoC_left/14-55-36_0
# 488           SC-SPoC_left/16-46-17_1
# 489           SC-SPoC_left/16-46-17_2
#
#                                             model_path
# 0    /neurospin/dico/data/deep_folding/current/mode...
# 1    /neurospin/dico/data/deep_folding/current/mode...
# 2    /neurospin/dico/data/deep_folding/current/mode...
# 3    /neurospin/dico/data/deep_folding/current/mode...
# 4    /neurospin/dico/data/deep_folding/current/mode...
# ..                                                 ...
# 485  /neurospin/dico/data/deep_folding/current/mode...
# 486  /neurospin/dico/data/deep_folding/current/mode...
# 487  /neurospin/dico/data/deep_folding/current/mode...
# 488  /neurospin/dico/data/deep_folding/current/mode...
# 489  /neurospin/dico/data/deep_folding/current/mode...
#
# [490 rows x 6 columns]

# %%
df['side'] = df['region'].str.split('_').str[-1]

# %%
df
# Out:
#                            region   roc_auc  roc_auc_std    model_name  \
# 0                 S.C.-sylv._left  0.644000     0.161416    11-43-38_2
# 1                 S.C.-sylv._left  0.637333     0.143518  14-00-57_116
# 2        S.F.inter.-S.F.sup._left  0.418667     0.055522    09-33-02_0
# 3    S.T.i.-S.T.s.-S.T.pol._right  0.638667     0.153270  20-15-00_117
# 4             F.Coll.-S.Rh._right  0.382667     0.165870    09-45-57_1
# ..                            ...       ...          ...           ...
# 485             S.C.-S.Po.C._left  0.500000     0.051640    16-46-17_3
# 486             S.C.-S.Po.C._left  0.554667     0.087168    16-46-17_0
# 487             S.C.-S.Po.C._left  0.582667     0.095926    14-55-36_0
# 488             S.C.-S.Po.C._left  0.526667     0.048990    16-46-17_1
# 489             S.C.-S.Po.C._left  0.545333     0.039418    16-46-17_2
#
#                           region_path  \
# 0             SC-sylv_left/11-43-38_2
# 1           SC-sylv_left/14-00-57_116
# 2       SFinter-SFsup_left/09-33-02_0
# 3    STi-STs-STpol_right/20-15-00_117
# 4          FColl-SRh_right/09-45-57_1
# ..                                ...
# 485           SC-SPoC_left/16-46-17_3
# 486           SC-SPoC_left/16-46-17_0
# 487           SC-SPoC_left/14-55-36_0
# 488           SC-SPoC_left/16-46-17_1
# 489           SC-SPoC_left/16-46-17_2
#
#                                             model_path   side
# 0    /neurospin/dico/data/deep_folding/current/mode...   left
# 1    /neurospin/dico/data/deep_folding/current/mode...   left
# 2    /neurospin/dico/data/deep_folding/current/mode...   left
# 3    /neurospin/dico/data/deep_folding/current/mode...  right
# 4    /neurospin/dico/data/deep_folding/current/mode...  right
# ..                                                 ...    ...
# 485  /neurospin/dico/data/deep_folding/current/mode...   left
# 486  /neurospin/dico/data/deep_folding/current/mode...   left
# 487  /neurospin/dico/data/deep_folding/current/mode...   left
# 488  /neurospin/dico/data/deep_folding/current/mode...   left
# 489  /neurospin/dico/data/deep_folding/current/mode...   left
#
# [490 rows x 7 columns]

# %%
def plot_horizontal(res, region_name, ax, AUC_name, std_auc_name, AUC2_name, std_auc2_name, visible, title):
    labelsize=10
    ax.xaxis.set_tick_params(labelsize = labelsize)
    ax.yaxis.set_tick_params(labelsize = labelsize)
    
    res = res.sort_values(by=AUC_name, ascending=True)

    # ax.errorbar(res[AUC_name], res[region_name], res[std_auc_name], fmt='s', color='black')
    # ax.scatter(res[AUC_name], res[region_name], marker='s', color='black')
    ax.axvline(x=0.5, color='black', linestyle='-')
    ax.barh(res[region_name], res[AUC2_name], fill=True, color='lightgray')
    ax.errorbar(res[AUC_name], res[region_name], xerr=0, fmt='s', color='black')
    # if visible:
    #     ax.set_ylabel("AUC ensemble")
    # else:
    #     ax.get_yaxis().set_ticks([])
    ax.set_xlim((0.3, 1.0))
    ax.set_title(title)

# %%
def plot_horizontal2(res, region_name, ax, AUC_name, std_auc_name, AUC2_name, std_auc2_name, visible, title):
    labelsize=10
    ax.xaxis.set_tick_params(labelsize = labelsize)
    ax.yaxis.set_tick_params(labelsize = labelsize)
    
    res = res.sort_values(by=AUC_name, ascending=True)

    # ax.errorbar(res[AUC_name], res[region_name], res[std_auc_name], fmt='s', color='black')
    # ax.scatter(res[AUC_name], res[region_name], marker='s', color='black')
    ax.axvline(x=0.5, color='black', linestyle='-')
    ax.barh(res[region_name], res[AUC2_name], fill=True, color='lightgray')
    ax.errorbar(res[AUC_name], res[region_name], xerr=res[std_auc_name], fmt='s', color='black')
    # if visible:
    #     ax.set_ylabel("AUC ensemble")
    # else:
    #     ax.get_yaxis().set_ticks([])
    ax.set_xlim((0.3, 1.0))
    ax.set_title(title)

# %%
plt.rc('axes', labelsize=12) 
f, ax = plt.subplots(1, 1, figsize=(10, 6))
plot_horizontal(df[df.side=='left'], "region", ax, "roc_auc", "roc_auc_std", "roc_auc", "roc_auc_std", True, "All regions")
plt.show()

# %%
plt.rc('axes', labelsize=12) 
f, ax = plt.subplots(1, 1, figsize=(10, 6))
plot_horizontal(df[df.side=='right'], "region", ax, "roc_auc", "roc_auc_std", "roc_auc", "roc_auc_std", True, "All regions")
plt.show()

# %%
ensemble = df[["region", "roc_auc"]].groupby("region").mean()
ensemble["std_auc"] = df[["region", "roc_auc"]].groupby("region").std()
ensemble = ensemble.reset_index()
ensemble['side'] = ensemble['region'].str.split('_').str[-1]
ensemble = ensemble.fillna(0)

# %%
ensemble.head()
# Out:
#                                   region   roc_auc   std_auc   side
# 0                         CINGULATE_left  0.467333  0.095807   left
# 1                        CINGULATE_right  0.537333  0.057022  right
# 2                   F.C.L.p.-S.GSM._left  0.550133  0.066115   left
# 3                  F.C.L.p.-S.GSM._right  0.209867  0.104242  right
# 4  F.C.L.p.-subsc.-F.C.L.a.-INSULA._left  0.605600  0.047257   left

# %%
plt.rc('axes', labelsize=12) 
f, ax = plt.subplots(1, 1, figsize=(10, 6))
plot_horizontal2(ensemble[ensemble.side=='left'], "region", ax, "roc_auc", "std_auc", "roc_auc", "std_auc", True, "All regions")
plt.show()

# %%
plt.rc('axes', labelsize=12) 
f, ax = plt.subplots(1, 1, figsize=(10, 6))
plot_horizontal2(ensemble[ensemble.side=='right'], "region", ax, "roc_auc", "std_auc", "roc_auc", "std_auc", True, "All regions")
plt.show()

# %%
# df.to_csv(output_filename)
