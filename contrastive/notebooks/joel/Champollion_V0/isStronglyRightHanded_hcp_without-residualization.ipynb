# %%
import glob
import os
import omegaconf

import pandas as pd
import numpy as np
import random

import logging

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import LeaveOneGroupOut

import matplotlib.pyplot as plt
import seaborn as sns


logging.basicConfig()
logging.getLogger().setLevel(logging.INFO)

# %%
path_champollion = "/neurospin/dico/data/deep_folding/current/models/Champollion_V0"
participants_file = "/neurospin/dico/data/deep_folding/current/datasets/hcp/Handedness/handedness_labels.csv"
embeddings_subpath = "hcp_random_embeddings/full_embeddings.csv"
output_filename = f"{path_champollion}/summary/isRightHanded_hcp_without_residualization.csv"
label = "isRightHanded"
max_iter = 2000
cv = 3

# %%
participants = pd.read_csv(participants_file, index_col=0)

# %%
participants
# Out:
#          Handedness Gender  isRightHanded  isStronglyRightHanded
# Subject
# 100004           95      M              1                    1.0
# 100206           65      M              1                    NaN
# 100307           95      F              1                    1.0
# 100408           55      M              1                    NaN
# 100610           85      M              1                    1.0
# ...             ...    ...            ...                    ...
# 992774          100      M              1                    1.0
# 993675           85      F              1                    1.0
# 994273           60      M              1                    NaN
# 995174          100      M              1                    1.0
# 996782          100      F              1                    1.0
#
# [1206 rows x 4 columns]

# %%
participants = participants[["isRightHanded"]]

# %%
participants = participants[[label]].dropna()

# %%
participants.hist()
# Out:
# array([[<Axes: title={'center': 'isRightHanded'}>]], dtype=object)

# %%
def is_it_a_file(sub_dir):
    if os.path.isdir(sub_dir):
        return False
    else:
        logging.debug(f"{sub_dir} is a file. Continue.")
        return True
    

def is_folder_a_model(sub_dir):
    if os.path.exists(sub_dir+'/.hydra/config.yaml'):
        return True
    else:
        logging.debug(f"\n{sub_dir} not associated to a model. Continue")
        return False

def get_model_paths(dir_path, result = None):
    """Recursively gets all models included in dir_path"""
    if result is None:  # create a new result if no intermediate was given
        result = [] 
    for name in os.listdir(dir_path):
        sub_dir = dir_path + '/' + name
        # checks if directory
        if is_it_a_file(sub_dir):
            pass
        elif not is_folder_a_model(sub_dir):
            result.extend(get_model_paths(sub_dir))
        else:
            result.append(sub_dir)
    return result

# %%
model_paths = get_model_paths(path_champollion)

# %%
model_paths[:5]
# Out:
# ['/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_left/11-43-38_2',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_left/14-00-57_116',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinter-SFsup_left/09-33-02_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/STi-STs-STpol_right/20-15-00_117',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FColl-SRh_right/09-45-57_1']

# %%
def compute(model_path):
    global embeddings
    global participants
    # Gets region name
    cfg = omegaconf.OmegaConf.load(model_path+'/.hydra/config.yaml')
    region = cfg['dataset'][next(iter(cfg['dataset']))]['crop_dir'].split('/')[-3]
    side = next(iter(cfg['dataset'])).split('_')[-1]
    region = region + '_' + side
    model_name = model_path.split('/')[-1]
    region_path = '/'.join(model_path.split('/')[-2:])
    print(f"Treating {region}: {region_path} : {model_path}")
    
    # Loads embeddings
    embeddings = pd.read_csv(f"{model_path}/{embeddings_subpath}", index_col=0)
    merged = participants[[label, "folds"]].merge(embeddings, left_index=True, right_index=True)
    
    # Classifies
    X = merged.drop([label, "folds"], axis=1)
    Y = merged[label]
    groups = merged["folds"]
    scaler = StandardScaler()
    X[X.columns] = scaler.fit_transform(X)
    model = LogisticRegression(max_iter=max_iter, random_state=1, class_weight='balanced')
    logo = LeaveOneGroupOut()
    cv = logo.split(X, Y, groups)
    res = cross_val_score(model, X, Y, cv=cv, scoring='roc_auc')
    
    # Gets result
    # roc_auc = roc_auc_score(Y, proba_pred[:,1])
    print(res)
    
    # Returns result
    return (region, res.mean(), res.std(), model_name, region_path, model_path)

# %%
def iterative_split_through_sorting_shuffle(df, n_splits, stratify_columns, random_state):
    """Custom iterative train test split which
    maintains balanced representation.
    """
    # Dataframe random row shuffle + sorting according to stratify_columns
    sorted = df.sample(frac=1, random_state=random_state).sort_values(stratify_columns)
    # for each fold, we take one row every n_splits rows
    folds = [sorted.iloc[i::n_splits, :] for i in range(n_splits)]
    # Further shuffling
    folds = [fold.sample(frac=1, random_state=random_state) for fold in folds]
    random.Random(random_state).shuffle(folds)
    return folds

# %%
def print_results(parent, folds, col, verbose=True):

    # For each conbination of labels, prints the number of rows for each fold
    # having this combination
    total_errors = 0
    n_splits = len(folds)
    if verbose:
        print("query   : #rows      : #rows per fold\n")

    for col0 in parent[col[0]].unique():
        df = parent.query(f"{col[0]}==@col0")
        len_query = len(df)
        if verbose:
            print(f"{col0}: total = {len_query} : per fold =", end = ' ')
        for fold in folds:
            df0 = fold.query(f"{col[0]}==@col0")
            len_query_fold = len(df0)
            if abs(len_query_fold-len_query/n_splits) >= 2:
                total_errors += 1
            if verbose:
                print(f"{len_query_fold} -", end= ' ')
        if verbose:
            print("")

    # Prints the statistics and the number of stratification errors
    expected_total_length = len(parent)
    total_length = 0
    total_mismatches = 0
    print("\nlengths of folds : ", end = ' ')
    for fold in folds:
        len_fold = len(fold)
        print(len_fold, end=' ')
        total_length += len_fold
        if abs(len_fold-expected_total_length/n_splits) >= 2:
            total_mismatches += 1
    print(f"\nExpected total_length = {expected_total_length}")
    print(f"Effective total_length = {total_length}")

    print(f"total number of stratification errors: {total_errors}")
    print(f"total number of mismatched fold sizes : {total_mismatches}")

# %%
participants.dtypes
# Out:
# isRightHanded    int64
# dtype: object

# %%
folds = iterative_split_through_sorting_shuffle(participants, cv, ["isRightHanded"], 1)

# %%
folds[0].dtypes
# Out:
# isRightHanded    int64
# folds            int64
# dtype: object

# %%
print_results(participants, folds, ["isRightHanded"])
# Out:
# query   : #rows      : #rows per fold
#
# 1: total = 1093 : per fold = 364 - 365 - 364 -
# 0: total = 113 : per fold = 38 - 37 - 38 -
#
# lengths of folds :  402 402 402
# Expected total_length = 1206
# Effective total_length = 1206
# total number of stratification errors: 0
# total number of mismatched fold sizes : 0

# %%
participants["folds"] = -1
for i, fold in enumerate(folds):
    participants.loc[fold.index, "folds"] = i

# %%
result = []
for model_path in model_paths:
    result.append(compute(model_path))
# Out:
# Treating S.C.-sylv._left: SC-sylv_left/11-43-38_2 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_left/11-43-38_2
# [0.41328165 0.42294946 0.46915137]
# Treating S.C.-sylv._left: SC-sylv_left/14-00-57_116 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_left/14-00-57_116
# [0.45398618 0.47216239 0.56347018]
# Treating S.F.inter.-S.F.sup._left: SFinter-SFsup_left/09-33-02_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinter-SFsup_left/09-33-02_0
# [0.45693578 0.47315659 0.49570562]
# Treating S.T.i.-S.T.s.-S.T.pol._right: STi-STs-STpol_right/20-15-00_117 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STi-STs-STpol_right/20-15-00_117
# [0.45878982 0.51839271 0.48254669]
# Treating F.Coll.-S.Rh._right: FColl-SRh_right/09-45-57_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FColl-SRh_right/09-45-57_1
# [0.56767234 0.61425021 0.5866362 ]
# Treating S.C.-sylv._right: SC-sylv_right/11-43-38_3 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_right/11-43-38_3
# [0.52334401 0.55625518 0.57773225]
# Treating S.C.-sylv._right: SC-sylv_right/13-19-08_28 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_right/13-19-08_28
# [0.54567672 0.55600663 0.62390671]
# Treating Lobule_parietal_sup._left: Lobule_parietal_sup_left/09-48-31_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/Lobule_parietal_sup_left/09-48-31_0
# [0.51061857 0.45451533 0.492081  ]
# Treating S.F.int.-S.R._left: SFint-SR_left/09-00-43_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFint-SR_left/09-00-43_0
# [0.63753582 0.5019884  0.54834134]
# Treating S.Po.C._left: SPoC_left/18-08-26_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_left/18-08-26_0
# [0.44918254 0.51391881 0.57071941]
# Treating S.F.inf.-BROCA-S.Pe.C.inf._right: SFinf-BROCA-SPeCinf_right/12-25-50_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinf-BROCA-SPeCinf_right/12-25-50_1
# [0.4924153  0.48285004 0.48766843]
# Treating S.s.P.-S.Pa.int._left: SsP-SPaint_left/10-06-38_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SsP-SPaint_left/10-06-38_0
# [0.55823361 0.53562552 0.50429438]
# Treating S.Or.-S.Olf._left: SOr-SOlf_left/18-00-16_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SOr-SOlf_left/18-00-16_0
# [0.5388505  0.54357912 0.52099913]
# Treating S.F.inf.-BROCA-S.Pe.C.inf._left: SFinf-BROCA-SPeCinf_left/12-25-50_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinf-BROCA-SPeCinf_left/12-25-50_0
# [0.42499579 0.51971831 0.50949492]
# Treating S.F.median-S.F.pol.tr.-S.F.sup._right: SFmedian-SFpoltr-SFsup_right/18-09-26_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFmedian-SFpoltr-SFsup_right/18-09-26_1
# [0.53151862 0.44647887 0.4704121 ]
# Treating F.Coll.-S.Rh._left: FColl-SRh_left/09-45-57_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FColl-SRh_left/09-45-57_0
# [0.53370976 0.47804474 0.62390671]
# Treating S.T.i.-S.T.s.-S.T.pol._left: STi-STs-STpol_left/14-30-34_34 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STi-STs-STpol_left/14-30-34_34
# [0.58638126 0.61317316 0.5393586 ]
# Treating S.F.int.-F.C.M.ant._left: SFint-FCMant_left/19-52-24_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFint-FCMant_left/19-52-24_0
# [0.53758638 0.46909693 0.51635017]
# Treating F.C.L.p.-subsc.-F.C.L.a.-INSULA._right: FCLp-subsc-FCLa-INSULA_right/19-49-20_193 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FCLp-subsc-FCLa-INSULA_right/19-49-20_193
# [0.49072982 0.52974316 0.45788354]
# Treating OCCIPITAL_right: OCCIPITAL_right/18-05-00_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/OCCIPITAL_right/18-05-00_1
# [0.45651441 0.44407622 0.40800567]
# Treating S.C.-S.Pe.C._right: SC-SPeC_right/09-49-03_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPeC_right/09-49-03_1
# [0.50387662 0.57887324 0.51548341]
# Treating S.Or.-S.Olf._right: SOr-SOlf_right/18-00-16_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SOr-SOlf_right/18-00-16_1
# [0.46165515 0.46628003 0.58033252]
# Treating CINGULATE_left: 2024-07-15/17-13-32_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/CINGULATE_left/2024-07-15/17-13-32_0
# [0.53295129 0.41855841 0.57300449]
# Treating CINGULATE_left: 2024-07-15/17-13-32_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/CINGULATE_left/2024-07-15/17-13-32_1
# [0.5589078  0.45302403 0.55614215]
# Treating CINGULATE_left: 2024-07-16/16-58-04_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/CINGULATE_left/2024-07-16/16-58-04_1
# [0.54980617 0.45567523 0.60641399]
# Treating CINGULATE_left: 2024-07-16/16-58-04_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/CINGULATE_left/2024-07-16/16-58-04_0
# [0.52309118 0.47290804 0.55740288]
# Treating S.F.int.-S.R._right: SFint-SR_right/09-00-43_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFint-SR_right/09-00-43_1
# [0.40957357 0.47812759 0.51887164]
# Treating CINGULATE_right: CINGULATE_right/09-52-22_75 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/CINGULATE_right/09-52-22_75
# [0.45887409 0.51665286 0.51233157]
# Treating fronto-parietal_medial_face._left: fronto-parietal_medial_face_left/13-07-50_190 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/fronto-parietal_medial_face_left/13-07-50_190
# [0.58157762 0.5038111  0.51524703]
# Treating fronto-parietal_medial_face._left: fronto-parietal_medial_face_left/10-37-44_89 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/fronto-parietal_medial_face_left/10-37-44_89
# [0.57053767 0.5051367  0.50303365]
# Treating Sc.Cal.-S.Li._left: ScCal-SLi_left/09-28-12_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/ScCal-SLi_left/09-28-12_0
# [0.58646553 0.53935377 0.58553305]
# Treating F.P.O.-S.Cu.-Sc.Cal._right: FPO-SCu-ScCal_right/20-03-37_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FPO-SCu-ScCal_right/20-03-37_1
# [0.60947244 0.56984258 0.50610669]
# Treating F.P.O.-S.Cu.-Sc.Cal._left: FPO-SCu-ScCal_left/20-03-37_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FPO-SCu-ScCal_left/20-03-37_0
# [0.52915894 0.46089478 0.53920101]
# Treating OCCIPITAL_left: OCCIPITAL_left/18-05-00_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/OCCIPITAL_left/18-05-00_0
# [0.48997135 0.51375311 0.42486802]
# Treating S.C.-S.Pe.C._left: SC-SPeC_left/09-49-03_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPeC_left/09-49-03_0
# [0.46772291 0.55244408 0.52446616]
# Treating S.T.s._right: STs_right/11-43-38_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STs_right/11-43-38_1
# [0.43283331 0.50654515 0.52107793]
# Treating F.I.P._left: FIP_left/14-56-46_3 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_left/14-56-46_3
# [0.54946907 0.50853355 0.47009692]
# Treating F.I.P._left: FIP_left/14-56-46_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_left/14-56-46_1
# [0.57694252 0.51557581 0.50445197]
# Treating F.I.P._left: FIP_left/14-56-46_2 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_left/14-56-46_2
# [0.52705208 0.48508699 0.43392956]
# Treating F.I.P._left: FIP_left/14-56-46_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_left/14-56-46_0
# [0.46738581 0.49726595 0.5000394 ]
# Treating F.I.P._left: FIP_left/14-56-46_4 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_left/14-56-46_4
# [0.56480701 0.53736537 0.53470964]
# Treating S.T.s.br._right: STsbr_right/17-47-57_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STsbr_right/17-47-57_1
# [0.47488623 0.56048053 0.52036877]
# Treating S.C.-S.Po.C._right: SC-SPoC_right/14-55-36_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPoC_right/14-55-36_1
# [0.53295129 0.51135046 0.57001024]
# Treating fronto-parietal_medial_face._right: fronto-parietal_medial_face_right/13-49-53_215 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/fronto-parietal_medial_face_right/13-49-53_215
# [0.54154728 0.53479702 0.51469545]
# Treating S.Pe.C._left: SPeC_left/12-36-31_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPeC_left/12-36-31_0
# [0.45466037 0.44672742 0.5432984 ]
# Treating S.Po.C._right: SPoC_right/18-08-26_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPoC_right/18-08-26_1
# [0.53893477 0.52692626 0.53762509]
# Treating S.T.i.-S.O.T.lat._right: STi-SOTlat_right/09-36-46_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STi-SOTlat_right/09-36-46_1
# [0.52165852 0.51772991 0.47537625]
# Treating F.C.M.post.-S.p.C._left: FCMpost-SpC_left/15-09-24_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FCMpost-SpC_left/15-09-24_0
# [0.55899208 0.45741508 0.47167284]
# Treating S.F.int.-F.C.M.ant._right: SFint-FCMant_right/19-52-24_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFint-FCMant_right/19-52-24_1
# [0.38252149 0.53827672 0.53045465]
# Treating S.F.median-S.F.pol.tr.-S.F.sup._left: SFmedian-SFpoltr-SFsup_left/18-09-26_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFmedian-SFpoltr-SFsup_left/18-09-26_0
# [0.41614697 0.50323115 0.47427311]
# Treating S.Pe.C._right: SPeC_right/12-36-31_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SPeC_right/12-36-31_1
# [0.5763526  0.54208782 0.4842014 ]
# Treating S.F.marginal-S.F.inf.ant._left: SFmarginal-SFinfant_left/17-49-19_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFmarginal-SFinfant_left/17-49-19_0
# [0.42356312 0.42054681 0.48451659]
# Treating F.I.P._right: FIP_right/14-24-09_213_joel : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_right/14-24-09_213_joel
# [0.55166021 0.45227838 0.60649279]
# Treating F.I.P._right: FIP_right/20-16-33_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_right/20-16-33_1
# [0.56168886 0.51748136 0.63864156]
# Treating F.I.P._right: FIP_right/20-16-33_2 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_right/20-16-33_2
# [0.53918759 0.52576636 0.61602711]
# Treating F.I.P._right: FIP_right/20-16-33_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_right/20-16-33_0
# [0.55107028 0.51996686 0.59940115]
# Treating F.I.P._right: FIP_right/20-16-33_4 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_right/20-16-33_4
# [0.58140907 0.52352941 0.59467339]
# Treating F.I.P._right: FIP_right/20-16-33_3 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FIP_right/20-16-33_3
# [0.56303725 0.54473902 0.57465921]
# Treating F.C.L.p.-subsc.-F.C.L.a.-INSULA._left: FCLp-subsc-FCLa-INSULA_left/18-59-14_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FCLp-subsc-FCLa-INSULA_left/18-59-14_0
# [0.52545087 0.54656172 0.53723111]
# Treating S.T.s.br._left: STsbr_left/17-47-57_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STsbr_left/17-47-57_0
# [0.56362717 0.57448219 0.52076275]
# Treating S.s.P.-S.Pa.int._right: SsP-SPaint_right/10-06-38_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SsP-SPaint_right/10-06-38_1
# [0.54399124 0.52957746 0.4408636 ]
# Treating Sc.Cal.-S.Li._right: ScCal-SLi_right/09-28-12_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/ScCal-SLi_right/09-28-12_1
# [0.61402326 0.4971831  0.49862107]
# Treating Lobule_parietal_sup._right: Lobule_parietal_sup_right/09-48-31_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/Lobule_parietal_sup_right/09-48-31_1
# [0.58949941 0.51541011 0.59853439]
# Treating ORBITAL_left: ORBITAL_left/20-56-02_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_left/20-56-02_1
# [0.5740772  0.4928749  0.49554803]
# Treating ORBITAL_left: ORBITAL_left/11-50-30_16 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_left/11-50-30_16
# [0.52932749 0.53960232 0.53841305]
# Treating ORBITAL_left: ORBITAL_left/20-56-02_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_left/20-56-02_0
# [0.52351256 0.48947804 0.51288315]
# Treating ORBITAL_left: ORBITAL_left/20-56-02_2 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_left/20-56-02_2
# [0.54205292 0.46172328 0.49121425]
# Treating ORBITAL_left: ORBITAL_left/16-19-26_238 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_left/16-19-26_238
# [0.52646216 0.47033969 0.45205264]
# Treating ORBITAL_left: ORBITAL_left/20-56-02_3 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_left/20-56-02_3
# [0.54946907 0.49759735 0.52856355]
# Treating S.F.marginal-S.F.inf.ant._right: SFmarginal-SFinfant_right/17-49-19_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFmarginal-SFinfant_right/17-49-19_1
# [0.47623462 0.46445733 0.50279726]
# Treating S.T.i.-S.O.T.lat._left: STi-SOTlat_left/09-36-46_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STi-SOTlat_left/09-36-46_0
# [0.61891117 0.56951118 0.55472382]
# Treating S.F.inter.-S.F.sup._right: SFinter-SFsup_right/09-33-02_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinter-SFsup_right/09-33-02_1
# [0.49418507 0.46454018 0.48270428]
# Treating S.T.s._left: STs_left/11-43-38_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/STs_left/11-43-38_0
# [0.5378392  0.56271748 0.48790481]
# Treating F.C.M.post.-S.p.C._right: FCMpost-SpC_right/15-09-24_1 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/FCMpost-SpC_right/15-09-24_1
# [0.50935446 0.56197183 0.59349145]
# Treating ORBITAL_right: ORBITAL_right/15-53-41_191 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/ORBITAL_right/15-53-41_191
# [0.4614866  0.47125104 0.56252462]
# Treating S.C.-S.Po.C._left: SC-SPoC_left/14-55-36_0 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-SPoC_left/14-55-36_0
# [0.47067251 0.48624689 0.5551178 ]

# %%
df = pd.DataFrame(result, columns=['region', 'roc_auc', 'roc_auc_std', 'model_name', 'region_path', 'model_path'])

# %%
df
# Out:
#                           region   roc_auc  roc_auc_std    model_name  \
# 0                S.C.-sylv._left  0.435127     0.024380    11-43-38_2
# 1                S.C.-sylv._left  0.496540     0.047905  14-00-57_116
# 2       S.F.inter.-S.F.sup._left  0.475266     0.015898    09-33-02_0
# 3   S.T.i.-S.T.s.-S.T.pol._right  0.486576     0.024499  20-15-00_117
# 4            F.Coll.-S.Rh._right  0.589520     0.019124    09-45-57_1
# ..                           ...       ...          ...           ...
# 71     S.F.inter.-S.F.sup._right  0.480477     0.012205    09-33-02_1
# 72                   S.T.s._left  0.529487     0.031108    11-43-38_0
# 73      F.C.M.post.-S.p.C._right  0.554939     0.034707    15-09-24_1
# 74                 ORBITAL_right  0.498421     0.045503  15-53-41_191
# 75             S.C.-S.Po.C._left  0.504012     0.036692    14-55-36_0
#
#                          region_path  \
# 0            SC-sylv_left/11-43-38_2
# 1          SC-sylv_left/14-00-57_116
# 2      SFinter-SFsup_left/09-33-02_0
# 3   STi-STs-STpol_right/20-15-00_117
# 4         FColl-SRh_right/09-45-57_1
# ..                               ...
# 71    SFinter-SFsup_right/09-33-02_1
# 72               STs_left/11-43-38_0
# 73      FCMpost-SpC_right/15-09-24_1
# 74        ORBITAL_right/15-53-41_191
# 75           SC-SPoC_left/14-55-36_0
#
#                                            model_path
# 0   /neurospin/dico/data/deep_folding/current/mode...
# 1   /neurospin/dico/data/deep_folding/current/mode...
# 2   /neurospin/dico/data/deep_folding/current/mode...
# 3   /neurospin/dico/data/deep_folding/current/mode...
# 4   /neurospin/dico/data/deep_folding/current/mode...
# ..                                                ...
# 71  /neurospin/dico/data/deep_folding/current/mode...
# 72  /neurospin/dico/data/deep_folding/current/mode...
# 73  /neurospin/dico/data/deep_folding/current/mode...
# 74  /neurospin/dico/data/deep_folding/current/mode...
# 75  /neurospin/dico/data/deep_folding/current/mode...
#
# [76 rows x 6 columns]

# %%
df['side'] = df['region'].str.split('_').str[-1]

# %%
df
# Out:
#                           region   roc_auc  roc_auc_std    model_name  \
# 0                S.C.-sylv._left  0.435127     0.024380    11-43-38_2
# 1                S.C.-sylv._left  0.496540     0.047905  14-00-57_116
# 2       S.F.inter.-S.F.sup._left  0.475266     0.015898    09-33-02_0
# 3   S.T.i.-S.T.s.-S.T.pol._right  0.486576     0.024499  20-15-00_117
# 4            F.Coll.-S.Rh._right  0.589520     0.019124    09-45-57_1
# ..                           ...       ...          ...           ...
# 71     S.F.inter.-S.F.sup._right  0.480477     0.012205    09-33-02_1
# 72                   S.T.s._left  0.529487     0.031108    11-43-38_0
# 73      F.C.M.post.-S.p.C._right  0.554939     0.034707    15-09-24_1
# 74                 ORBITAL_right  0.498421     0.045503  15-53-41_191
# 75             S.C.-S.Po.C._left  0.504012     0.036692    14-55-36_0
#
#                          region_path  \
# 0            SC-sylv_left/11-43-38_2
# 1          SC-sylv_left/14-00-57_116
# 2      SFinter-SFsup_left/09-33-02_0
# 3   STi-STs-STpol_right/20-15-00_117
# 4         FColl-SRh_right/09-45-57_1
# ..                               ...
# 71    SFinter-SFsup_right/09-33-02_1
# 72               STs_left/11-43-38_0
# 73      FCMpost-SpC_right/15-09-24_1
# 74        ORBITAL_right/15-53-41_191
# 75           SC-SPoC_left/14-55-36_0
#
#                                            model_path   side
# 0   /neurospin/dico/data/deep_folding/current/mode...   left
# 1   /neurospin/dico/data/deep_folding/current/mode...   left
# 2   /neurospin/dico/data/deep_folding/current/mode...   left
# 3   /neurospin/dico/data/deep_folding/current/mode...  right
# 4   /neurospin/dico/data/deep_folding/current/mode...  right
# ..                                                ...    ...
# 71  /neurospin/dico/data/deep_folding/current/mode...  right
# 72  /neurospin/dico/data/deep_folding/current/mode...   left
# 73  /neurospin/dico/data/deep_folding/current/mode...  right
# 74  /neurospin/dico/data/deep_folding/current/mode...  right
# 75  /neurospin/dico/data/deep_folding/current/mode...   left
#
# [76 rows x 7 columns]

# %%
def plot_horizontal(res, region_name, ax, AUC_name, std_auc_name, AUC2_name, std_auc2_name, visible, title):
    labelsize=10
    ax.xaxis.set_tick_params(labelsize = labelsize)
    ax.yaxis.set_tick_params(labelsize = labelsize)
    
    res = res.sort_values(by=AUC_name, ascending=True)

    # ax.errorbar(res[AUC_name], res[region_name], res[std_auc_name], fmt='s', color='black')
    # ax.scatter(res[AUC_name], res[region_name], marker='s', color='black')
    ax.axvline(x=0.5, color='black', linestyle='-')
    ax.barh(res[region_name], res[AUC2_name], fill=True, color='lightgray')
    ax.errorbar(res[AUC_name], res[region_name], xerr=res[std_auc_name], fmt='s', color='black')
    # if visible:
    #     ax.set_ylabel("AUC ensemble")
    # else:
    #     ax.get_yaxis().set_ticks([])
    ax.set_xlim((0.45, 1.0))
    ax.set_title(title)

# %%
plt.rc('axes', labelsize=12) 
f, ax = plt.subplots(1, 1, figsize=(10, 6))
plot_horizontal(df[df.side=='left'], "region", ax, "roc_auc", "roc_auc_std", "roc_auc", "roc_auc_std", True, "All regions")
plt.show()

# %%
plt.rc('axes', labelsize=12) 
f, ax = plt.subplots(1, 1, figsize=(10, 6))
plot_horizontal(df[df.side=='right'], "region", ax, "roc_auc", "roc_auc_std", "roc_auc", "roc_auc_std", True, "All regions")
plt.show()

# %%
df
# Out:
#                           region   roc_auc  roc_auc_std    model_name  \
# 0                S.C.-sylv._left  0.490319     0.030127    11-43-38_2
# 1                S.C.-sylv._left  0.540576     0.066662  14-00-57_116
# 2       S.F.inter.-S.F.sup._left  0.524380     0.090232    09-33-02_0
# 3   S.T.i.-S.T.s.-S.T.pol._right  0.474862     0.051557  20-15-00_117
# 4            F.Coll.-S.Rh._right  0.560782     0.069611    09-45-57_1
# ..                           ...       ...          ...           ...
# 71     S.F.inter.-S.F.sup._right  0.458966     0.034568    09-33-02_1
# 72                   S.T.s._left  0.517555     0.049674    11-43-38_0
# 73      F.C.M.post.-S.p.C._right  0.533545     0.050757    15-09-24_1
# 74                 ORBITAL_right  0.520374     0.085876  15-53-41_191
# 75             S.C.-S.Po.C._left  0.517233     0.046865    14-55-36_0
#
#                          region_path  \
# 0            SC-sylv_left/11-43-38_2
# 1          SC-sylv_left/14-00-57_116
# 2      SFinter-SFsup_left/09-33-02_0
# 3   STi-STs-STpol_right/20-15-00_117
# 4         FColl-SRh_right/09-45-57_1
# ..                               ...
# 71    SFinter-SFsup_right/09-33-02_1
# 72               STs_left/11-43-38_0
# 73      FCMpost-SpC_right/15-09-24_1
# 74        ORBITAL_right/15-53-41_191
# 75           SC-SPoC_left/14-55-36_0
#
#                                            model_path   side
# 0   /neurospin/dico/data/deep_folding/current/mode...   left
# 1   /neurospin/dico/data/deep_folding/current/mode...   left
# 2   /neurospin/dico/data/deep_folding/current/mode...   left
# 3   /neurospin/dico/data/deep_folding/current/mode...  right
# 4   /neurospin/dico/data/deep_folding/current/mode...  right
# ..                                                ...    ...
# 71  /neurospin/dico/data/deep_folding/current/mode...  right
# 72  /neurospin/dico/data/deep_folding/current/mode...   left
# 73  /neurospin/dico/data/deep_folding/current/mode...  right
# 74  /neurospin/dico/data/deep_folding/current/mode...  right
# 75  /neurospin/dico/data/deep_folding/current/mode...   left
#
# [76 rows x 7 columns]

# %%
df.to_csv(output_filename)
