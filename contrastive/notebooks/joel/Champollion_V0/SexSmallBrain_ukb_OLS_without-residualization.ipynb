# %%
import glob
import os
import omegaconf

import pandas as pd
import numpy as np
import random

import logging

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import LeaveOneGroupOut

import statsmodels.api as sm

import matplotlib.pyplot as plt
import seaborn as sns


logging.basicConfig()
logging.getLogger().setLevel(logging.INFO)

# %%
path_champollion = "/neurospin/dico/data/deep_folding/current/models/Champollion_V0"
participants_file = "/neurospin/dico/data/deep_folding/current/datasets/UkBioBank/participants.csv"
embeddings_subpath = "ukb_random_embeddings/full_embeddings.csv"
output_filename = f"{path_champollion}/summary/SexSmallBrain_ukb_without_residualization.csv"
label = "Sex"
max_iter = 2000
cv = 3

# %%
participants = pd.read_csv(participants_file, index_col=0)

# %%
participants = participants[participants.isBigBrain==0]

# %%
participants = participants[["Sex", "BrainVolumeFreeSurfer_mm3"]]

# %%
def closest_point(point, points):
    """ Find closest point from a list of points. """
    return np.argsort((points-point)**2)[:10]

# %%
participants
# Out:
#                 Sex  BrainVolumeFreeSurfer_mm3
# participant_id
# sub-1188492       0                   997615.0
# sub-2348409       0                  1002614.0
# sub-2214448       1                  1012144.0
# sub-5790117       0                  1007438.0
# sub-3794733       0                   964232.0
# ...             ...                        ...
# sub-1734788       0                  1029931.0
# sub-1673986       0                  1000852.0
# sub-5224110       0                   997299.0
# sub-1476670       0                  1030609.0
# sub-1895291       0                   986665.0
#
# [3802 rows x 2 columns]

# %%
females = participants[participants.Sex==0].copy()
males = participants[participants.Sex==1].copy()

females["chosen"] = 0
for one_male in males.iloc[:,1]:
    chosen_rows = closest_point(one_male, females.iloc[:,1])
    for chosen_row in chosen_rows:
        if females.iloc[chosen_row, 2] == 0:
            females.iloc[chosen_row, 2] = 1
            break

participants = pd.concat([males, females[females.chosen==1][["Sex", "BrainVolumeFreeSurfer_mm3"]]])

# %%
# participants[participants.Sex==0]["BrainVolumeFreeSurfer_mm3"].hist(bins=100)

# %%
# participants[participants.Sex==1]["BrainVolumeFreeSurfer_mm3"].hist(bins=100)

# %%
participants = participants[[label]].dropna()

# %%
participants.hist()
# Out:
# array([[<Axes: title={'center': 'Sex'}>]], dtype=object)

# %%
def is_it_a_file(sub_dir):
    if os.path.isdir(sub_dir):
        return False
    else:
        logging.debug(f"{sub_dir} is a file. Continue.")
        return True
    

def is_folder_a_model(sub_dir):
    if os.path.exists(sub_dir+'/.hydra/config.yaml'):
        return True
    else:
        logging.debug(f"\n{sub_dir} not associated to a model. Continue")
        return False

def get_model_paths(dir_path, result = None):
    """Recursively gets all models included in dir_path"""
    if result is None:  # create a new result if no intermediate was given
        result = [] 
    for name in os.listdir(dir_path):
        sub_dir = dir_path + '/' + name
        # checks if directory
        if is_it_a_file(sub_dir):
            pass
        elif not is_folder_a_model(sub_dir):
            result.extend(get_model_paths(sub_dir))
        else:
            result.append(sub_dir)
    return result

# %%
model_paths = get_model_paths(path_champollion)

# %%
model_paths[:5]
# Out:
# ['/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_left/11-43-38_2',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_left/14-00-57_116',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SFinter-SFsup_left/09-33-02_0',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/STi-STs-STpol_right/20-15-00_117',
#  '/neurospin/dico/data/deep_folding/current/models/Champollion_V0/FColl-SRh_right/09-45-57_1']

# %%
def compute(model_path):
    # Gets region name
    cfg = omegaconf.OmegaConf.load(model_path+'/.hydra/config.yaml')
    region = cfg['dataset'][next(iter(cfg['dataset']))]['crop_dir'].split('/')[-3]
    side = next(iter(cfg['dataset'])).split('_')[-1]
    region = region + '_' + side
    model_name = model_path.split('/')[-1]
    region_path = '/'.join(model_path.split('/')[-2:])
    print(f"Treating {region}: {region_path} : {model_path}")
    
    # Loads embeddings
    embeddings = pd.read_csv(f"{model_path}/{embeddings_subpath}", index_col=0)
    merged = participants[[label]].merge(embeddings, left_index=True, right_index=True)
    
    # Classifies
    X = merged.drop([label], axis=1)
    Y = merged[[label]]
    scaler = StandardScaler()
    X[X.columns] = scaler.fit_transform(X)
    df2 = X.copy()

    # Makes OLS
    df2 = sm.add_constant(df2)
    model = sm.OLS(Y[label], df2)
    results = model.fit()
    f_value = results.fvalue
    p_value = results.f_pvalue
    
    # Gets result
    # roc_auc = roc_auc_score(Y, proba_pred[:,1])
    print(f_value)
    
    # Returns result
    return (region, f_value, p_value, model_name, region_path, model_path)

# %%
result = []
for model_path in model_paths:
    result.append(compute(model_path))
# Out:
# Treating S.C.-sylv._left: SC-sylv_left/11-43-38_2 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_left/11-43-38_2
# 1.8084507378207861
# Treating S.C.-sylv._left: SC-sylv_left/14-00-57_116 : /neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_left/14-00-57_116
# 1.5967073688317768
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 3
#       1 result = []
#       2 for model_path in model_paths:
# ----> 3     result.append(compute(model_path))
#
# Cell In[17], line 3, in compute(model_path)
#       1 def compute(model_path):
#       2     # Gets region name
# ----> 3     cfg = omegaconf.OmegaConf.load(model_path+'/.hydra/config.yaml')
#       4     region = cfg['dataset'][next(iter(cfg['dataset']))]['crop_dir'].split('/')[-3]
#       5     side = next(iter(cfg['dataset'])).split('_')[-1]
#
# File ~/Runs/70_self-supervised_two-regions/Program/venv_natif/lib/python3.10/site-packages/omegaconf/omegaconf.py:205, in OmegaConf.load(file_)
#     203     ret = OmegaConf.create()
#     204 else:
# --> 205     ret = OmegaConf.create(obj)
#     206 return ret
#
# File ~/Runs/70_self-supervised_two-regions/Program/venv_natif/lib/python3.10/site-packages/omegaconf/omegaconf.py:178, in OmegaConf.create(obj, parent, flags)
#     172 @staticmethod
#     173 def create(  # noqa F811
#     174     obj: Any = _DEFAULT_MARKER_,
#     175     parent: Optional[BaseContainer] = None,
#     176     flags: Optional[Dict[str, bool]] = None,
#     177 ) -> Union[DictConfig, ListConfig]:
# --> 178     return OmegaConf._create_impl(
#     179         obj=obj,
#     180         parent=parent,
#     181         flags=flags,
#     182     )
#
# File ~/Runs/70_self-supervised_two-regions/Program/venv_natif/lib/python3.10/site-packages/omegaconf/omegaconf.py:861, in OmegaConf._create_impl(obj, parent, flags)
#     859         obj_type = OmegaConf.get_type(obj)
#     860         key_type, element_type = get_dict_key_value_types(obj_type)
# --> 861         return DictConfig(
#     862             content=obj,
#     863             parent=parent,
#     864             key_type=key_type,
#     865             element_type=element_type,
#     866             flags=flags,
#     867         )
#     868 elif is_primitive_list(obj) or OmegaConf.is_list(obj):
#     869     if isinstance(obj, ListConfig):
#
# File ~/Runs/70_self-supervised_two-regions/Program/venv_natif/lib/python3.10/site-packages/omegaconf/dictconfig.py:109, in DictConfig.__init__(self, content, key, parent, ref_type, key_type, element_type, is_optional, flags)
#     107             metadata.key_type = key_type
#     108             self.__dict__["_metadata"] = metadata
# --> 109         self._set_value(content, flags=flags)
#     110 except Exception as ex:
#     111     format_and_raise(node=None, key=key, value=None, cause=ex, msg=str(ex))
#
# File ~/Runs/70_self-supervised_two-regions/Program/venv_natif/lib/python3.10/site-packages/omegaconf/dictconfig.py:644, in DictConfig._set_value(self, value, flags)
#     642 try:
#     643     previous_content = self.__dict__["_content"]
# --> 644     self._set_value_impl(value, flags)
#     645 except Exception as e:
#     646     self.__dict__["_content"] = previous_content
#
# File ~/Runs/70_self-supervised_two-regions/Program/venv_natif/lib/python3.10/site-packages/omegaconf/dictconfig.py:690, in DictConfig._set_value_impl(self, value, flags)
#     688     with flag_override(self, ["struct", "readonly"], False):
#     689         for k, v in value.items():
# --> 690             self.__setitem__(k, v)
#     691     self._metadata.object_type = dict
#     693 else:  # pragma: no cover
#
# File ~/Runs/70_self-supervised_two-regions/Program/venv_natif/lib/python3.10/site-packages/omegaconf/dictconfig.py:308, in DictConfig.__setitem__(self, key, value)
#     306 def __setitem__(self, key: DictKeyType, value: Any) -> None:
#     307     try:
# --> 308         self.__set_impl(key=key, value=value)
#     309     except AttributeError as e:
#     310         self._format_and_raise(
#     311             key=key, value=value, type_override=ConfigKeyError, cause=e
#     312         )
#
# File ~/Runs/70_self-supervised_two-regions/Program/venv_natif/lib/python3.10/site-packages/omegaconf/dictconfig.py:318, in DictConfig.__set_impl(self, key, value)
#     316 def __set_impl(self, key: DictKeyType, value: Any) -> None:
#     317     key = self._validate_and_normalize_key(key)
# --> 318     self._set_item_impl(key, value)
#
# File ~/Runs/70_self-supervised_two-regions/Program/venv_natif/lib/python3.10/site-packages/omegaconf/basecontainer.py:531, in BaseContainer._set_item_impl(self, key, value)
#     525 """
#     526 Changes the value of the node key with the desired value. If the node key doesn't
#     527 exist it creates a new one.
#     528 """
#     529 from .nodes import AnyNode, ValueNode
# --> 531 if isinstance(value, Node):
#     532     do_deepcopy = not self._get_flag("no_deepcopy_set_nodes")
#     533     if not do_deepcopy and isinstance(value, Box):
#     534         # if value is from the same config, perform a deepcopy no matter what.
#
# File /usr/lib/python3.10/abc.py:117, in ABCMeta.__instancecheck__(cls, instance)
#     111     """Register a virtual subclass of an ABC.
#     112
#     113     Returns the subclass, to allow usage as a class decorator.
#     114     """
#     115     return _abc_register(cls, subclass)
# --> 117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
#     119     return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(result, columns=['region', 'f_value', 'p_value', 'model_name', 'region_path', 'model_path'])

# %%
df
# Out:
#                           region   f_value   p_value    model_name  \
# 0                S.C.-sylv._left  1.808451  0.000012    11-43-38_2
# 1                S.C.-sylv._left  1.596707  0.000406  14-00-57_116
# 2       S.F.inter.-S.F.sup._left  0.944559  0.664356    09-33-02_0
# 3   S.T.i.-S.T.s.-S.T.pol._right  1.352443  0.014889  20-15-00_117
# 4            F.Coll.-S.Rh._right  1.669470  0.000126    09-45-57_1
# ..                           ...       ...       ...           ...
# 72     S.F.inter.-S.F.sup._right  1.268451  0.043252    09-33-02_1
# 73                   S.T.s._left  1.384166  0.009685    11-43-38_0
# 74      F.C.M.post.-S.p.C._right  1.638104  0.000209    15-09-24_1
# 75                 ORBITAL_right  1.398817  0.007904  15-53-41_191
# 76             S.C.-S.Po.C._left  1.771585  0.000023    14-55-36_0
#
#                          region_path  \
# 0            SC-sylv_left/11-43-38_2
# 1          SC-sylv_left/14-00-57_116
# 2      SFinter-SFsup_left/09-33-02_0
# 3   STi-STs-STpol_right/20-15-00_117
# 4         FColl-SRh_right/09-45-57_1
# ..                               ...
# 72    SFinter-SFsup_right/09-33-02_1
# 73               STs_left/11-43-38_0
# 74      FCMpost-SpC_right/15-09-24_1
# 75        ORBITAL_right/15-53-41_191
# 76           SC-SPoC_left/14-55-36_0
#
#                                            model_path
# 0   /neurospin/dico/data/deep_folding/current/mode...
# 1   /neurospin/dico/data/deep_folding/current/mode...
# 2   /neurospin/dico/data/deep_folding/current/mode...
# 3   /neurospin/dico/data/deep_folding/current/mode...
# 4   /neurospin/dico/data/deep_folding/current/mode...
# ..                                                ...
# 72  /neurospin/dico/data/deep_folding/current/mode...
# 73  /neurospin/dico/data/deep_folding/current/mode...
# 74  /neurospin/dico/data/deep_folding/current/mode...
# 75  /neurospin/dico/data/deep_folding/current/mode...
# 76  /neurospin/dico/data/deep_folding/current/mode...
#
# [77 rows x 6 columns]

# %%
df['side'] = df['region'].str.split('_').str[-1]

# %%
def plot_horizontal(res, region_name, ax, f_value, p_value, f2_value, visible, title):
    labelsize=10
    ax.xaxis.set_tick_params(labelsize = labelsize)
    ax.yaxis.set_tick_params(labelsize = labelsize)
    
    res = res.sort_values(by=f_value, ascending=True)

    # ax.errorbar(res[AUC_name], res[region_name], res[std_auc_name], fmt='s', color='black')
    # ax.scatter(res[AUC_name], res[region_name], marker='s', color='black')
    ax.axvline(x=0.05, color='black', linestyle='-')
    ax.barh(res[region_name], res[f2_value], fill=True, color='lightgray')
    ax.errorbar(res[f_value], res[region_name], xerr=0, fmt='s', color='black')
    # if visible:
    #     ax.set_ylabel("AUC ensemble")
    # else:
    #     ax.get_yaxis().set_ticks([])
    # ax.set_xlim((0.3, 1.0))
    ax.set_title(title)

# %%
df.sort_values(by="f_value", ascending=False)
# Out:
#                                    region   f_value       p_value  model_name  \
# 16                     F.Coll.-S.Rh._left  2.341322  1.141054e-09  09-45-57_0
# 11       S.F.inf.-BROCA-S.Pe.C.inf._right  2.096710  8.392021e-08  12-25-50_1
# 22                     S.Or.-S.Olf._right  1.993639  5.091053e-07  18-00-16_1
# 31                     Sc.Cal.-S.Li._left  1.929286  1.557040e-06  09-28-12_0
# 59  F.C.L.p.-subsc.-F.C.L.a.-INSULA._left  1.896251  2.754932e-06  18-59-14_0
# ..                                    ...       ...           ...         ...
# 25                         CINGULATE_left  1.057833  3.438584e-01  16-58-04_1
# 52         S.F.marginal-S.F.inf.ant._left  1.015576  4.581360e-01  17-49-19_0
# 24                         CINGULATE_left  1.009145  4.765522e-01  17-13-32_1
# 58                           F.I.P._right  0.990676  5.302746e-01  20-16-33_3
# 2                S.F.inter.-S.F.sup._left  0.944559  6.643564e-01  09-33-02_0
#
#                                region_path  \
# 16               FColl-SRh_left/09-45-57_0
# 11    SFinf-BROCA-SPeCinf_right/12-25-50_1
# 22               SOr-SOlf_right/18-00-16_1
# 31               ScCal-SLi_left/09-28-12_0
# 59  FCLp-subsc-FCLa-INSULA_left/18-59-14_0
# ..                                     ...
# 25                   2024-07-16/16-58-04_1
# 52     SFmarginal-SFinfant_left/17-49-19_0
# 24                   2024-07-15/17-13-32_1
# 58                    FIP_right/20-16-33_3
# 2            SFinter-SFsup_left/09-33-02_0
#
#                                            model_path   side
# 16  /neurospin/dico/data/deep_folding/current/mode...   left
# 11  /neurospin/dico/data/deep_folding/current/mode...  right
# 22  /neurospin/dico/data/deep_folding/current/mode...  right
# 31  /neurospin/dico/data/deep_folding/current/mode...   left
# 59  /neurospin/dico/data/deep_folding/current/mode...   left
# ..                                                ...    ...
# 25  /neurospin/dico/data/deep_folding/current/mode...   left
# 52  /neurospin/dico/data/deep_folding/current/mode...   left
# 24  /neurospin/dico/data/deep_folding/current/mode...   left
# 58  /neurospin/dico/data/deep_folding/current/mode...  right
# 2   /neurospin/dico/data/deep_folding/current/mode...   left
#
# [77 rows x 7 columns]

# %%
plt.rc('axes', labelsize=12) 
f, ax = plt.subplots(1, 1, figsize=(10, 6))
plot_horizontal(df[df.side=='left'], "region", ax, "f_value", "f_value", "p_value",  True, "All regions")
plt.show()

# %%
plt.rc('axes', labelsize=12) 
f, ax = plt.subplots(1, 1, figsize=(10, 6))
plot_horizontal(df[df.side=='right'], "region", ax, "f_value", "p_value", "p_value",  True, "All regions")
plt.show()

# %%
df
# Out:
#                           region   f_value   p_value    model_name  \
# 0                S.C.-sylv._left  1.808451  0.000012    11-43-38_2
# 1                S.C.-sylv._left  1.596707  0.000406  14-00-57_116
# 2       S.F.inter.-S.F.sup._left  0.944559  0.664356    09-33-02_0
# 3   S.T.i.-S.T.s.-S.T.pol._right  1.352443  0.014889  20-15-00_117
# 4            F.Coll.-S.Rh._right  1.669470  0.000126    09-45-57_1
# ..                           ...       ...       ...           ...
# 72     S.F.inter.-S.F.sup._right  1.268451  0.043252    09-33-02_1
# 73                   S.T.s._left  1.384166  0.009685    11-43-38_0
# 74      F.C.M.post.-S.p.C._right  1.638104  0.000209    15-09-24_1
# 75                 ORBITAL_right  1.398817  0.007904  15-53-41_191
# 76             S.C.-S.Po.C._left  1.771585  0.000023    14-55-36_0
#
#                          region_path  \
# 0            SC-sylv_left/11-43-38_2
# 1          SC-sylv_left/14-00-57_116
# 2      SFinter-SFsup_left/09-33-02_0
# 3   STi-STs-STpol_right/20-15-00_117
# 4         FColl-SRh_right/09-45-57_1
# ..                               ...
# 72    SFinter-SFsup_right/09-33-02_1
# 73               STs_left/11-43-38_0
# 74      FCMpost-SpC_right/15-09-24_1
# 75        ORBITAL_right/15-53-41_191
# 76           SC-SPoC_left/14-55-36_0
#
#                                            model_path   side
# 0   /neurospin/dico/data/deep_folding/current/mode...   left
# 1   /neurospin/dico/data/deep_folding/current/mode...   left
# 2   /neurospin/dico/data/deep_folding/current/mode...   left
# 3   /neurospin/dico/data/deep_folding/current/mode...  right
# 4   /neurospin/dico/data/deep_folding/current/mode...  right
# ..                                                ...    ...
# 72  /neurospin/dico/data/deep_folding/current/mode...  right
# 73  /neurospin/dico/data/deep_folding/current/mode...   left
# 74  /neurospin/dico/data/deep_folding/current/mode...  right
# 75  /neurospin/dico/data/deep_folding/current/mode...  right
# 76  /neurospin/dico/data/deep_folding/current/mode...   left
#
# [77 rows x 7 columns]

# %%
# df.to_csv(output_filename)
