# %% [markdown]
# This notebook create dataset config files from reference

# %%
import pandas as pd
import os
import glob
import json

# %%
os.getcwd()
# Out:
# '/neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils'

# %%
path = f"{os.getcwd()}/../../../configs/dataset/with_reskel_distbottom/2mm/imagen"
ref_file = f"{path}/reference.yaml"
crop_path = "/neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm"
crop_dirs = glob.glob(f"{crop_path}/*")
crop_drops = []

# %%
crop_dirs = [f for f in crop_dirs if not os.path.basename(f) in crop_drops]

# %%
print(ref_file)
print('\n'.join(crop_dirs))
# Out:
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/reference.yaml
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/F.Coll.-S.Rh.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/S.F.median-S.F.pol.tr.-S.F.sup.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/S.F.inf.-BROCA-S.Pe.C.inf.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/S.Po.C.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/fronto-parietal_medial_face.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/F.I.P.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/S.T.s.-S.GSM.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/CINGULATE.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/F.C.L.p.-S.GSM.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/S.C.-S.Po.C.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/S.F.inter.-S.F.sup.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/F.C.M.post.-S.p.C.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/S.s.P.-S.Pa.int.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/S.Or.-S.Olf.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/F.P.O.-S.Cu.-Sc.Cal.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/S.F.marginal-S.F.inf.ant.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/S.F.int.-F.C.M.ant.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/S.T.i.-S.T.s.-S.T.pol.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/S.F.int.-S.R.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/Lobule_parietal_sup.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/S.T.i.-S.O.T.lat.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/S.Pe.C.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/S.T.s.br.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/Sc.Cal.-S.Li.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/S.T.s.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/F.C.L.p.-subsc.-F.C.L.a.-INSULA.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/S.C.-sylv.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/S.C.-S.Pe.C.
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/OCCIPITAL
# /neurospin/dico/data/deep_folding/current/datasets/imagen/crops/2mm/S.Or.

# %%
# Read in the reference file
with open(ref_file, 'r') as file:
  ref = file.read()

print(ref)
# Out:
# # @package dataset.REPLACE_DATASET
# dataset_name: REPLACE_DATASET
# pickle_normal: ${dataset_folder}/imagen/crops/2mm/REPLACE_CROP_NAME/mask/REPLACE_SIDEskeleton.pkl
# numpy_all: ${dataset_folder}/imagen/crops/2mm/REPLACE_CROP_NAME/mask/REPLACE_SIDEskeleton.npy
# subjects_all: ${dataset_folder}/imagen/crops/2mm/REPLACE_CROP_NAME/mask/REPLACE_SIDEskeleton_subject.csv
# crop_dir: ${dataset_folder}/imagen/crops/2mm/REPLACE_CROP_NAME/mask/REPLACE_SIDEcrops
# foldlabel_dir: ${dataset_folder}/imagen/crops/2mm/REPLACE_CROP_NAME/mask/REPLACE_SIDElabels
# foldlabel_all: ${dataset_folder}/imagen/crops/2mm/REPLACE_CROP_NAME/mask/REPLACE_SIDElabel.npy
# subjects_foldlabel_all: ${dataset_folder}/imagen/crops/2mm/REPLACE_CROP_NAME/mask/REPLACE_SIDElabel_subject.csv
# distbottom_dir: ${dataset_folder}/imagen/crops/2mm/REPLACE_CROP_NAME/mask/REPLACE_SIDEdistbottom
# distbottom_all: ${dataset_folder}/imagen/crops/2mm/REPLACE_CROP_NAME/mask/REPLACE_SIDEdistbottom.npy
# subjects_distbottom_all: ${dataset_folder}/imagen/crops/2mm/REPLACE_CROP_NAME/mask/REPLACE_SIDEdistbottom_subject.csv
# crop_file_suffix: _cropped_skeleton.nii.gz
# pickle_benchmark:
# train_val_csv_file: ${dataset_folder}/imagen/subjects_full.csv
# subject_labels_file: ${dataset_folder}/imagen/participants.csv
# subject_column_name: 'Subject'
# input_size: (1, REPLACE_SIZEX, REPLACE_SIZEY, REPLACE_SIZEZ)

# %%
def replace_reference_yaml(crop_dir, side, ref):
  """For each crop name, it builds the yaml from the reference yaml"""
  crop_name = os.path.basename(crop_dir)
  dataset_name = crop_name.replace('.', '')
  mask_file = f"{crop_dir}/mask/{side}mask_cropped.nii.gz.minf"
  with open(mask_file, 'r') as file:
    mask = file.read()
  mask = mask.replace("attributes = ", "")
  mask = mask.replace("\'", "\"")
  # print(mask)
  mask_json = json.loads(mask)
  # print(mask_json)
  side = side
  side_long = "left" if side=='L' else "right"
  dataset_name = f"{dataset_name}_{side_long}"
  filedata = ref.replace('REPLACE_CROP_NAME', crop_name)
  filedata = filedata.replace('REPLACE_DATASET', dataset_name)
  filedata = filedata.replace('REPLACE_SIDE', side)
  filedata = filedata.replace('REPLACE_SIZEX', str(mask_json['sizeX']))
  filedata = filedata.replace('REPLACE_SIZEY', str(mask_json['sizeY']))
  filedata = filedata.replace('REPLACE_SIZEZ', str(mask_json['sizeZ']))

  result_file = f"{path}/{dataset_name}.yaml"

  return filedata, result_file

# %%
# Replace the target string
for crop_dir in crop_dirs:
    for side in ['L', 'R']:
        filedata, result_file = replace_reference_yaml(crop_dir, side, ref)
        print(result_file)
        with open(result_file, 'w') as file:
          file.write(filedata)
# Out:
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/FColl-SRh_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/FColl-SRh_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SFmedian-SFpoltr-SFsup_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SFmedian-SFpoltr-SFsup_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SFinf-BROCA-SPeCinf_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SFinf-BROCA-SPeCinf_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SPoC_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SPoC_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/fronto-parietal_medial_face_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/fronto-parietal_medial_face_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/FIP_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/FIP_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/STs-SGSM_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/STs-SGSM_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/CINGULATE_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/CINGULATE_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/FCLp-SGSM_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/FCLp-SGSM_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SC-SPoC_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SC-SPoC_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SFinter-SFsup_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SFinter-SFsup_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/FCMpost-SpC_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/FCMpost-SpC_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SsP-SPaint_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SsP-SPaint_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SOr-SOlf_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SOr-SOlf_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/FPO-SCu-ScCal_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/FPO-SCu-ScCal_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SFmarginal-SFinfant_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SFmarginal-SFinfant_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SFint-FCMant_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SFint-FCMant_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/STi-STs-STpol_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/STi-STs-STpol_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SFint-SR_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SFint-SR_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/Lobule_parietal_sup_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/Lobule_parietal_sup_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/STi-SOTlat_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/STi-SOTlat_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SPeC_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SPeC_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/STsbr_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/STsbr_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/ScCal-SLi_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/ScCal-SLi_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/STs_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/STs_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/FCLp-subsc-FCLa-INSULA_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/FCLp-subsc-FCLa-INSULA_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SC-sylv_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SC-sylv_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SC-SPeC_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SC-SPeC_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/OCCIPITAL_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/OCCIPITAL_right.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SOr_left.yaml
# /neurospin/dico/jchavas/Runs/70_self-supervised_two-regions/Program/2023_jlaval_STSbabies/contrastive/notebooks/joel/utils/../../../configs/dataset/with_reskel_distbottom/2mm/imagen/SOr_right.yaml

# %%
# # Write the file out again
# with open('file.txt', 'w') as file:
#   file.write(filedata)

# %% [markdown]
# # Command line of train.py

# %%
path_champollion = "/neurospin/dico/data/deep_folding/current/models/Champollion_V0"
path_configs = path

# %%
trained_regions = glob.glob(f"{path_champollion}/*")
trained_regions = [f for f in trained_regions if not "README.md" in f]
trained_regions = [os.path.basename(f) for f in trained_regions]
print('\n'.join(trained_regions))
# Out:
# SC-sylv_left
# SFinter-SFsup_left
# STi-STs-STpol_right
# FColl-SRh_right
# STs-SGSM_left
# SC-sylv_right
# Lobule_parietal_sup_left
# SFint-SR_left
# SPoC_left
# SFinf-BROCA-SPeCinf_right
# SsP-SPaint_left
# SOr-SOlf_left
# SFinf-BROCA-SPeCinf_left
# SFmedian-SFpoltr-SFsup_right
# FColl-SRh_left
# STi-STs-STpol_left
# SFint-FCMant_left
# FCLp-subsc-FCLa-INSULA_right
# OCCIPITAL_right
# cluster
# summary
# SC-SPeC_right
# SOr-SOlf_right
# CINGULATE_left
# SFint-SR_right
# CINGULATE_right
# FCLp-SGSM_right
# fronto-parietal_medial_face_left
# ScCal-SLi_left
# FPO-SCu-ScCal_right
# FPO-SCu-ScCal_left
# OCCIPITAL_left
# SC-SPeC_left
# STs_right
# FIP_left
# STsbr_right
# SC-SPoC_right
# fronto-parietal_medial_face_right
# SPeC_left
# STs-SGSM_right
# SPoC_right
# STi-SOTlat_right
# FCLp-SGSM_left
# FCMpost-SpC_left
# SFint-FCMant_right
# SFmedian-SFpoltr-SFsup_left
# SPeC_right
# SFmarginal-SFinfant_left
# FIP_right
# FCLp-subsc-FCLa-INSULA_left
# STsbr_left
# SsP-SPaint_right
# ScCal-SLi_right
# Lobule_parietal_sup_right
# ORBITAL_left
# SFmarginal-SFinfant_right
# STi-SOTlat_left
# SFinter-SFsup_right
# STs_left
# FCMpost-SpC_right
# ORBITAL_right
# SC-SPoC_left

# %%
available_configs = glob.glob(f"{path_configs}/*")
available_configs = [f for f in available_configs if not "reference.yaml" in f]
available_configs = [os.path.basename(f).replace(".yaml", "") for f in available_configs]
print('\n'.join(available_configs))
# Out:
# SFint-FCMant_left
# SOr-SOlf_left
# CINGULATE_right
# SFint-FCMant_right
# SFinter-SFsup_left
# SFmedian-SFpoltr-SFsup_left
# SPoC_left
# SOr-SOlf_right
# SsP-SPaint_right
# STi-SOTlat_left
# ScCal-SLi_left
# STsbr_left
# SFint-SR_right
# SsP-SPaint_left
# STs_right
# STs_left
# SC-sylv_right
# fronto-parietal_medial_face_left
# FCLp-SGSM_right
# SOr_right
# FIP_right
# SC-SPeC_left
# FCLp-subsc-FCLa-INSULA_right
# Lobule_parietal_sup_left
# SOr_left
# FCMpost-SpC_right
# SFinf-BROCA-SPeCinf_left
# STsbr_right
# SC-SPoC_left
# FColl-SRh_left
# SC-sylv_left
# SFinter-SFsup_right
# STi-SOTlat_right
# FColl-SRh_right
# STi-STs-STpol_right
# Lobule_parietal_sup_right
# SC-SPoC_right
# FCLp-SGSM_left
# SC-SPeC_right
# FIP_left
# STi-STs-STpol_left
# STs-SGSM_left
# SFmarginal-SFinfant_left
# SPoC_right
# SPeC_right
# SFmarginal-SFinfant_right
# SFinf-BROCA-SPeCinf_right
# fronto-parietal_medial_face_right
# SPeC_left
# ScCal-SLi_right
# CINGULATE_left
# OCCIPITAL_left
# FCLp-subsc-FCLa-INSULA_left
# SFmedian-SFpoltr-SFsup_right
# STs-SGSM_right
# FPO-SCu-ScCal_right
# SFint-SR_left
# OCCIPITAL_right
# FPO-SCu-ScCal_left
# FCMpost-SpC_left

# %%
to_train = set(available_configs) - set(trained_regions)
print(len(to_train))
to_train = [f"with_reskel_distbottom/2mm/imagen/{i}" for i in to_train]
# Out:
# 2

# %%
','.join(to_train)
# Out:
# 'with_reskel_distbottom/2mm/imagen/SOr_left,with_reskel_distbottom/2mm/imagen/SOr_right'

# %%
len(to_train)
# Out:
# 2
