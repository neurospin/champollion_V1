# %%
import glob
import os
import pandas as pd
import numpy as np

# %%
path = "/mnt/n4habcd"
subpath = "ses-1/anat/t1mri/default_acquisition/default_analysis/folds/3.1"
qc_file = "/neurospin/dico/data/deep_folding/current/datasets/ABCD/qc.tsv"

# %%
list_folders = glob.glob(f"{path}/*")
list_folders = [x for x in list_folders]
list_subjects = [os.path.basename(f) for f in list_folders]

# %%
list_subjects
# Out:
# ['sub-NDARINVLVJNK52B',
#  'sub-NDARINVG7B119A0',
#  'sub-NDARINVTFPAU4FF',
#  'sub-NDARINVZ5G203VB',
#  'sub-NDARINVYPZAV10C',
#  'sub-NDARINVXHJBRK7N',
#  'sub-NDARINVCZWTTCVK',
#  'sub-NDARINVJ45XGZRF',
#  'sub-NDARINVXBDHH0WV',
#  'sub-NDARINVFM6CBFTY',
#  'sub-NDARINVL9NUBDAN',
#  'sub-NDARINVZ6Z9DP4H',
#  'sub-NDARINV7BCF45XY',
#  'sub-NDARINVR7N0XBL6',
#  'sub-NDARINVW49LW8G9',
#  'sub-NDARINV75EWTV73',
#  'sub-NDARINV2N0CBXE8',
#  'sub-NDARINVB74PPWH0',
#  'sub-NDARINVDCRLF3FV',
#  'sub-NDARINVGB21KKU9',
#  'sub-NDARINVTHWNZF8Y',
#  'sub-NDARINVWLNTC8GU',
#  'sub-NDARINVY4984X9Z',
#  'sub-NDARINV3AY9C1RJ',
#  'sub-NDARINV5Z57C4GY',
#  'sub-NDARINVMKRG2K7G',
#  'sub-NDARINVY3HRTGKA',
#  'sub-NDARINVA354YMUE',
#  'sub-NDARINVTL0JKXBF',
#  'sub-NDARINVKB7UD17H',
#  'sub-NDARINVVVD39H82',
#  'sub-NDARINVZZNX6W2P',
#  'sub-NDARINVYVTDJF8M',
#  'sub-NDARINVKDZR86PA',
#  'sub-NDARINVBZBW11DL',
#  'sub-NDARINV2DZUL8LC',
#  'sub-NDARINV87C4733D',
#  'sub-NDARINV4J8HX541',
#  'sub-NDARINVXFVDB3VJ',
#  'sub-NDARINV84PUG220',
#  'sub-NDARINVMVTF3GGD',
#  'sub-NDARINVGLTMA4LA',
#  'sub-NDARINV79ZF8916',
#  'sub-NDARINV9K1GRJNJ',
#  'sub-NDARINVJAUU039W',
#  'sub-NDARINVWX7WTJX6',
#  'sub-NDARINVV8URWFJ6',
#  'sub-NDARINVPPY8DZG0',
#  'sub-NDARINVGHL1WZCU',
#  'sub-NDARINVKXFX6UM8',
#  'sub-NDARINVYXGKVZAY',
#  'sub-NDARINVLCYH9EDJ',
#  'sub-NDARINVEAH0VU8C',
#  'sub-NDARINVA36UUP5T',
#  'sub-NDARINV4BB6Z0VU',
#  'sub-NDARINVR64BGK81',
#  'sub-NDARINV8TFN2FX0',
#  'sub-NDARINVCVZ70012',
#  'sub-NDARINV3BLPP0EZ',
#  'sub-NDARINV1YFEDW44',
#  'sub-NDARINVY20R5X1P',
#  'sub-NDARINVBUPMZF11',
#  'sub-NDARINVCE8LF65E',
#  'sub-NDARINV9LKMUE8U',
#  'sub-NDARINV99XGJFE8',
#  'sub-NDARINVVPNP73C4',
#  'sub-NDARINV89HG7074',
#  'sub-NDARINVFW085ZMA',
#  'sub-NDARINV8Z3G152U',
#  'sub-NDARINV01D03VR7',
#  'sub-NDARINVMBVX3LHF',
#  'sub-NDARINV94LUVVX8',
#  'sub-NDARINVP9LWMMB5',
#  'sub-NDARINVYU7KURNA',
#  'sub-NDARINVT23YJZWZ',
#  'sub-NDARINVPMV3Y0GW',
#  'sub-NDARINV4JCA65T3',
#  'sub-NDARINV5DW63RTW',
#  'sub-NDARINVTZCLUNW2',
#  'sub-NDARINVLTFXTGJ0',
#  'sub-NDARINV2F870CXM',
#  'sub-NDARINVFWFC9K4K',
#  'sub-NDARINVYLNHN7LR',
#  'sub-NDARINVTCAFT1FE',
#  'sub-NDARINVUXBAPXMJ',
#  'sub-NDARINV0KHYZ082',
#  'sub-NDARINVG1HPL4C5',
#  'sub-NDARINVCL1R63XL',
#  'sub-NDARINV2G6169KB',
#  'sub-NDARINVCENTPAJU',
#  'sub-NDARINVVC1UM0RW',
#  'sub-NDARINVFJEW218J',
#  'sub-NDARINV5NNKMGJE',
#  'sub-NDARINV67PGLMAX',
#  'sub-NDARINV9XZMNP0M',
#  'sub-NDARINVE299DCVM',
#  'sub-NDARINV7CBUV9AY',
#  'sub-NDARINV8PMAFPCV',
#  'sub-NDARINVP3NFD934',
#  'sub-NDARINV3N0KGZ5G',
#  'sub-NDARINV7LWNRC3F',
#  'sub-NDARINVXFURZ24F',
#  'sub-NDARINVDRM97DTU',
#  'sub-NDARINVVKR3UP6G',
#  'sub-NDARINVH2CGXAAN',
#  'sub-NDARINVUFF64VGJ',
#  'sub-NDARINVZA2HPC0L',
#  'sub-NDARINV4P9B9PGN',
#  'sub-NDARINVV2TL3DA9',
#  'sub-NDARINVZT1J0KUC',
#  'sub-NDARINVLRTEWBMH',
#  'sub-NDARINV5JGG99ZM',
#  'sub-NDARINVMENCHP62',
#  'sub-NDARINVWE9H9FRJ',
#  'sub-NDARINV50ABALT4',
#  'sub-NDARINVNUAGE7UT',
#  'sub-NDARINVF7K681U5',
#  'sub-NDARINVJ5JJZDPB',
#  'sub-NDARINVDPWJMF3B',
#  'sub-NDARINVHP17VUZM',
#  'sub-NDARINVKLL0383Z',
#  'sub-NDARINV85W3GP9V',
#  'sub-NDARINVG5M25E6R',
#  'sub-NDARINVGFB2AURV',
#  'sub-NDARINV1AA2VG9C',
#  'sub-NDARINV46X37HLX',
#  'sub-NDARINVU46YJV27',
#  'sub-NDARINVVM2X0W61',
#  'sub-NDARINVYCL4R17D',
#  'sub-NDARINV3XRWEG62',
#  'sub-NDARINVJ2A3JCGK',
#  'sub-NDARINV1P29RX5F',
#  'sub-NDARINV74MKXN03',
#  'sub-NDARINVV5MHL75K',
#  'sub-NDARINVKV39ALMD',
#  'sub-NDARINV20GGC8X5',
#  'sub-NDARINVUEXW27D7',
#  'sub-NDARINVJM19UTB0',
#  'sub-NDARINVK9RPEUC1',
#  'sub-NDARINVF4NKLBXV',
#  'sub-NDARINV49EG90M3',
#  'sub-NDARINVTTB355AR',
#  'sub-NDARINVABT9X85F',
#  'sub-NDARINV1P7L5P3B',
#  'sub-NDARINV6ETG8KHZ',
#  'sub-NDARINV3MANP3Y8',
#  'sub-NDARINVNXU172XX',
#  'sub-NDARINV7C262RWK',
#  'sub-NDARINVEPM1GJ03',
#  'sub-NDARINVFBEG8E1Z',
#  'sub-NDARINVJTU3X2VF',
#  'sub-NDARINVKJCYGTUC',
#  'sub-NDARINVKTLE69Y8',
#  'sub-NDARINVCHUKUNFD',
#  'sub-NDARINV0VBJ9TP2',
#  'sub-NDARINV0CV2Y4YR',
#  'sub-NDARINVG6WRD4X4',
#  'sub-NDARINV9AH5WYA7',
#  'sub-NDARINV37C7BURT',
#  'sub-NDARINVZ6ZN350N',
#  'sub-NDARINV9DV0865Y',
#  'sub-NDARINVY8CPCJJ3',
#  'sub-NDARINVY61UGEKY',
#  'sub-NDARINV1CTLWW8V',
#  'sub-NDARINVT7HVBTRE',
#  'sub-NDARINVD43PR719',
#  'sub-NDARINVGB1LBZ5W',
#  'sub-NDARINVU325J0ED',
#  'sub-NDARINV8MC7B79X',
#  'sub-NDARINV5XN1DB2X',
#  'sub-NDARINVRX41226B',
#  'sub-NDARINVMF6NM996',
#  'sub-NDARINV3XZKYEVA',
#  'sub-NDARINVC6941X6U',
#  'sub-NDARINV5MXTGY8D',
#  'sub-NDARINVWV0VWFDF',
#  'sub-NDARINV6F8VJE7N',
#  'sub-NDARINVB20VM7P8',
#  'sub-NDARINVPHWBVRBU',
#  'sub-NDARINV9U33DV8X',
#  'sub-NDARINVPFLP04U0',
#  'sub-NDARINVJU4UKFJC',
#  'sub-NDARINV1ZPJCKVC',
#  'sub-NDARINV1W2D4CFP',
#  'sub-NDARINVH9F934NE',
#  'sub-NDARINV6CNL0TLZ',
#  'sub-NDARINV0DUXE0ZA',
#  'sub-NDARINVK32MTP5J',
#  'sub-NDARINVG0ZNL58U',
#  'sub-NDARINVJD6CRBP8',
#  'sub-NDARINV7H8LD2B5',
#  'sub-NDARINVZNN6JK3K',
#  'sub-NDARINVK20NJZWV',
#  'sub-NDARINVUULNDK83',
#  'sub-NDARINVCPAB62JD',
#  'sub-NDARINVC29KYLLN',
#  'sub-NDARINVET4W53Z8',
#  'sub-NDARINVPR6CBWP9',
#  'sub-NDARINVDT744K7Y',
#  'sub-NDARINV4A443KDZ',
#  'sub-NDARINVH9ERT7NK',
#  'sub-NDARINV66D8NKUD',
#  'sub-NDARINV64PVVHP3',
#  'sub-NDARINVD681TFUL',
#  'sub-NDARINVT4XE5642',
#  'sub-NDARINV7F1PXABE',
#  'sub-NDARINVDHJNAJ5Y',
#  'sub-NDARINVC3LRZTRT',
#  'sub-NDARINVVZ679N9G',
#  'sub-NDARINVZ76CGDX4',
#  'sub-NDARINVRTN0KC8U',
#  'sub-NDARINVL456T3RZ',
#  'sub-NDARINV1V752R9N',
#  'sub-NDARINVRTHVMF0B',
#  'sub-NDARINV4XF3MZ2T',
#  'sub-NDARINVTA7NT65Z',
#  'sub-NDARINVEPFT013C',
#  'sub-NDARINV72PBFKDM',
#  'sub-NDARINV0JAG7BGC',
#  'sub-NDARINVH4U16H28',
#  'sub-NDARINV0RHLKA9M',
#  'sub-NDARINVBZKEHZY8',
#  'sub-NDARINVFX004DUH',
#  'sub-NDARINVJP58CZGJ',
#  'sub-NDARINVVZJ1V3A9',
#  'sub-NDARINVFZ1W3N0D',
#  'sub-NDARINVFEKGBDCL',
#  'sub-NDARINVTFE6R22P',
#  'sub-NDARINVHT2VVF5A',
#  'sub-NDARINVKFH1X898',
#  'sub-NDARINVCVNFXR7V',
#  'sub-NDARINVNEGNRZ5L',
#  'sub-NDARINV5WZA04YF',
#  'sub-NDARINVXHKRJC1C',
#  'sub-NDARINVH32GHURA',
#  'sub-NDARINVGWGVANWJ',
#  'sub-NDARINV62G4MJ4G',
#  'sub-NDARINV3B70AX8C',
#  'sub-NDARINV7E2LV7HF',
#  'sub-NDARINVULJ63ZZK',
#  'sub-NDARINVG1TXFJX2',
#  'sub-NDARINVM02A1YVT',
#  'sub-NDARINVWJ086JLF',
#  'sub-NDARINVPBJTJ0Z3',
#  'sub-NDARINVG29BXF0A',
#  'sub-NDARINVDMT3XG3K',
#  'sub-NDARINVV2WL8NJZ',
#  'sub-NDARINV08894886',
#  'sub-NDARINVF00P4A2L',
#  'sub-NDARINV0VY70352',
#  'sub-NDARINVPZ1GC78K',
#  'sub-NDARINV9XEANHKF',
#  'sub-NDARINVK4KJGM46',
#  'sub-NDARINVR9A6L5EN',
#  'sub-NDARINVHX9H807C',
#  'sub-NDARINVDHPX2Z6Y',
#  'sub-NDARINVWUHH5YTP',
#  'sub-NDARINVWMTTWY8K',
#  'sub-NDARINVZCNK7B3X',
#  'sub-NDARINVP61N70TM',
#  'sub-NDARINVLXZ3RPWB',
#  'sub-NDARINVUA3V5JAA',
#  'sub-NDARINV31NMMY4J',
#  'sub-NDARINV4K2HKN0K',
#  'sub-NDARINVG86EJHZD',
#  'sub-NDARINVWNTYPRLM',
#  'sub-NDARINVP3U1CUBR',
#  'sub-NDARINVZF82Z2N1',
#  'sub-NDARINVREGPJEJ9',
#  'sub-NDARINV6UUPURN1',
#  'sub-NDARINV39DK1BKF',
#  'sub-NDARINV0DC9BJZK',
#  'sub-NDARINV6MRZ56RM',
#  'sub-NDARINV61GRLR8M',
#  'sub-NDARINVVRX7WTKX',
#  'sub-NDARINVFFG2LPV0',
#  'sub-NDARINV3Z6H844T',
#  'sub-NDARINV95TJXP19',
#  'sub-NDARINV57V4LC2W',
#  'sub-NDARINVH8NGBTPP',
#  'sub-NDARINV50UATGZM',
#  'sub-NDARINV5RY4ZHHG',
#  'sub-NDARINV71MKD752',
#  'sub-NDARINVJKDWLHZU',
#  'sub-NDARINV7J2P2KEU',
#  'sub-NDARINVZ1Z285F2',
#  'sub-NDARINV4X6J651P',
#  'sub-NDARINV8GWBGTAB',
#  'sub-NDARINV7N4MXK3N',
#  'sub-NDARINVDWTK3PP0',
#  'sub-NDARINVYXATK265',
#  'sub-NDARINV26WFVNRJ',
#  'sub-NDARINV88HZ7ZCH',
#  'sub-NDARINVGZJDGF8L',
#  'sub-NDARINV4T71DFV4',
#  'sub-NDARINVVYY8ZHN5',
#  'sub-NDARINVYC395FB1',
#  'sub-NDARINV2BJ826W8',
#  'sub-NDARINVZ4V1KGHH',
#  'sub-NDARINVRJ65NCMR',
#  'sub-NDARINVVA82JDEJ',
#  'sub-NDARINV9PA518RY',
#  'sub-NDARINVAKPAVUC0',
#  'sub-NDARINVMJB4F3FB',
#  'sub-NDARINVCB9AY93V',
#  'sub-NDARINVVKCT9VLF',
#  'sub-NDARINVPRDYVE4C',
#  'sub-NDARINVAWP77RE3',
#  'sub-NDARINVY4UH45DB',
#  'sub-NDARINVYC3MCRAY',
#  'sub-NDARINVXARTK6ET',
#  'sub-NDARINVKKC98J6W',
#  'sub-NDARINVAJNNT0JH',
#  'sub-NDARINVTL901BED',
#  'sub-NDARINV7NAGRWL5',
#  'sub-NDARINV1925AD9X',
#  'sub-NDARINV4WB9H8LL',
#  'sub-NDARINV9UV6PK7Y',
#  'sub-NDARINVWZHDTM6W',
#  'sub-NDARINV2HYZJ61G',
#  'sub-NDARINVCXXT5U2P',
#  'sub-NDARINVJT2E2T8K',
#  'sub-NDARINV2FV9YY14',
#  'sub-NDARINVGLM2JGDD',
#  'sub-NDARINVXGUFG37J',
#  'sub-NDARINVT96B8JHC',
#  'sub-NDARINVR6PPY0VL',
#  'sub-NDARINV48NE3N41',
#  'sub-NDARINVU6TK1ULB',
#  'sub-NDARINVGD6JWJWD',
#  'sub-NDARINVX5326K7A',
#  'sub-NDARINVLBAKFHGK',
#  'sub-NDARINVP55M5T0X',
#  'sub-NDARINVH8HNJZD4',
#  'sub-NDARINV0191C80U',
#  'sub-NDARINV6WH2N8P4',
#  'sub-NDARINV7R0TF1TJ',
#  'sub-NDARINV1GL1F6FK',
#  'sub-NDARINVGCZFBJ6B',
#  'sub-NDARINVWTTUXX1L',
#  'sub-NDARINV1ER3Z8ZF',
#  'sub-NDARINVB3438R23',
#  'sub-NDARINVK1KZZ8D4',
#  'sub-NDARINVZJHF566H',
#  'sub-NDARINVGMC8M2DC',
#  'sub-NDARINVZJV3HZEF',
#  'sub-NDARINVE32G7HZE',
#  'sub-NDARINVYDL52THG',
#  'sub-NDARINV1FGX3DL8',
#  'sub-NDARINV5XZZKLKM',
#  'sub-NDARINV7FTHG8XU',
#  'sub-NDARINVFX6XRA82',
#  'sub-NDARINVYLKWWGJ2',
#  'sub-NDARINV1CKXVV32',
#  'sub-NDARINVCY4X20TC',
#  'sub-NDARINVK2YU9TW1',
#  'sub-NDARINVXBPBAPVX',
#  'sub-NDARINVWBGB46VZ',
#  'sub-NDARINV1BGRYN2J',
#  'sub-NDARINVTZ5XBL2L',
#  'sub-NDARINV9M8W1495',
#  'sub-NDARINVBEG60AUC',
#  'sub-NDARINV14UJARAJ',
#  'sub-NDARINVUVB66Y7Z',
#  'sub-NDARINV58GL6F39',
#  'sub-NDARINVA41WLWNU',
#  'sub-NDARINVYFGJBRCE',
#  'sub-NDARINVWUYB82C8',
#  'sub-NDARINV0T41MTFH',
#  'sub-NDARINVJD6BW0Y0',
#  'sub-NDARINV38DJNT05',
#  'sub-NDARINV9MF93B7R',
#  'sub-NDARINV66PM75JX',
#  'sub-NDARINVZWACXHZ6',
#  'sub-NDARINVWAVA878R',
#  'sub-NDARINVTNKV2H46',
#  'sub-NDARINVBKW33JVR',
#  'sub-NDARINVDR3M36J1',
#  'sub-NDARINVMJ61WEFZ',
#  'sub-NDARINVK0870VPA',
#  'sub-NDARINVKYCN6AYE',
#  'sub-NDARINV6KZ6GTEJ',
#  'sub-NDARINVEG7V5UN3',
#  'sub-NDARINVAB10CA5H',
#  'sub-NDARINV229XUWRH',
#  'sub-NDARINVHEW2AUBP',
#  'sub-NDARINVMGYDVKBT',
#  'sub-NDARINVVRZT93M0',
#  'sub-NDARINVBPB9W02P',
#  'sub-NDARINVUKKJ04AZ',
#  'sub-NDARINVJH93PMX3',
#  'sub-NDARINVMDEU4XC0',
#  'sub-NDARINVJFC8DZWR',
#  'sub-NDARINVX3ET5EK4',
#  'sub-NDARINVHWPUPM4D',
#  'sub-NDARINV05LGG3GZ',
#  'sub-NDARINV90HEMJDR',
#  'sub-NDARINVHV5ACGVN',
#  'sub-NDARINVPH4BZ3KW',
#  'sub-NDARINVR20CKWHP',
#  'sub-NDARINV5E97AP49',
#  'sub-NDARINVLLGNHY2A',
#  'sub-NDARINV8N41W2W1',
#  'sub-NDARINV1LX1A3TR',
#  'sub-NDARINVCZU8RL3L',
#  'sub-NDARINVYU3FUA3E',
#  'sub-NDARINVU6C1J3JP',
#  'sub-NDARINVGD7X7HAX',
#  'sub-NDARINVE5K3E4XA',
#  'sub-NDARINV4C2YD3TH',
#  'sub-NDARINVXYF9FXT8',
#  'sub-NDARINVK4H5ZTFE',
#  'sub-NDARINVKM38D8JZ',
#  'sub-NDARINVLMY0XZB5',
#  'sub-NDARINVKP2NYJN2',
#  'sub-NDARINVDPP9W7AV',
#  'sub-NDARINV5R57W4GA',
#  'sub-NDARINVR77YG5G1',
#  'sub-NDARINVRRAW1J1K',
#  'sub-NDARINVA4PY09B5',
#  'sub-NDARINVKH0DH6EC',
#  'sub-NDARINV0W4PR2WT',
#  'sub-NDARINVZDHYHJKH',
#  'sub-NDARINVHNER3YDN',
#  'sub-NDARINVFGGKCL3V',
#  'sub-NDARINV4JD9NHNZ',
#  'sub-NDARINVRE317TA3',
#  'sub-NDARINVATE29B31',
#  'sub-NDARINVGY8VBRN0',
#  'sub-NDARINVXTRH94BW',
#  'sub-NDARINVLW9XT5P3',
#  'sub-NDARINV5L65JM7L',
#  'sub-NDARINV19JV1ZX5',
#  'sub-NDARINVR06UP6NN',
#  'sub-NDARINVYTVCUEA2',
#  'sub-NDARINVF7RLL816',
#  'sub-NDARINV6KUUNE55',
#  'sub-NDARINVBB0FDDL0',
#  'sub-NDARINVDLRDW633',
#  'sub-NDARINVFP8B264R',
#  'sub-NDARINV25KAJM0U',
#  'sub-NDARINV21ZAXTA3',
#  'sub-NDARINVV0YMYACE',
#  'sub-NDARINVAHDU5HRW',
#  'sub-NDARINVKZW3CU83',
#  'sub-NDARINVJTM54RD3',
#  'sub-NDARINVLBZW40WR',
#  'sub-NDARINVKAJWW29J',
#  'sub-NDARINV3WA4PYL5',
#  'sub-NDARINVZLEFF9ZA',
#  'sub-NDARINV9Y43MGV3',
#  'sub-NDARINV66B2RLDF',
#  'sub-NDARINVJ2NHEXRP',
#  'sub-NDARINV4EK87DJK',
#  'sub-NDARINV5BJZW7MU',
#  'sub-NDARINVH4XJFFCE',
#  'sub-NDARINV504L1YB4',
#  'sub-NDARINV1JERB432',
#  'sub-NDARINVRC3GEEEJ',
#  'sub-NDARINVNF2BWTVU',
#  'sub-NDARINV5BA97WFG',
#  'sub-NDARINVCFYJ60VA',
#  'sub-NDARINV6BE95J7K',
#  'sub-NDARINVJPH56X7G',
#  'sub-NDARINV8T2NUL38',
#  'sub-NDARINVWH0P4JHC',
#  'sub-NDARINV82D8H4A0',
#  'sub-NDARINV0BAVEL0T',
#  'sub-NDARINV96KLPLFJ',
#  'sub-NDARINVJAGE8DBX',
#  'sub-NDARINVARFAEL21',
#  'sub-NDARINVP8D1V80P',
#  'sub-NDARINVHXFHEYX7',
#  'sub-NDARINV3PTPRFM5',
#  'sub-NDARINVUZMRNA0C',
#  'sub-NDARINVAAR0XGYL',
#  'sub-NDARINVEZR60E9U',
#  'sub-NDARINVHV9VDD6H',
#  'sub-NDARINV6Z1RJLBY',
#  'sub-NDARINVWEZHYJ9U',
#  'sub-NDARINV9245VEY5',
#  'sub-NDARINV021N0FLH',
#  'sub-NDARINVNBJ852WE',
#  'sub-NDARINVPDVYFN7E',
#  'sub-NDARINV04TRXUGL',
#  'sub-NDARINVBJUT8TR0',
#  'sub-NDARINVNAJWH1CY',
#  'sub-NDARINVFLL0YDNF',
#  'sub-NDARINV43VWMCUC',
#  'sub-NDARINVJK6VB601',
#  'sub-NDARINVG5XLB72Y',
#  'sub-NDARINV474A4X05',
#  'sub-NDARINV82FT97YR',
#  'sub-NDARINV7KB5VY4J',
#  'sub-NDARINVZJD4XU1U',
#  'sub-NDARINV39R1KUT6',
#  'sub-NDARINVE30MYZ4J',
#  'sub-NDARINVXRR639H7',
#  'sub-NDARINVUKT7ETKD',
#  'sub-NDARINVR85P7XPP',
#  'sub-NDARINV52CVLNFF',
#  'sub-NDARINV9X8VZ9R1',
#  'sub-NDARINVBKNVGWPC',
#  'sub-NDARINVAB0FFGNZ',
#  'sub-NDARINVBZH975R2',
#  'sub-NDARINV24YLW97V',
#  'sub-NDARINV70EJ1089',
#  'sub-NDARINVHTM2U5ZY',
#  'sub-NDARINV2GR8F963',
#  'sub-NDARINV7KENV8ZC',
#  'sub-NDARINV6TM6V4CG',
#  'sub-NDARINVGA8XJ9W5',
#  'sub-NDARINVNPCKJF8R',
#  'sub-NDARINV1M9Y0F92',
#  'sub-NDARINVPEYUTRRT',
#  'sub-NDARINVGE15ZEP5',
#  'sub-NDARINVUJ86W3MP',
#  'sub-NDARINVCURU4G26',
#  'sub-NDARINVHFDKX3LR',
#  'sub-NDARINVC5KPLUZ5',
#  'sub-NDARINV8M54WJ04',
#  'sub-NDARINVPKD1XX0E',
#  'sub-NDARINVPWWHBBJV',
#  'sub-NDARINVJ2TYM3HG',
#  'sub-NDARINV06DP74KL',
#  'sub-NDARINV3E6J6JJR',
#  'sub-NDARINVLDK00HZG',
#  'sub-NDARINVK9UVPE20',
#  'sub-NDARINV9ZMB5YUX',
#  'sub-NDARINVANDUZADC',
#  'sub-NDARINVXL4UCXMM',
#  'sub-NDARINV00CY2MDM',
#  'sub-NDARINV4EXN0D8M',
#  'sub-NDARINVY3YXX5T8',
#  'sub-NDARINVB0P6W6EC',
#  'sub-NDARINVK9E4206N',
#  'sub-NDARINVZ5T7BWT5',
#  'sub-NDARINVAHRMZ8T8',
#  'sub-NDARINVNU2URG3T',
#  'sub-NDARINVNDTALD7T',
#  'sub-NDARINVVD3KF4HE',
#  'sub-NDARINVRVM5WTB0',
#  'sub-NDARINV50WZX903',
#  'sub-NDARINVYWZBJ786',
#  'sub-NDARINVFB9M4ZBX',
#  'sub-NDARINVZU8PLK49',
#  'sub-NDARINVUFVGYBER',
#  'sub-NDARINVUTNUNCNK',
#  'sub-NDARINV1V7XPJKR',
#  'sub-NDARINV5PWUMKR0',
#  'sub-NDARINV8PHEF3UH',
#  'sub-NDARINVWMKGJZXX',
#  'sub-NDARINVCTY8WJMJ',
#  'sub-NDARINVZUKTAC4W',
#  'sub-NDARINV61VV3W6U',
#  'sub-NDARINVTANY2ML3',
#  'sub-NDARINVPGE70ZD4',
#  'sub-NDARINVG269TZZX',
#  'sub-NDARINV9BC4K3FV',
#  'sub-NDARINVEC4FTVA6',
#  'sub-NDARINVVT6N62X5',
#  'sub-NDARINVLMAAJ8JJ',
#  'sub-NDARINVHCG47NJV',
#  'sub-NDARINVJ8DDAHGM',
#  'sub-NDARINVXDNVH6WF',
#  'sub-NDARINV439CWGCM',
#  'sub-NDARINVNFVA3GM5',
#  'sub-NDARINVFHF15G0J',
#  'sub-NDARINVEUFTT1XU',
#  'sub-NDARINV4T1NP49C',
#  'sub-NDARINV581KGKG6',
#  'sub-NDARINVYEMHGFJF',
#  'sub-NDARINV79LWB567',
#  'sub-NDARINVWBE2PE0T',
#  'sub-NDARINV2VHU0WU5',
#  'sub-NDARINVGN54BJA4',
#  'sub-NDARINVX6J9RV2M',
#  'sub-NDARINV4HUTD0B9',
#  'sub-NDARINV1E4F8UMB',
#  'sub-NDARINVAWNDT22T',
#  'sub-NDARINVVY8RD656',
#  'sub-NDARINVPATP4RPG',
#  'sub-NDARINVV7RTRM32',
#  'sub-NDARINV2VD87TK5',
#  'sub-NDARINVCA5FDEFD',
#  'sub-NDARINV7Z8XPB8M',
#  'sub-NDARINVJDPCZE2H',
#  'sub-NDARINVNHW5VBD8',
#  'sub-NDARINVPENZ13BH',
#  'sub-NDARINVKK61BBH5',
#  'sub-NDARINV7WG3F8GT',
#  'sub-NDARINVPL7J5X85',
#  'sub-NDARINVZJUBWF3F',
#  'sub-NDARINVJ2Z7HTR6',
#  'sub-NDARINV6ZDALB3F',
#  'sub-NDARINV28NRLWRX',
#  'sub-NDARINVRRT6GJ3T',
#  'sub-NDARINV7TB8096T',
#  'sub-NDARINVLB1UUZT7',
#  'sub-NDARINV13276WYW',
#  'sub-NDARINVL63XHP8H',
#  'sub-NDARINVVB32WMEB',
#  'sub-NDARINV5HH9FDM1',
#  'sub-NDARINVP69PZ8N4',
#  'sub-NDARINV9LU6R773',
#  'sub-NDARINVH55KXYRL',
#  'sub-NDARINVCUDZ40WZ',
#  'sub-NDARINV17UL1T8L',
#  'sub-NDARINVXAPU8YP9',
#  'sub-NDARINVD0WWVAGX',
#  'sub-NDARINV8E597FU6',
#  'sub-NDARINVCFTDDBW7',
#  'sub-NDARINV5A2VREUG',
#  'sub-NDARINVTEB0VDTW',
#  'sub-NDARINVR9JZP8TC',
#  'sub-NDARINV1NZMD6UK',
#  'sub-NDARINVL0WTR0H9',
#  'sub-NDARINV8HCCN8CF',
#  'sub-NDARINVCTCGHXFZ',
#  'sub-NDARINV61RKCL4Y',
#  'sub-NDARINVG2PGTD44',
#  'sub-NDARINV2RB7270C',
#  'sub-NDARINV35E15ZE0',
#  'sub-NDARINVTYX16864',
#  'sub-NDARINVFY2VY166',
#  'sub-NDARINVGJMJAZ5P',
#  'sub-NDARINVC9GR4GM4',
#  'sub-NDARINVRXN9H1J6',
#  'sub-NDARINVT9E1CUGM',
#  'sub-NDARINVYXB3EL5M',
#  'sub-NDARINVHJX7K8DN',
#  'sub-NDARINVGA33T3P5',
#  'sub-NDARINVFA37LXB3',
#  'sub-NDARINVJTR7TBEP',
#  'sub-NDARINVR6PJMZ5P',
#  'sub-NDARINVUGT2AFVT',
#  'sub-NDARINVL6EFKUHV',
#  'sub-NDARINV9EVRB30H',
#  'sub-NDARINVKUWH9WHT',
#  'sub-NDARINV7ZN09VAT',
#  'sub-NDARINV4YPJW3P2',
#  'sub-NDARINV3C0FHDGM',
#  'sub-NDARINVC4MV1Y0C',
#  'sub-NDARINVC88CYTJE',
#  'sub-NDARINVK6U0AB4B',
#  'sub-NDARINVRUGEM9AA',
#  'sub-NDARINVE26BNZDK',
#  'sub-NDARINV9W9BF541',
#  'sub-NDARINVVNRTKY5K',
#  'sub-NDARINV9ZTXVA4J',
#  'sub-NDARINVWKV26ZEY',
#  'sub-NDARINVUU44L176',
#  'sub-NDARINVFNCXC6GH',
#  'sub-NDARINVLABCHP1W',
#  'sub-NDARINVUB8UKMXG',
#  'sub-NDARINVCXW3Y64K',
#  'sub-NDARINVVLC9RFM1',
#  'sub-NDARINVC9ZZ3NYD',
#  'sub-NDARINVC63Z86E8',
#  'sub-NDARINVKPH9VE20',
#  'sub-NDARINVKNU295WW',
#  'sub-NDARINVRCFHLNK7',
#  'sub-NDARINVBR1ZHAEJ',
#  'sub-NDARINV0YE7L9KU',
#  'sub-NDARINVBH7UHE62',
#  'sub-NDARINV2GDYKWG2',
#  'sub-NDARINVP6NAG8DY',
#  'sub-NDARINV15YZBNE0',
#  'sub-NDARINVYFRHV339',
#  'sub-NDARINV2H704HJD',
#  'sub-NDARINV0A4P0LWM',
#  'sub-NDARINVXJVE0AXP',
#  'sub-NDARINV61PF7E1L',
#  'sub-NDARINVMHCA4296',
#  'sub-NDARINVYX7ADDMR',
#  'sub-NDARINV2UR3G0TV',
#  'sub-NDARINVBRL2W991',
#  'sub-NDARINVF4P23JMZ',
#  'sub-NDARINV0LN1KD13',
#  'sub-NDARINV8NLT77TT',
#  'sub-NDARINVV7EUYJMM',
#  'sub-NDARINVKBGNJEVP',
#  'sub-NDARINVY03DJ9M0',
#  'sub-NDARINVFK3DP5LR',
#  'sub-NDARINVBUZ6HVF0',
#  'sub-NDARINVWY8VJ509',
#  'sub-NDARINVTMTWB0ZX',
#  'sub-NDARINV8ZCTKXDR',
#  'sub-NDARINV6U1YT1NL',
#  'sub-NDARINVUFFFFXBF',
#  'sub-NDARINVDJHUKGLH',
#  'sub-NDARINVFTJ00JVU',
#  'sub-NDARINVT5G6HNMZ',
#  'sub-NDARINVYKPWRXF2',
#  'sub-NDARINVUUP2MCRU',
#  'sub-NDARINVJDW2699M',
#  'sub-NDARINVEAY771YT',
#  'sub-NDARINV355PUM5E',
#  'sub-NDARINVE4V221E1',
#  'sub-NDARINVNHW1MYD8',
#  'sub-NDARINVBWJKR7B5',
#  'sub-NDARINVKXUNRZDG',
#  'sub-NDARINVMBB9TAJL',
#  'sub-NDARINVYBJPP4VV',
#  'sub-NDARINVURNYZ0V7',
#  'sub-NDARINVHYK6GFFE',
#  'sub-NDARINV9HVP5GZ1',
#  'sub-NDARINVHT9V9KV9',
#  'sub-NDARINV8AGDK03U',
#  'sub-NDARINV1YE699WK',
#  'sub-NDARINVM7LL5JGJ',
#  'sub-NDARINV6DC4XC3T',
#  'sub-NDARINVNE8U2H3X',
#  'sub-NDARINVX6WEX0YJ',
#  'sub-NDARINVBMKV8MN1',
#  'sub-NDARINVE6LJVFVY',
#  'sub-NDARINVZ04GJXZA',
#  'sub-NDARINVMJPLXBJT',
#  'sub-NDARINVV5Y81HT9',
#  'sub-NDARINV735T3VEK',
#  'sub-NDARINVV23Y1DXH',
#  'sub-NDARINVEF2EVE42',
#  'sub-NDARINVMKFGRBV4',
#  'sub-NDARINVXH4JV9XL',
#  'sub-NDARINVFJP3171C',
#  'sub-NDARINVTTNVZVLW',
#  'sub-NDARINVVZXGPU1H',
#  'sub-NDARINVCJH4YEDW',
#  'sub-NDARINV6Y7LCCWT',
#  'sub-NDARINV4AGK770Z',
#  'sub-NDARINV20KZBB9N',
#  'sub-NDARINV85UUUHN0',
#  'sub-NDARINVN2MD051W',
#  'sub-NDARINVL1GA12Y1',
#  'sub-NDARINVC4GYKW12',
#  'sub-NDARINV182YC0D9',
#  'sub-NDARINVKRG5L5EG',
#  'sub-NDARINVVM3WVMV7',
#  'sub-NDARINV5JE05DJK',
#  'sub-NDARINVWBEMY06N',
#  'sub-NDARINVM6VG3Z7Y',
#  'sub-NDARINV8Z59C4WA',
#  'sub-NDARINV0WELU60J',
#  'sub-NDARINV9JLEZ6WE',
#  'sub-NDARINV5VRKLMXL',
#  'sub-NDARINVAWA5076Z',
#  'sub-NDARINVN4YXHNL8',
#  'sub-NDARINV9924G4W9',
#  'sub-NDARINVNC7PM9RJ',
#  'sub-NDARINVKR81E1T7',
#  'sub-NDARINV625BWGDB',
#  'sub-NDARINVUU2N14ZU',
#  'sub-NDARINVM2BH35YN',
#  'sub-NDARINVNYP48E8M',
#  'sub-NDARINVV0L5J7B4',
#  'sub-NDARINVXAF2R3YX',
#  'sub-NDARINVEJ8M7WJ8',
#  'sub-NDARINV2X02MDU2',
#  'sub-NDARINVRFNHTDPM',
#  'sub-NDARINV3KBYKMJ2',
#  'sub-NDARINV5VD5LWH4',
#  'sub-NDARINVJMLDL425',
#  'sub-NDARINVAM8K670H',
#  'sub-NDARINVKXCAUBG6',
#  'sub-NDARINVMM3Y00ZD',
#  'sub-NDARINV2TBMGWU5',
#  'sub-NDARINVA7PB1MWM',
#  'sub-NDARINVMZLYE6WZ',
#  'sub-NDARINV808X1WYW',
#  'sub-NDARINV8NBF737P',
#  'sub-NDARINVUXMACPNB',
#  'sub-NDARINV78R9N2X5',
#  'sub-NDARINVY5XMUWB0',
#  'sub-NDARINVK9MXKUUB',
#  'sub-NDARINVM278A3KW',
#  'sub-NDARINVTU1DE4PM',
#  'sub-NDARINV2NMMXZ45',
#  'sub-NDARINVF548JWWW',
#  'sub-NDARINV95EC7CAZ',
#  'sub-NDARINVZPEKP3FW',
#  'sub-NDARINV6XNGNVUC',
#  'sub-NDARINV78YTP5L9',
#  'sub-NDARINVXRP6TZGT',
#  'sub-NDARINVAHBX7CYX',
#  'sub-NDARINVX9XKM89P',
#  'sub-NDARINVLT4KYA8H',
#  'sub-NDARINVT9DL54AF',
#  'sub-NDARINVECC0UT5E',
#  'sub-NDARINVCFCXNV7G',
#  'sub-NDARINVGY4WAXPR',
#  'sub-NDARINVXGPKHPUV',
#  'sub-NDARINVUTVE98D5',
#  'sub-NDARINVG47HFECU',
#  'sub-NDARINVZJKN66UT',
#  'sub-NDARINVJ7L6EW0J',
#  'sub-NDARINV0H05G0TR',
#  'sub-NDARINV32P8UGE7',
#  'sub-NDARINVAYDXW667',
#  'sub-NDARINV12F1NWCG',
#  'sub-NDARINV2YHU3XBN',
#  'sub-NDARINV2DBPLRUD',
#  'sub-NDARINVRBTUEV72',
#  'sub-NDARINVKX21XUNJ',
#  'sub-NDARINVAED2T8J0',
#  'sub-NDARINV2W4HNGV7',
#  'sub-NDARINV1AYXT588',
#  'sub-NDARINVF5JET3CJ',
#  'sub-NDARINV0G42TBW1',
#  'sub-NDARINV7J3KXGBK',
#  'sub-NDARINVGKARWYND',
#  'sub-NDARINV8J9WC4XB',
#  'sub-NDARINVAN03AH80',
#  'sub-NDARINVJT03Z8N3',
#  'sub-NDARINV898CW3V8',
#  'sub-NDARINV3CJ9GXRL',
#  'sub-NDARINVMC12A6UB',
#  'sub-NDARINVG5PC310E',
#  'sub-NDARINVU1THG28C',
#  'sub-NDARINVAR03WFKR',
#  'sub-NDARINVNCM6KXZT',
#  'sub-NDARINVCR7WRBTX',
#  'sub-NDARINVMLU3DJN0',
#  'sub-NDARINVKZT2PNJK',
#  'sub-NDARINVUG6DTWVU',
#  'sub-NDARINV8FHKFFRM',
#  'sub-NDARINVP1BMWBHG',
#  'sub-NDARINV7HLNGBZN',
#  'sub-NDARINVU2JURFC1',
#  'sub-NDARINVG2K6ZE55',
#  'sub-NDARINVUZAZXB08',
#  'sub-NDARINVCKTT8HAT',
#  'sub-NDARINVXF8CMXGC',
#  'sub-NDARINVUJ6PGMCW',
#  'sub-NDARINV6BVU3BDR',
#  'sub-NDARINVV1LRPT07',
#  'sub-NDARINVZG6365BX',
#  'sub-NDARINV5K62JDBR',
#  'sub-NDARINVADW3JCNG',
#  'sub-NDARINVY84DY6RU',
#  'sub-NDARINVM4D87T1B',
#  'sub-NDARINVDDKF5HBX',
#  'sub-NDARINV9N895VTP',
#  'sub-NDARINV8J86AFF3',
#  'sub-NDARINVN31J6BXZ',
#  'sub-NDARINVT88PYFND',
#  'sub-NDARINVNEMEFF9L',
#  'sub-NDARINV44AXV5FM',
#  'sub-NDARINVYACN0D32',
#  'sub-NDARINV0APJMRD1',
#  'sub-NDARINVKWEP6GVC',
#  'sub-NDARINVWLAN2765',
#  'sub-NDARINV6L7B1GX3',
#  'sub-NDARINVKX00T99C',
#  'sub-NDARINVHMFGD3EC',
#  'sub-NDARINVZVYCX57J',
#  'sub-NDARINVUKT3Y1U0',
#  'sub-NDARINVJWAPD83W',
#  'sub-NDARINV82HYA45D',
#  'sub-NDARINVC4HPTXKN',
#  'sub-NDARINVNZZPEY3P',
#  'sub-NDARINVNXE35ZCX',
#  'sub-NDARINVZV8YW4NC',
#  'sub-NDARINVWLX2MF41',
#  'sub-NDARINVZDC9G098',
#  'sub-NDARINVK6W4APWD',
#  'sub-NDARINV6XE6J751',
#  'sub-NDARINV65NLFHYD',
#  'sub-NDARINVX8PGW7RC',
#  'sub-NDARINVX8D3JRAH',
#  'sub-NDARINVK832EFEE',
#  'sub-NDARINVRC238TRX',
#  'sub-NDARINV84V3NTN5',
#  'sub-NDARINVED05HV5A',
#  'sub-NDARINVJHEF7HG0',
#  'sub-NDARINVBK5APVLC',
#  'sub-NDARINV5MRTJNYU',
#  'sub-NDARINVPUYA9796',
#  'sub-NDARINVCV07Y8GY',
#  'sub-NDARINV7K1MZVU9',
#  'sub-NDARINV3F5L113U',
#  'sub-NDARINVURX0F423',
#  'sub-NDARINVDXEP8X66',
#  'sub-NDARINVAGGKXW0P',
#  'sub-NDARINVRL863G1R',
#  'sub-NDARINVRHKAEMD9',
#  'sub-NDARINV3KZATZ7M',
#  'sub-NDARINVK1WPW1EZ',
#  'sub-NDARINV3TUE7DV5',
#  'sub-NDARINV0FBX6KWX',
#  'sub-NDARINVXEG4M9UL',
#  'sub-NDARINVE2JXEZ3N',
#  'sub-NDARINVA9REPBD4',
#  'sub-NDARINVT83A7WN8',
#  'sub-NDARINVZ0MP06TT',
#  'sub-NDARINV56P2568B',
#  'sub-NDARINV4CKYEHYL',
#  'sub-NDARINVM2EJE47J',
#  'sub-NDARINVDPYR4KM2',
#  'sub-NDARINVU3M4BG5Y',
#  'sub-NDARINVJPA3LE7X',
#  'sub-NDARINVL7GG9GJV',
#  'sub-NDARINVX67A1GFL',
#  'sub-NDARINVXZ44NE7H',
#  'sub-NDARINVT1JDV64B',
#  'sub-NDARINV7CC21C8B',
#  'sub-NDARINVWBLWK0A5',
#  'sub-NDARINV4M8H34KB',
#  'sub-NDARINVNXXDV17F',
#  'sub-NDARINVUELN86MB',
#  'sub-NDARINV6ARV4JZP',
#  'sub-NDARINVHNR4UJ6G',
#  'sub-NDARINV7V10F8LD',
#  'sub-NDARINVC5H2UXTA',
#  'sub-NDARINVCE0TWGXM',
#  'sub-NDARINVHZ7D1EYU',
#  'sub-NDARINVN6EULLPB',
#  'sub-NDARINVBVYD3AAF',
#  'sub-NDARINV6KCMKK84',
#  'sub-NDARINVXUT1RZUJ',
#  'sub-NDARINVW4PDFHV1',
#  'sub-NDARINV4UYK50KN',
#  'sub-NDARINV1PE2WZWB',
#  'sub-NDARINVMCBYJEV4',
#  'sub-NDARINV23PJ8ECJ',
#  'sub-NDARINVYLMRXPYA',
#  'sub-NDARINVE4NE0L80',
#  'sub-NDARINV64GKZ96V',
#  'sub-NDARINVU8D4R4YF',
#  'sub-NDARINVXMWVP3Y9',
#  'sub-NDARINVB5PN305C',
#  'sub-NDARINVB1DNH7JC',
#  'sub-NDARINVG4HBU1Y0',
#  'sub-NDARINV18H0Y70H',
#  'sub-NDARINVUR7GBKPR',
#  'sub-NDARINVE3DYU63E',
#  'sub-NDARINV3YBDL5L3',
#  'sub-NDARINVZEKA1L7D',
#  'sub-NDARINV57F63WRL',
#  'sub-NDARINVPTL6W25B',
#  'sub-NDARINVUYF7JD2E',
#  'sub-NDARINVP4YPBFFH',
#  'sub-NDARINVD1EMLDV6',
#  'sub-NDARINV09VBPCLU',
#  'sub-NDARINVT4BR7L9V',
#  'sub-NDARINVDMXMW991',
#  'sub-NDARINVLKEDD3PV',
#  'sub-NDARINVNYNVR7NV',
#  'sub-NDARINVN1VPLV83',
#  'sub-NDARINVYZJRWG4A',
#  'sub-NDARINV3617ZB48',
#  'sub-NDARINVP74XG4NJ',
#  'sub-NDARINVRGF2CX0R',
#  'sub-NDARINVEWYRM0KZ',
#  'sub-NDARINV324JE1UG',
#  'sub-NDARINVAWAEU3P4',
#  'sub-NDARINV0E350J5D',
#  'sub-NDARINV5C9WJ4B3',
#  'sub-NDARINVY09XGV2D',
#  'sub-NDARINV4DPTUVZ7',
#  'sub-NDARINV6R64U2H8',
#  'sub-NDARINVXGK0BB15',
#  'sub-NDARINVPH3LCEGR',
#  'sub-NDARINVXWG8C94J',
#  'sub-NDARINVZTP2ZHLN',
#  'sub-NDARINVAHREHU85',
#  'sub-NDARINVRP56XWD8',
#  'sub-NDARINVX329JYUJ',
#  'sub-NDARINVRHX34P95',
#  'sub-NDARINV3DDJKN73',
#  'sub-NDARINVTEL35LKE',
#  'sub-NDARINVNE5HMEV6',
#  'sub-NDARINVZ7FR6UCT',
#  'sub-NDARINVHR1HZ6FC',
#  'sub-NDARINVTCJ78M4K',
#  'sub-NDARINVM38PWW4W',
#  'sub-NDARINVX1RAFVJ4',
#  'sub-NDARINVDGP58A6H',
#  'sub-NDARINVW7YX6WG3',
#  'sub-NDARINVK10RYUC1',
#  'sub-NDARINVXPGNE2W4',
#  'sub-NDARINV2L2B6VXP',
#  'sub-NDARINV2XAHZZ2A',
#  'sub-NDARINV0FV544H9',
#  'sub-NDARINVCGXC468Y',
#  'sub-NDARINV7AWGW55P',
#  'sub-NDARINVV30162D6',
#  'sub-NDARINVFF01R0CH',
#  'sub-NDARINV5UABVWT2',
#  'sub-NDARINV6H4LKF9P',
#  'sub-NDARINVUD0M0169',
#  'sub-NDARINV4EHL4L0L',
#  'sub-NDARINV0PDYPPJ7',
#  'sub-NDARINV1Y40DZT8',
#  'sub-NDARINVG9W26JX4',
#  'sub-NDARINV5F786HZ9',
#  'sub-NDARINVBNXAAKCX',
#  'sub-NDARINV0MCARYLD',
#  'sub-NDARINVAPJKJ5KB',
#  'sub-NDARINVAAV56RVU',
#  'sub-NDARINVTZUFYJ76',
#  ...]

# %%
[x for x in list_subjects if not'sub' in x]
# Out:
# []

# %%
qc = pd.DataFrame(list_subjects, columns=["participant_id"]).set_index("participant_id")

# %%
qc["qc"] = 1
qc["comments"] =  ""

# %%
qc.head()
# Out:
#                      qc comments
# participant_id
# sub-NDARINVLVJNK52B   1
# sub-NDARINVG7B119A0   1
# sub-NDARINVTFPAU4FF   1
# sub-NDARINVZ5G203VB   1
# sub-NDARINVYPZAV10C   1

# %%
qc["qc"] = 1
qc["comments"] =  ""

for f, s in zip(list_folders, list_subjects):
    path_to_graph = f"{f}/{subpath}"

    # Checks of left graph exists
    graph_file = f"{path_to_graph}/L{s}.arg"
    if not os.path.isfile(graph_file):
        print(f"\nL{s}.arg does not exist")
        qc.loc[s, "qc"] = 0
        qc.loc[s, "comments"] = "Left graph does not exist"

    
    graph_file = f"{path_to_graph}/R{s}.arg"
    if not os.path.isfile(graph_file):
        print(f"\nR{s}.arg does not exist")
        qc.loc[s, "qc"] = 0
        qc.loc[s, "comments"] = "Right graph does not exist"

    if qc.loc[s, "qc"] == 1:
        print('.', end='')
# Out:
# ....................
# Lsub-NDARINVTHWNZF8Y.arg does not exist
#
# Rsub-NDARINVTHWNZF8Y.arg does not exist
# ..........
# Lsub-NDARINVZZNX6W2P.arg does not exist
#
# Rsub-NDARINVZZNX6W2P.arg does not exist
# ..
# Lsub-NDARINVBZBW11DL.arg does not exist
#
# Rsub-NDARINVBZBW11DL.arg does not exist
# ......
# Lsub-NDARINVGLTMA4LA.arg does not exist
#
# Rsub-NDARINVGLTMA4LA.arg does not exist
# ...................
# Lsub-NDARINVBUPMZF11.arg does not exist
#
# Rsub-NDARINVBUPMZF11.arg does not exist
# ....................................
# Lsub-NDARINVP3NFD934.arg does not exist
#
# Rsub-NDARINVP3NFD934.arg does not exist
# ......
# Lsub-NDARINVUFF64VGJ.arg does not exist
#
# Rsub-NDARINVUFF64VGJ.arg does not exist
# ..................
# Lsub-NDARINV1AA2VG9C.arg does not exist
#
# Rsub-NDARINV1AA2VG9C.arg does not exist
# .
# Lsub-NDARINVU46YJV27.arg does not exist
#
# Rsub-NDARINVU46YJV27.arg does not exist
# ..........
# Lsub-NDARINVJM19UTB0.arg does not exist
#
# Rsub-NDARINVJM19UTB0.arg does not exist
# ..
# Lsub-NDARINV49EG90M3.arg does not exist
#
# Rsub-NDARINV49EG90M3.arg does not exist
# ..
# Lsub-NDARINV1P7L5P3B.arg does not exist
#
# Rsub-NDARINV1P7L5P3B.arg does not exist
# .....
# Lsub-NDARINVFBEG8E1Z.arg does not exist
#
# Rsub-NDARINVFBEG8E1Z.arg does not exist
# .....
# Lsub-NDARINV0CV2Y4YR.arg does not exist
#
# Rsub-NDARINV0CV2Y4YR.arg does not exist
# ......
# Lsub-NDARINVY61UGEKY.arg does not exist
#
# Rsub-NDARINVY61UGEKY.arg does not exist
# .........
# Lsub-NDARINV3XZKYEVA.arg does not exist
#
# Rsub-NDARINV3XZKYEVA.arg does not exist
# .........
# Lsub-NDARINV1ZPJCKVC.arg does not exist
#
# Rsub-NDARINV1ZPJCKVC.arg does not exist
# .....
# Lsub-NDARINVG0ZNL58U.arg does not exist
#
# Rsub-NDARINVG0ZNL58U.arg does not exist
# ..........................
# Lsub-NDARINVTA7NT65Z.arg does not exist
#
# Rsub-NDARINVTA7NT65Z.arg does not exist
# .....
# Lsub-NDARINVBZKEHZY8.arg does not exist
#
# Rsub-NDARINVBZKEHZY8.arg does not exist
#
# Lsub-NDARINVFX004DUH.arg does not exist
#
# Rsub-NDARINVFX004DUH.arg does not exist
# .....................................
# Lsub-NDARINVLXZ3RPWB.arg does not exist
#
# Rsub-NDARINVLXZ3RPWB.arg does not exist
# .................................
# Lsub-NDARINV4T71DFV4.arg does not exist
#
# Rsub-NDARINV4T71DFV4.arg does not exist
# ..............................
# Lsub-NDARINVT96B8JHC.arg does not exist
#
# Rsub-NDARINVT96B8JHC.arg does not exist
# ...
# Lsub-NDARINVGD6JWJWD.arg does not exist
#
# Rsub-NDARINVGD6JWJWD.arg does not exist
# ................................
# Lsub-NDARINV14UJARAJ.arg does not exist
#
# Rsub-NDARINV14UJARAJ.arg does not exist
# ...............................................
# Lsub-NDARINVXYF9FXT8.arg does not exist
#
# Rsub-NDARINVXYF9FXT8.arg does not exist
#
# Lsub-NDARINVK4H5ZTFE.arg does not exist
#
# Rsub-NDARINVK4H5ZTFE.arg does not exist
# .........
# Lsub-NDARINV0W4PR2WT.arg does not exist
#
# Rsub-NDARINV0W4PR2WT.arg does not exist
# ....
# Lsub-NDARINVRE317TA3.arg does not exist
#
# Rsub-NDARINVRE317TA3.arg does not exist
# ............
# Lsub-NDARINVFP8B264R.arg does not exist
#
# Rsub-NDARINVFP8B264R.arg does not exist
#
# Lsub-NDARINV25KAJM0U.arg does not exist
#
# Rsub-NDARINV25KAJM0U.arg does not exist
# ..
# Lsub-NDARINVAHDU5HRW.arg does not exist
#
# Rsub-NDARINVAHDU5HRW.arg does not exist
#
# Lsub-NDARINVKZW3CU83.arg does not exist
#
# Rsub-NDARINVKZW3CU83.arg does not exist
# .
# Lsub-NDARINVLBZW40WR.arg does not exist
#
# Rsub-NDARINVLBZW40WR.arg does not exist
# ..........................................
# Lsub-NDARINVJK6VB601.arg does not exist
#
# Rsub-NDARINVJK6VB601.arg does not exist
# ................
# Lsub-NDARINV70EJ1089.arg does not exist
#
# Rsub-NDARINV70EJ1089.arg does not exist
# ...
# Lsub-NDARINV6TM6V4CG.arg does not exist
#
# Rsub-NDARINV6TM6V4CG.arg does not exist
# ........
# Lsub-NDARINVC5KPLUZ5.arg does not exist
#
# Rsub-NDARINVC5KPLUZ5.arg does not exist
# .........
# Lsub-NDARINVANDUZADC.arg does not exist
#
# Rsub-NDARINVANDUZADC.arg does not exist
# .
# Lsub-NDARINV00CY2MDM.arg does not exist
#
# Rsub-NDARINV00CY2MDM.arg does not exist
# ....
# Lsub-NDARINVZ5T7BWT5.arg does not exist
#
# Rsub-NDARINVZ5T7BWT5.arg does not exist
# ...........
# Lsub-NDARINV1V7XPJKR.arg does not exist
#
# Rsub-NDARINV1V7XPJKR.arg does not exist
# ....
# Lsub-NDARINVZUKTAC4W.arg does not exist
#
# Rsub-NDARINVZUKTAC4W.arg does not exist
# ......................
# Lsub-NDARINVX6J9RV2M.arg does not exist
#
# Rsub-NDARINVX6J9RV2M.arg does not exist
# .......................
# Lsub-NDARINVL63XHP8H.arg does not exist
#
# Rsub-NDARINVL63XHP8H.arg does not exist
#
# Lsub-NDARINVVB32WMEB.arg does not exist
#
# Rsub-NDARINVVB32WMEB.arg does not exist
# ................................................
# Lsub-NDARINVWKV26ZEY.arg does not exist
#
# Rsub-NDARINVWKV26ZEY.arg does not exist
# ...
# Lsub-NDARINVUB8UKMXG.arg does not exist
#
# Rsub-NDARINVUB8UKMXG.arg does not exist
# ..........
# Lsub-NDARINV2GDYKWG2.arg does not exist
#
# Rsub-NDARINV2GDYKWG2.arg does not exist
# .....
# Lsub-NDARINVXJVE0AXP.arg does not exist
#
# Rsub-NDARINVXJVE0AXP.arg does not exist
# .....
# Lsub-NDARINVF4P23JMZ.arg does not exist
#
# Rsub-NDARINVF4P23JMZ.arg does not exist
# ............................................
# Lsub-NDARINVMKFGRBV4.arg does not exist
#
# Rsub-NDARINVMKFGRBV4.arg does not exist
# ........
# Lsub-NDARINV85UUUHN0.arg does not exist
#
# Rsub-NDARINV85UUUHN0.arg does not exist
# .............
# Lsub-NDARINVAWA5076Z.arg does not exist
#
# Rsub-NDARINVAWA5076Z.arg does not exist
# .............
# Lsub-NDARINV3KBYKMJ2.arg does not exist
#
# Rsub-NDARINV3KBYKMJ2.arg does not exist
# ..
# Lsub-NDARINVAM8K670H.arg does not exist
#
# Rsub-NDARINVAM8K670H.arg does not exist
# ........................................
# Lsub-NDARINVAED2T8J0.arg does not exist
#
# Rsub-NDARINVAED2T8J0.arg does not exist
# ............
# Lsub-NDARINVG5PC310E.arg does not exist
#
# Rsub-NDARINVG5PC310E.arg does not exist
# ...
# Lsub-NDARINVCR7WRBTX.arg does not exist
#
# Rsub-NDARINVCR7WRBTX.arg does not exist
# ..............
# Lsub-NDARINVZG6365BX.arg does not exist
#
# Rsub-NDARINVZG6365BX.arg does not exist
# ......
# Lsub-NDARINV8J86AFF3.arg does not exist
#
# Rsub-NDARINV8J86AFF3.arg does not exist
# ......
# Lsub-NDARINVKWEP6GVC.arg does not exist
#
# Rsub-NDARINVKWEP6GVC.arg does not exist
# .....
# Lsub-NDARINVUKT3Y1U0.arg does not exist
#
# Rsub-NDARINVUKT3Y1U0.arg does not exist
# ..........
# Lsub-NDARINV65NLFHYD.arg does not exist
#
# Rsub-NDARINV65NLFHYD.arg does not exist
# ........
# Lsub-NDARINV5MRTJNYU.arg does not exist
#
# Rsub-NDARINV5MRTJNYU.arg does not exist
# ...
# Lsub-NDARINV3F5L113U.arg does not exist
#
# Rsub-NDARINV3F5L113U.arg does not exist
# .........
# Lsub-NDARINVXEG4M9UL.arg does not exist
#
# Rsub-NDARINVXEG4M9UL.arg does not exist
# ..........................................
# Lsub-NDARINV18H0Y70H.arg does not exist
#
# Rsub-NDARINV18H0Y70H.arg does not exist
# .....
# Lsub-NDARINVPTL6W25B.arg does not exist
#
# Rsub-NDARINVPTL6W25B.arg does not exist
# ....................................
# Lsub-NDARINVX1RAFVJ4.arg does not exist
#
# Rsub-NDARINVX1RAFVJ4.arg does not exist
# .........................
# Lsub-NDARINV1555HTEC.arg does not exist
#
# Rsub-NDARINV1555HTEC.arg does not exist
# ......................
# Lsub-NDARINVAF722ZVJ.arg does not exist
#
# Rsub-NDARINVAF722ZVJ.arg does not exist
# .....
# Lsub-NDARINVBG040P9Z.arg does not exist
#
# Rsub-NDARINVBG040P9Z.arg does not exist
# .....
# Lsub-NDARINVA8J2VT49.arg does not exist
#
# Rsub-NDARINVA8J2VT49.arg does not exist
# .............................................
# Lsub-NDARINVTAV7MB4T.arg does not exist
#
# Rsub-NDARINVTAV7MB4T.arg does not exist
# .......
# Lsub-NDARINV7E8WJTYE.arg does not exist
#
# Rsub-NDARINV7E8WJTYE.arg does not exist
# .............
# Lsub-NDARINVFAYYH7CJ.arg does not exist
#
# Rsub-NDARINVFAYYH7CJ.arg does not exist
# ........
# Lsub-NDARINV4CLN1AC5.arg does not exist
#
# Rsub-NDARINV4CLN1AC5.arg does not exist
# ..................
# Lsub-NDARINVTGXYZJTP.arg does not exist
#
# Rsub-NDARINVTGXYZJTP.arg does not exist
# ..........
# Lsub-NDARINVAXXG3HHV.arg does not exist
#
# Rsub-NDARINVAXXG3HHV.arg does not exist
# ...........
# Lsub-NDARINV97K3KGF4.arg does not exist
#
# Rsub-NDARINV97K3KGF4.arg does not exist
# .......
# Lsub-NDARINVT6XZEJHF.arg does not exist
#
# Rsub-NDARINVT6XZEJHF.arg does not exist
# .........
# Lsub-NDARINV059VLAHF.arg does not exist
#
# Rsub-NDARINV059VLAHF.arg does not exist
# .........
# Lsub-NDARINV7R9KB5XY.arg does not exist
#
# Rsub-NDARINV7R9KB5XY.arg does not exist
# ........................
# Lsub-NDARINVJ3X1G87Z.arg does not exist
#
# Rsub-NDARINVJ3X1G87Z.arg does not exist
# .....
# Lsub-NDARINVKHC499NA.arg does not exist
#
# Rsub-NDARINVKHC499NA.arg does not exist
# ...
# Lsub-NDARINVFCN9U0EN.arg does not exist
#
# Rsub-NDARINVFCN9U0EN.arg does not exist
# ............
# Lsub-NDARINVUH0F2U1W.arg does not exist
#
# Rsub-NDARINVUH0F2U1W.arg does not exist
# .
# Lsub-NDARINV2GAAH0E9.arg does not exist
#
# Rsub-NDARINV2GAAH0E9.arg does not exist
# ..
# Lsub-NDARINVG8NL3R9N.arg does not exist
#
# Rsub-NDARINVG8NL3R9N.arg does not exist
#
# Lsub-NDARINV5VT1M6LF.arg does not exist
#
# Rsub-NDARINV5VT1M6LF.arg does not exist
# ....
# Lsub-NDARINV8M1KK4KX.arg does not exist
#
# Rsub-NDARINV8M1KK4KX.arg does not exist
# ....
# Lsub-NDARINV1XDPJKBE.arg does not exist
#
# Rsub-NDARINV1XDPJKBE.arg does not exist
# ...............
# Lsub-NDARINV32CJUUBP.arg does not exist
#
# Rsub-NDARINV32CJUUBP.arg does not exist
# ..
# Lsub-NDARINV2KJNX54B.arg does not exist
#
# Rsub-NDARINV2KJNX54B.arg does not exist
# ................
# Lsub-NDARINVPDW73ZHF.arg does not exist
#
# Rsub-NDARINVPDW73ZHF.arg does not exist
# ...
# Lsub-NDARINVPX2DGJHP.arg does not exist
#
# Rsub-NDARINVPX2DGJHP.arg does not exist
# .
# Lsub-NDARINV08AT7TLH.arg does not exist
#
# Rsub-NDARINV08AT7TLH.arg does not exist
# .
# Lsub-NDARINV45ZYAREH.arg does not exist
#
# Rsub-NDARINV45ZYAREH.arg does not exist
# ..
# Lsub-NDARINV5NZW4ZBJ.arg does not exist
#
# Rsub-NDARINV5NZW4ZBJ.arg does not exist
# ....
# Lsub-NDARINVE4T6ZUA5.arg does not exist
#
# Rsub-NDARINVE4T6ZUA5.arg does not exist
# ............
# Lsub-NDARINVHBCXW11P.arg does not exist
#
# Rsub-NDARINVHBCXW11P.arg does not exist
# .............................
# Lsub-NDARINVWH7LABN8.arg does not exist
#
# Rsub-NDARINVWH7LABN8.arg does not exist
# .................................................
# Lsub-NDARINV1R36G2UH.arg does not exist
#
# Rsub-NDARINV1R36G2UH.arg does not exist
# ........
# Lsub-NDARINV0HFHMCFZ.arg does not exist
#
# Rsub-NDARINV0HFHMCFZ.arg does not exist
# .........................
# Lsub-NDARINV3KYJ3920.arg does not exist
#
# Rsub-NDARINV3KYJ3920.arg does not exist
# ..........................
# Lsub-NDARINVMMLVDCJH.arg does not exist
#
# Rsub-NDARINVMMLVDCJH.arg does not exist
# ....
# Lsub-NDARINVJJURZC29.arg does not exist
#
# Rsub-NDARINVJJURZC29.arg does not exist
# ...................
# Lsub-NDARINV4B0U03EB.arg does not exist
#
# Rsub-NDARINV4B0U03EB.arg does not exist
# ...
# Lsub-NDARINV3WDYMBWU.arg does not exist
#
# Rsub-NDARINV3WDYMBWU.arg does not exist
# ................
# Lsub-NDARINVA928P6B7.arg does not exist
#
# Rsub-NDARINVA928P6B7.arg does not exist
# .
# Lsub-NDARINV0LDK94T8.arg does not exist
#
# Rsub-NDARINV0LDK94T8.arg does not exist
# ........................
# Lsub-NDARINV4MEF6MVP.arg does not exist
#
# Rsub-NDARINV4MEF6MVP.arg does not exist
# .
# Lsub-NDARINVVG3X2TFW.arg does not exist
#
# Rsub-NDARINVVG3X2TFW.arg does not exist
# ....
# Lsub-NDARINVT21R0YG4.arg does not exist
#
# Rsub-NDARINVT21R0YG4.arg does not exist
# ..
# Lsub-NDARINVTC7KEJAP.arg does not exist
#
# Rsub-NDARINVTC7KEJAP.arg does not exist
# ....
# Lsub-NDARINVFZY230ME.arg does not exist
#
# Rsub-NDARINVFZY230ME.arg does not exist
# .................................
# Lsub-NDARINVC39CENF6.arg does not exist
#
# Rsub-NDARINVC39CENF6.arg does not exist
#
# Lsub-NDARINVA7CLY4PL.arg does not exist
#
# Rsub-NDARINVA7CLY4PL.arg does not exist
# ......................
# Lsub-NDARINVL7KKBD44.arg does not exist
#
# Rsub-NDARINVL7KKBD44.arg does not exist
# .....
# Lsub-NDARINV1PYEEE1R.arg does not exist
#
# Rsub-NDARINV1PYEEE1R.arg does not exist
# ................
# Lsub-NDARINVK334BG3U.arg does not exist
#
# Rsub-NDARINVK334BG3U.arg does not exist
# ................
# Lsub-NDARINV7GGXBFFE.arg does not exist
#
# Rsub-NDARINV7GGXBFFE.arg does not exist
# ......
# Lsub-NDARINVDPM9DWBB.arg does not exist
#
# Rsub-NDARINVDPM9DWBB.arg does not exist
#
# Lsub-NDARINV08P3GNDV.arg does not exist
#
# Rsub-NDARINV08P3GNDV.arg does not exist
# .
# Lsub-NDARINV2LL2Y78J.arg does not exist
#
# Rsub-NDARINV2LL2Y78J.arg does not exist
# ........
# Lsub-NDARINV1PX9GGJP.arg does not exist
#
# Rsub-NDARINV1PX9GGJP.arg does not exist
# .
# Lsub-NDARINV22F4J621.arg does not exist
#
# Rsub-NDARINV22F4J621.arg does not exist
# ....
# Lsub-NDARINVDV5217A4.arg does not exist
#
# Rsub-NDARINVDV5217A4.arg does not exist
# .............................
# Lsub-NDARINV4B1YV01D.arg does not exist
#
# Rsub-NDARINV4B1YV01D.arg does not exist
# ..........
# Lsub-NDARINVTF8HPRGG.arg does not exist
#
# Rsub-NDARINVTF8HPRGG.arg does not exist
# ................
# Lsub-NDARINV619DWVEK.arg does not exist
#
# Rsub-NDARINV619DWVEK.arg does not exist
# ........
# Lsub-NDARINVRVCMVEY9.arg does not exist
#
# Rsub-NDARINVRVCMVEY9.arg does not exist
# ...................
# Lsub-NDARINV5MFBJTBG.arg does not exist
#
# Rsub-NDARINV5MFBJTBG.arg does not exist
# .........
# Lsub-NDARINVXV7GLFGG.arg does not exist
#
# Rsub-NDARINVXV7GLFGG.arg does not exist
# ............
# Lsub-NDARINV5R386XD4.arg does not exist
#
# Rsub-NDARINV5R386XD4.arg does not exist
# ..
# Lsub-NDARINVXK52H154.arg does not exist
#
# Rsub-NDARINVXK52H154.arg does not exist
# ......
# Lsub-NDARINVUB6TZMWL.arg does not exist
#
# Rsub-NDARINVUB6TZMWL.arg does not exist
# ..................
# Lsub-NDARINVGC4RRGD2.arg does not exist
#
# Rsub-NDARINVGC4RRGD2.arg does not exist
# .........
# Lsub-NDARINVRNG7B964.arg does not exist
#
# Rsub-NDARINVRNG7B964.arg does not exist
# ....
# Lsub-NDARINVNUNMDE7M.arg does not exist
#
# Rsub-NDARINVNUNMDE7M.arg does not exist
# ..........
# Lsub-NDARINVLGBWLRM4.arg does not exist
#
# Rsub-NDARINVLGBWLRM4.arg does not exist
# ...
# Lsub-NDARINVEDNJMEJ0.arg does not exist
#
# Rsub-NDARINVEDNJMEJ0.arg does not exist
# .
# Lsub-NDARINVF504BFVB.arg does not exist
#
# Rsub-NDARINVF504BFVB.arg does not exist
# ...
# Lsub-NDARINVYE30YAL9.arg does not exist
#
# Rsub-NDARINVYE30YAL9.arg does not exist
# .....
# Lsub-NDARINVK2M95XYW.arg does not exist
#
# Rsub-NDARINVK2M95XYW.arg does not exist
# ......
# Lsub-NDARINVNMHULM8G.arg does not exist
#
# Rsub-NDARINVNMHULM8G.arg does not exist
# ..................
# Lsub-NDARINVHNT0B9EC.arg does not exist
#
# Rsub-NDARINVHNT0B9EC.arg does not exist
# ...................
# Lsub-NDARINV7YKXALB5.arg does not exist
#
# Rsub-NDARINV7YKXALB5.arg does not exist
# ......
# Lsub-NDARINV1415W413.arg does not exist
#
# Rsub-NDARINV1415W413.arg does not exist
# ....
# Lsub-NDARINVZLL8B2MA.arg does not exist
#
# Rsub-NDARINVZLL8B2MA.arg does not exist
# ...........
# Lsub-NDARINVUWNVH2C7.arg does not exist
#
# Rsub-NDARINVUWNVH2C7.arg does not exist
# ......
# Lsub-NDARINV6HVN64HM.arg does not exist
#
# Rsub-NDARINV6HVN64HM.arg does not exist
# ......
# Lsub-NDARINV9H4U1DHY.arg does not exist
#
# Rsub-NDARINV9H4U1DHY.arg does not exist
# .......
# Lsub-NDARINV1313F6FM.arg does not exist
#
# Rsub-NDARINV1313F6FM.arg does not exist
# .................................
# Lsub-NDARINVB60GTH59.arg does not exist
#
# Rsub-NDARINVB60GTH59.arg does not exist
# ............
# Lsub-NDARINVCVWPX3EA.arg does not exist
#
# Rsub-NDARINVCVWPX3EA.arg does not exist
# ...........................
# Lsub-NDARINVLG186K52.arg does not exist
#
# Rsub-NDARINVLG186K52.arg does not exist
# .
# Lsub-NDARINVLLUH8L20.arg does not exist
#
# Rsub-NDARINVLLUH8L20.arg does not exist
# ..
# Lsub-NDARINVTFEZ1X41.arg does not exist
#
# Rsub-NDARINVTFEZ1X41.arg does not exist
# .....
# Lsub-NDARINVVH9GWJVF.arg does not exist
#
# Rsub-NDARINVVH9GWJVF.arg does not exist
# ..
# Lsub-NDARINVHHJXG6Y1.arg does not exist
#
# Rsub-NDARINVHHJXG6Y1.arg does not exist
# .
# Lsub-NDARINV4P1Z8PCT.arg does not exist
#
# Rsub-NDARINV4P1Z8PCT.arg does not exist
# .......
# Lsub-NDARINVFWC6LDUD.arg does not exist
#
# Rsub-NDARINVFWC6LDUD.arg does not exist
# .........
# Lsub-NDARINVP2EL0JFJ.arg does not exist
#
# Rsub-NDARINVP2EL0JFJ.arg does not exist
# ..........................................
# Lsub-NDARINV65VTXZRA.arg does not exist
#
# Rsub-NDARINV65VTXZRA.arg does not exist
# ....
# Lsub-NDARINV5RAR4VBD.arg does not exist
#
# Rsub-NDARINV5RAR4VBD.arg does not exist
# ..................
# Lsub-NDARINVYCVPJ3MW.arg does not exist
#
# Rsub-NDARINVYCVPJ3MW.arg does not exist
# ........................
# Lsub-NDARINVWFP0E099.arg does not exist
#
# Rsub-NDARINVWFP0E099.arg does not exist
# ...
# Lsub-NDARINVLFTGDBYE.arg does not exist
#
# Rsub-NDARINVLFTGDBYE.arg does not exist
# ..
# Lsub-NDARINVFRJ6LFD5.arg does not exist
#
# Rsub-NDARINVFRJ6LFD5.arg does not exist
# ..................................
# Lsub-NDARINVLRHY4MJ7.arg does not exist
#
# Rsub-NDARINVLRHY4MJ7.arg does not exist
# ......
# Lsub-NDARINVDLEUAKLH.arg does not exist
#
# Rsub-NDARINVDLEUAKLH.arg does not exist
# .................................
# Lsub-NDARINV8GMUJRGK.arg does not exist
#
# Rsub-NDARINV8GMUJRGK.arg does not exist
# ..............
# Lsub-NDARINVN150D5AC.arg does not exist
#
# Rsub-NDARINVN150D5AC.arg does not exist
# ..
# Lsub-NDARINV76NR9YPR.arg does not exist
#
# Rsub-NDARINV76NR9YPR.arg does not exist
# .......
# Lsub-NDARINV8B8WV7MT.arg does not exist
#
# Rsub-NDARINV8B8WV7MT.arg does not exist
# ....
# Lsub-NDARINVWV30VA2P.arg does not exist
#
# Rsub-NDARINVWV30VA2P.arg does not exist
# ....
# Lsub-NDARINVE06V8Y23.arg does not exist
#
# Rsub-NDARINVE06V8Y23.arg does not exist
# ...
# Lsub-NDARINVGCL0XR2C.arg does not exist
#
# Rsub-NDARINVGCL0XR2C.arg does not exist
# .........................................
# Lsub-NDARINVHPNB07E7.arg does not exist
#
# Rsub-NDARINVHPNB07E7.arg does not exist
# ..
# Lsub-NDARINVEXWHLUB5.arg does not exist
#
# Rsub-NDARINVEXWHLUB5.arg does not exist
# .....
# Lsub-NDARINVLW36C0X2.arg does not exist
#
# Rsub-NDARINVLW36C0X2.arg does not exist
# .
# Lsub-NDARINVVHUHUPY6.arg does not exist
#
# Rsub-NDARINVVHUHUPY6.arg does not exist
#
# Lsub-NDARINVVR534N8K.arg does not exist
#
# Rsub-NDARINVVR534N8K.arg does not exist
# ........
# Lsub-NDARINVPRZDG64U.arg does not exist
#
# Rsub-NDARINVPRZDG64U.arg does not exist
# .............
# Lsub-NDARINVZAF52UKG.arg does not exist
#
# Rsub-NDARINVZAF52UKG.arg does not exist
# ...........
# Lsub-NDARINVXH1KPX9J.arg does not exist
#
# Rsub-NDARINVXH1KPX9J.arg does not exist
# ...........
# Lsub-NDARINV086U18RD.arg does not exist
#
# Rsub-NDARINV086U18RD.arg does not exist
# ................
# Lsub-NDARINV8R9KBJ6M.arg does not exist
#
# Rsub-NDARINV8R9KBJ6M.arg does not exist
# ..........................
# Lsub-NDARINV11G4DZFX.arg does not exist
#
# Rsub-NDARINV11G4DZFX.arg does not exist
# .....
# Lsub-NDARINVJYHUJ7E5.arg does not exist
#
# Rsub-NDARINVJYHUJ7E5.arg does not exist
# .......
# Lsub-NDARINVB15ECXNF.arg does not exist
#
# Rsub-NDARINVB15ECXNF.arg does not exist
# ........
# Lsub-NDARINVTL3FVU14.arg does not exist
#
# Rsub-NDARINVTL3FVU14.arg does not exist
# ................
# Lsub-NDARINVDTKLRD8X.arg does not exist
#
# Rsub-NDARINVDTKLRD8X.arg does not exist
# ......
# Lsub-NDARINVE117NA3X.arg does not exist
#
# Rsub-NDARINVE117NA3X.arg does not exist
# ..
# Lsub-NDARINVH1A3JG9F.arg does not exist
#
# Rsub-NDARINVH1A3JG9F.arg does not exist
# ...
# Lsub-NDARINV8TWGX6LF.arg does not exist
#
# Rsub-NDARINV8TWGX6LF.arg does not exist
# ........
# Lsub-NDARINVMKDUT5K4.arg does not exist
#
# Rsub-NDARINVMKDUT5K4.arg does not exist
#
# Lsub-NDARINV5GUMR9J0.arg does not exist
#
# Rsub-NDARINV5GUMR9J0.arg does not exist
#
# Lsub-NDARINVP47A7DPL.arg does not exist
#
# Rsub-NDARINVP47A7DPL.arg does not exist
#
# Lsub-NDARINV3PZ5UBCM.arg does not exist
#
# Rsub-NDARINV3PZ5UBCM.arg does not exist
# ..........
# Lsub-NDARINVUXT4TZJF.arg does not exist
#
# Rsub-NDARINVUXT4TZJF.arg does not exist
# ........
# Lsub-NDARINVWT60P58U.arg does not exist
#
# Rsub-NDARINVWT60P58U.arg does not exist
# ......
# Lsub-NDARINVG55HTLK3.arg does not exist
#
# Rsub-NDARINVG55HTLK3.arg does not exist
# .
# Lsub-NDARINV2NVAXBZL.arg does not exist
#
# Rsub-NDARINV2NVAXBZL.arg does not exist
# .........
# Lsub-NDARINV5TT0JL6Z.arg does not exist
#
# Rsub-NDARINV5TT0JL6Z.arg does not exist
# .........
# Lsub-NDARINVM8P79888.arg does not exist
#
# Rsub-NDARINVM8P79888.arg does not exist
# .....
# Lsub-NDARINV0DG8XR2P.arg does not exist
#
# Rsub-NDARINV0DG8XR2P.arg does not exist
# ...
# Lsub-NDARINV1AYCA8E3.arg does not exist
#
# Rsub-NDARINV1AYCA8E3.arg does not exist
# ............
# Lsub-NDARINVLFU6DJV5.arg does not exist
#
# Rsub-NDARINVLFU6DJV5.arg does not exist
# .......
# Lsub-NDARINVVF47E1YM.arg does not exist
#
# Rsub-NDARINVVF47E1YM.arg does not exist
# ...........
# Lsub-NDARINVR22TV84L.arg does not exist
#
# Rsub-NDARINVR22TV84L.arg does not exist
# .
# Lsub-NDARINVEJ1NL7U8.arg does not exist
#
# Rsub-NDARINVEJ1NL7U8.arg does not exist
# ....
# Lsub-NDARINVHRT3979L.arg does not exist
#
# Rsub-NDARINVHRT3979L.arg does not exist
# .............
# Lsub-NDARINV6MDZCZBV.arg does not exist
#
# Rsub-NDARINV6MDZCZBV.arg does not exist
# ..........
# Lsub-NDARINV08K0R9C4.arg does not exist
#
# Rsub-NDARINV08K0R9C4.arg does not exist
# ...........................
# Lsub-NDARINVW39H8UW6.arg does not exist
#
# Rsub-NDARINVW39H8UW6.arg does not exist
# ......
# Lsub-NDARINVR81CF71A.arg does not exist
#
# Rsub-NDARINVR81CF71A.arg does not exist
# .........
# Lsub-NDARINVJV8V3BD5.arg does not exist
#
# Rsub-NDARINVJV8V3BD5.arg does not exist
# ...........
# Lsub-NDARINVZBC07FC4.arg does not exist
#
# Rsub-NDARINVZBC07FC4.arg does not exist
# ................
# Lsub-NDARINVAWBNZMY0.arg does not exist
#
# Rsub-NDARINVAWBNZMY0.arg does not exist
# ..........
# Lsub-NDARINVM826RRL7.arg does not exist
#
# Rsub-NDARINVM826RRL7.arg does not exist
# ........
# Lsub-NDARINVDGTRNE7V.arg does not exist
#
# Rsub-NDARINVDGTRNE7V.arg does not exist
# .........
# Lsub-NDARINVAUWM0VRE.arg does not exist
#
# Rsub-NDARINVAUWM0VRE.arg does not exist
# .................................
# Lsub-NDARINVVL1JXMTC.arg does not exist
#
# Rsub-NDARINVVL1JXMTC.arg does not exist
# .........
# Lsub-NDARINVT06LDPZU.arg does not exist
#
# Rsub-NDARINVT06LDPZU.arg does not exist
# .......
# Lsub-NDARINVM5M4VXYD.arg does not exist
#
# Rsub-NDARINVM5M4VXYD.arg does not exist
# ..
# Lsub-NDARINVCFPMDG7R.arg does not exist
#
# Rsub-NDARINVCFPMDG7R.arg does not exist
# .......
# Lsub-NDARINV8179BTRR.arg does not exist
#
# Rsub-NDARINV8179BTRR.arg does not exist
# ..........
# Lsub-NDARINV9D4JG706.arg does not exist
#
# Rsub-NDARINV9D4JG706.arg does not exist
# ......................................
# Lsub-NDARINVUUBJL9X5.arg does not exist
#
# Rsub-NDARINVUUBJL9X5.arg does not exist
# ..............
# Lsub-NDARINVB14DZFG7.arg does not exist
#
# Rsub-NDARINVB14DZFG7.arg does not exist
# .
# Lsub-NDARINVAYAW3D7X.arg does not exist
#
# Rsub-NDARINVAYAW3D7X.arg does not exist
#
# Lsub-NDARINV1FDC7YAJ.arg does not exist
#
# Rsub-NDARINV1FDC7YAJ.arg does not exist
# ..
# Lsub-NDARINV7KN1R7KK.arg does not exist
#
# Rsub-NDARINV7KN1R7KK.arg does not exist
# ...
# Lsub-NDARINV3NBMWRE0.arg does not exist
#
# Rsub-NDARINV3NBMWRE0.arg does not exist
# ......
# Lsub-NDARINVPAJ2K2CD.arg does not exist
#
# Rsub-NDARINVPAJ2K2CD.arg does not exist
# ..............
# Lsub-NDARINVDXR1A58H.arg does not exist
#
# Rsub-NDARINVDXR1A58H.arg does not exist
# ...............
# Lsub-NDARINV9ANUKVD0.arg does not exist
#
# Rsub-NDARINV9ANUKVD0.arg does not exist
# ....
# Lsub-NDARINV9553AJPG.arg does not exist
#
# Rsub-NDARINV9553AJPG.arg does not exist
# ...
# Lsub-NDARINV6EU13388.arg does not exist
#
# Rsub-NDARINV6EU13388.arg does not exist
# .....
# Lsub-NDARINV8M3DC6NP.arg does not exist
#
# Rsub-NDARINV8M3DC6NP.arg does not exist
# .
# Lsub-NDARINVN70WP7FM.arg does not exist
#
# Rsub-NDARINVN70WP7FM.arg does not exist
# .............
# Lsub-NDARINV9TE5V8TH.arg does not exist
#
# Rsub-NDARINV9TE5V8TH.arg does not exist
# ................
# Lsub-NDARINV3MR1M0V3.arg does not exist
#
# Rsub-NDARINV3MR1M0V3.arg does not exist
# ................
# Lsub-NDARINVRFLMRCMP.arg does not exist
#
# Rsub-NDARINVRFLMRCMP.arg does not exist
# ..........
# Lsub-NDARINVTCT40GNY.arg does not exist
#
# Rsub-NDARINVTCT40GNY.arg does not exist
# ....
# Lsub-NDARINVA4EVCYRA.arg does not exist
#
# Rsub-NDARINVA4EVCYRA.arg does not exist
# .....
# Lsub-NDARINV4ZPG6HXX.arg does not exist
#
# Rsub-NDARINV4ZPG6HXX.arg does not exist
# .....
# Lsub-NDARINVTYMAAW33.arg does not exist
#
# Rsub-NDARINVTYMAAW33.arg does not exist
# ..................
# Lsub-NDARINV0CP9XGTP.arg does not exist
#
# Rsub-NDARINV0CP9XGTP.arg does not exist
# ........
# Lsub-NDARINVP6YMTHPY.arg does not exist
#
# Rsub-NDARINVP6YMTHPY.arg does not exist
# ....
# Lsub-NDARINV859KRFB8.arg does not exist
#
# Rsub-NDARINV859KRFB8.arg does not exist
# ..................
# Lsub-NDARINVRP3R4YCP.arg does not exist
#
# Rsub-NDARINVRP3R4YCP.arg does not exist
# ...
# Lsub-NDARINV1NBW9RH8.arg does not exist
#
# Rsub-NDARINV1NBW9RH8.arg does not exist
# ......
# Lsub-NDARINVRFJLGX8M.arg does not exist
#
# Rsub-NDARINVRFJLGX8M.arg does not exist
# .............
# Lsub-NDARINV7R5D0BJ0.arg does not exist
#
# Rsub-NDARINV7R5D0BJ0.arg does not exist
# ...
# Lsub-NDARINVH9DU5D5F.arg does not exist
#
# Rsub-NDARINVH9DU5D5F.arg does not exist
# ........................
# Lsub-NDARINVLHDVLUHD.arg does not exist
#
# Rsub-NDARINVLHDVLUHD.arg does not exist
#
# Lsub-NDARINVJ9YKZEB3.arg does not exist
#
# Rsub-NDARINVJ9YKZEB3.arg does not exist
# ...
# Lsub-NDARINVALTBLNYG.arg does not exist
#
# Rsub-NDARINVALTBLNYG.arg does not exist
# ..................
# Lsub-NDARINVJ586JN4M.arg does not exist
#
# Rsub-NDARINVJ586JN4M.arg does not exist
# ..............................
# Lsub-NDARINVB8MBHMWM.arg does not exist
#
# Rsub-NDARINVB8MBHMWM.arg does not exist
# .........
# Lsub-NDARINV2W8WT4Y2.arg does not exist
#
# Rsub-NDARINV2W8WT4Y2.arg does not exist
# ..................
# Lsub-NDARINVR2EC067F.arg does not exist
#
# Rsub-NDARINVR2EC067F.arg does not exist
# ............
# Lsub-NDARINVZCCYZY0V.arg does not exist
#
# Rsub-NDARINVZCCYZY0V.arg does not exist
# ...............
# Lsub-NDARINVML6ZF1HE.arg does not exist
#
# Rsub-NDARINVML6ZF1HE.arg does not exist
# ..............
# Lsub-NDARINVF039FKEV.arg does not exist
#
# Rsub-NDARINVF039FKEV.arg does not exist
# .
# Lsub-NDARINVAH6KK71Y.arg does not exist
#
# Rsub-NDARINVAH6KK71Y.arg does not exist
# ....................
# Lsub-NDARINVPXA96T93.arg does not exist
#
# Rsub-NDARINVPXA96T93.arg does not exist
# ...............................
# Lsub-NDARINVL8MTLH03.arg does not exist
#
# Rsub-NDARINVL8MTLH03.arg does not exist
# .......
# Lsub-NDARINVWBAKLX5Y.arg does not exist
#
# Rsub-NDARINVWBAKLX5Y.arg does not exist
# .....
# Lsub-NDARINVW2JAJB5C.arg does not exist
#
# Rsub-NDARINVW2JAJB5C.arg does not exist
# ..............
# Lsub-NDARINVCB2NZA8D.arg does not exist
#
# Rsub-NDARINVCB2NZA8D.arg does not exist
# ....
# Lsub-NDARINVU5Z0C61N.arg does not exist
#
# Rsub-NDARINVU5Z0C61N.arg does not exist
# ..................
# Lsub-NDARINVBNBBL7HY.arg does not exist
#
# Rsub-NDARINVBNBBL7HY.arg does not exist
# ..
# Lsub-NDARINV701F04JM.arg does not exist
#
# Rsub-NDARINV701F04JM.arg does not exist
# ...........................................
# Lsub-NDARINV3CR6NXBG.arg does not exist
#
# Rsub-NDARINV3CR6NXBG.arg does not exist
# .....................
# Lsub-NDARINV4FRT1ZYZ.arg does not exist
#
# Rsub-NDARINV4FRT1ZYZ.arg does not exist
# .
# Lsub-NDARINVG957G5YY.arg does not exist
#
# Rsub-NDARINVG957G5YY.arg does not exist
#
# Lsub-NDARINVRN9A0LAB.arg does not exist
#
# Rsub-NDARINVRN9A0LAB.arg does not exist
# .......
# Lsub-NDARINVGXLKFNXZ.arg does not exist
#
# Rsub-NDARINVGXLKFNXZ.arg does not exist
# ....
# Lsub-NDARINVB9BEKCD9.arg does not exist
#
# Rsub-NDARINVB9BEKCD9.arg does not exist
# .
# Lsub-NDARINV2FXB1E4J.arg does not exist
#
# Rsub-NDARINV2FXB1E4J.arg does not exist
# ...............................
# Lsub-NDARINVGCK54ERY.arg does not exist
#
# Rsub-NDARINVGCK54ERY.arg does not exist
# ..............
# Lsub-NDARINVFT0UZ37W.arg does not exist
#
# Rsub-NDARINVFT0UZ37W.arg does not exist
# .
# Lsub-NDARINVRDA59E22.arg does not exist
#
# Rsub-NDARINVRDA59E22.arg does not exist
# ..................
# Lsub-NDARINVLRWKM99G.arg does not exist
#
# Rsub-NDARINVLRWKM99G.arg does not exist
# ...........
# Lsub-NDARINVCECKJY72.arg does not exist
#
# Rsub-NDARINVCECKJY72.arg does not exist
# .............................
# Lsub-NDARINVT53ZF6N7.arg does not exist
#
# Rsub-NDARINVT53ZF6N7.arg does not exist
# ..
# Lsub-NDARINVJYXYG81D.arg does not exist
#
# Rsub-NDARINVJYXYG81D.arg does not exist
# ...................................
# Lsub-NDARINV4UZ9DDJH.arg does not exist
#
# Rsub-NDARINV4UZ9DDJH.arg does not exist
# .........
# Lsub-NDARINVEY4BB6R7.arg does not exist
#
# Rsub-NDARINVEY4BB6R7.arg does not exist
# ......................
# Lsub-NDARINVAY3PH51J.arg does not exist
#
# Rsub-NDARINVAY3PH51J.arg does not exist
# ....
# Lsub-NDARINVF1TB9CPJ.arg does not exist
#
# Rsub-NDARINVF1TB9CPJ.arg does not exist
# ...
# Lsub-NDARINV14C1N3KZ.arg does not exist
#
# Rsub-NDARINV14C1N3KZ.arg does not exist
# .....
# Lsub-NDARINVV7NEVHLK.arg does not exist
#
# Rsub-NDARINVV7NEVHLK.arg does not exist
# ...........
# Lsub-NDARINVLG5EUWL6.arg does not exist
#
# Rsub-NDARINVLG5EUWL6.arg does not exist
# ...........
# Lsub-NDARINVFR2DW1WV.arg does not exist
#
# Rsub-NDARINVFR2DW1WV.arg does not exist
# ......
# Lsub-NDARINVL9WJ58CN.arg does not exist
#
# Rsub-NDARINVL9WJ58CN.arg does not exist
# .........
# Lsub-NDARINVG6XAK90E.arg does not exist
#
# Rsub-NDARINVG6XAK90E.arg does not exist
# ................
# Lsub-NDARINVET2UMV8G.arg does not exist
#
# Rsub-NDARINVET2UMV8G.arg does not exist
# .
# Lsub-NDARINVHYDABU5J.arg does not exist
#
# Rsub-NDARINVHYDABU5J.arg does not exist
# ..................
# Lsub-NDARINVBT3FWGL7.arg does not exist
#
# Rsub-NDARINVBT3FWGL7.arg does not exist
# ..........
# Lsub-NDARINVXTN3RGA3.arg does not exist
#
# Rsub-NDARINVXTN3RGA3.arg does not exist
# ...
# Lsub-NDARINV5VMC4WL1.arg does not exist
#
# Rsub-NDARINV5VMC4WL1.arg does not exist
# ...............
# Lsub-NDARINV67GRP56R.arg does not exist
#
# Rsub-NDARINV67GRP56R.arg does not exist
# .........................................
# Lsub-NDARINVXWKLKMG1.arg does not exist
#
# Rsub-NDARINVXWKLKMG1.arg does not exist
# .............................
# Lsub-NDARINV1K1285TU.arg does not exist
#
# Rsub-NDARINV1K1285TU.arg does not exist
# ..
# Lsub-NDARINV9W6CZFBK.arg does not exist
#
# Rsub-NDARINV9W6CZFBK.arg does not exist
# .......
# Lsub-NDARINVRXDY2EL7.arg does not exist
#
# Rsub-NDARINVRXDY2EL7.arg does not exist
# .................
# Lsub-NDARINVGYZ787M8.arg does not exist
#
# Rsub-NDARINVGYZ787M8.arg does not exist
# .
# Lsub-NDARINVN070J1H4.arg does not exist
#
# Rsub-NDARINVN070J1H4.arg does not exist
# ...........
# Lsub-NDARINV320U3LPD.arg does not exist
#
# Rsub-NDARINV320U3LPD.arg does not exist
# ........
# Lsub-NDARINVFB1H93PN.arg does not exist
#
# Rsub-NDARINVFB1H93PN.arg does not exist
# ...
# Lsub-NDARINVEGZWYGFM.arg does not exist
#
# Rsub-NDARINVEGZWYGFM.arg does not exist
# .
# Lsub-NDARINVV8Y5PNGN.arg does not exist
#
# Rsub-NDARINVV8Y5PNGN.arg does not exist
# .......
# Lsub-NDARINVL02ZXJAE.arg does not exist
#
# Rsub-NDARINVL02ZXJAE.arg does not exist
# .
# Lsub-NDARINVF8M7HCCK.arg does not exist
#
# Rsub-NDARINVF8M7HCCK.arg does not exist
# ....................................................
# Lsub-NDARINV5U1CRWKY.arg does not exist
#
# Rsub-NDARINV5U1CRWKY.arg does not exist
# .......
# Lsub-NDARINV5YHWBYRD.arg does not exist
#
# Rsub-NDARINV5YHWBYRD.arg does not exist
# .
# Lsub-NDARINVLG46HHB0.arg does not exist
#
# Rsub-NDARINVLG46HHB0.arg does not exist
# .........................
# Lsub-NDARINVY9845LHL.arg does not exist
#
# Rsub-NDARINVY9845LHL.arg does not exist
#
# Lsub-NDARINVEFMK5HUC.arg does not exist
#
# Rsub-NDARINVEFMK5HUC.arg does not exist
# .......................................
# Lsub-NDARINV4W2U0GZN.arg does not exist
#
# Rsub-NDARINV4W2U0GZN.arg does not exist
# .
# Lsub-NDARINVT9LPE86G.arg does not exist
#
# Rsub-NDARINVT9LPE86G.arg does not exist
# ............
# Lsub-NDARINVLHVD7DAX.arg does not exist
#
# Rsub-NDARINVLHVD7DAX.arg does not exist
# ........................................................................................
# Lsub-NDARINVT48MJ3F9.arg does not exist
#
# Rsub-NDARINVT48MJ3F9.arg does not exist
# ..
# Lsub-NDARINV0XKVPBB0.arg does not exist
#
# Rsub-NDARINV0XKVPBB0.arg does not exist
# .....
# Lsub-NDARINVZMVGC1BU.arg does not exist
#
# Rsub-NDARINVZMVGC1BU.arg does not exist
# ...
# Lsub-NDARINVY81M9FZH.arg does not exist
#
# Rsub-NDARINVY81M9FZH.arg does not exist
# ...........
# Lsub-NDARINV3KAPX6MY.arg does not exist
#
# Rsub-NDARINV3KAPX6MY.arg does not exist
#
# Lsub-NDARINV7MAEB0ZY.arg does not exist
#
# Rsub-NDARINV7MAEB0ZY.arg does not exist
# .........
# Lsub-NDARINV4F95WY7X.arg does not exist
#
# Rsub-NDARINV4F95WY7X.arg does not exist
# ........
# Lsub-NDARINVZTWTFU2A.arg does not exist
#
# Rsub-NDARINVZTWTFU2A.arg does not exist
#
# Lsub-NDARINVEYXZ3PDP.arg does not exist
#
# Rsub-NDARINVEYXZ3PDP.arg does not exist
# ....................
# Lsub-NDARINV56B953GR.arg does not exist
#
# Rsub-NDARINV56B953GR.arg does not exist
# .........
# Lsub-NDARINVWJ6WE11U.arg does not exist
#
# Rsub-NDARINVWJ6WE11U.arg does not exist
#
# Lsub-NDARINV9EC8VLZC.arg does not exist
#
# Rsub-NDARINV9EC8VLZC.arg does not exist
# ...................................................
# Lsub-NDARINVM7T4Y22R.arg does not exist
#
# Rsub-NDARINVM7T4Y22R.arg does not exist
# ...........................
# Lsub-NDARINV40AA6KX2.arg does not exist
#
# Rsub-NDARINV40AA6KX2.arg does not exist
# .........
# Lsub-NDARINVEW9ZPKZK.arg does not exist
#
# Rsub-NDARINVEW9ZPKZK.arg does not exist
# .
# Lsub-NDARINVTZ42813G.arg does not exist
#
# Rsub-NDARINVTZ42813G.arg does not exist
# ....................
# Lsub-NDARINVGT92D3H6.arg does not exist
#
# Rsub-NDARINVGT92D3H6.arg does not exist
# ......
# Lsub-NDARINVH712DY5X.arg does not exist
#
# Rsub-NDARINVH712DY5X.arg does not exist
# ...............
# Lsub-NDARINVUTEVFWND.arg does not exist
#
# Rsub-NDARINVUTEVFWND.arg does not exist
# ....
# Lsub-NDARINVX3MF6X7B.arg does not exist
#
# Rsub-NDARINVX3MF6X7B.arg does not exist
#
# Lsub-NDARINVD13XNZ1E.arg does not exist
#
# Rsub-NDARINVD13XNZ1E.arg does not exist
# ...
# Lsub-NDARINV19FYU534.arg does not exist
#
# Rsub-NDARINV19FYU534.arg does not exist
# ......
# Lsub-NDARINV0D83M5VE.arg does not exist
#
# Rsub-NDARINV0D83M5VE.arg does not exist
# .
# Lsub-NDARINVR6R1HRTP.arg does not exist
#
# Rsub-NDARINVR6R1HRTP.arg does not exist
# ............
# Lsub-NDARINVG34U0PZU.arg does not exist
#
# Rsub-NDARINVG34U0PZU.arg does not exist
# ...........
# Lsub-NDARINV086114AT.arg does not exist
#
# Rsub-NDARINV086114AT.arg does not exist
# ............
# Lsub-NDARINVZ1WZW3KT.arg does not exist
#
# Rsub-NDARINVZ1WZW3KT.arg does not exist
# ...............................
# Lsub-NDARINV4KRWWP18.arg does not exist
#
# Rsub-NDARINV4KRWWP18.arg does not exist
# ..................
# Lsub-NDARINVTFJ2LGCD.arg does not exist
#
# Rsub-NDARINVTFJ2LGCD.arg does not exist
# ............................
# Lsub-NDARINVBENKM4B0.arg does not exist
#
# Rsub-NDARINVBENKM4B0.arg does not exist
# .......
# Lsub-NDARINVUCUU472H.arg does not exist
#
# Rsub-NDARINVUCUU472H.arg does not exist
# ........
# Lsub-NDARINV4L9UBRH1.arg does not exist
#
# Rsub-NDARINV4L9UBRH1.arg does not exist
# ...
# Lsub-NDARINV3A2DLZTM.arg does not exist
#
# Rsub-NDARINV3A2DLZTM.arg does not exist
#
# Lsub-NDARINVTDXHD95M.arg does not exist
#
# Rsub-NDARINVTDXHD95M.arg does not exist
# ............
# Lsub-NDARINVULE1VKVR.arg does not exist
#
# Rsub-NDARINVULE1VKVR.arg does not exist
#
# Lsub-NDARINV8C2MCZ4K.arg does not exist
#
# Rsub-NDARINV8C2MCZ4K.arg does not exist
#
# Lsub-NDARINVE38ABK6X.arg does not exist
#
# Rsub-NDARINVE38ABK6X.arg does not exist
# ...
# Lsub-NDARINVML1A2JFY.arg does not exist
#
# Rsub-NDARINVML1A2JFY.arg does not exist
# .............
# Lsub-NDARINVEXAKNZ18.arg does not exist
#
# Rsub-NDARINVEXAKNZ18.arg does not exist
#
# Lsub-NDARINV0P2ZCYPM.arg does not exist
#
# Rsub-NDARINV0P2ZCYPM.arg does not exist
# ..........................
# Lsub-NDARINVV7J7HV7U.arg does not exist
#
# Rsub-NDARINVV7J7HV7U.arg does not exist
#
# Lsub-NDARINVZPTGXKT8.arg does not exist
#
# Rsub-NDARINVZPTGXKT8.arg does not exist
# ..
# Lsub-NDARINVTX0U3YDP.arg does not exist
#
# Rsub-NDARINVTX0U3YDP.arg does not exist
# ...
# Lsub-NDARINV3ZHEYRWE.arg does not exist
#
# Rsub-NDARINV3ZHEYRWE.arg does not exist
# ...
# Lsub-NDARINVYCAUME01.arg does not exist
#
# Rsub-NDARINVYCAUME01.arg does not exist
# ........
# Lsub-NDARINV0GYC1NWR.arg does not exist
#
# Rsub-NDARINV0GYC1NWR.arg does not exist
# ...................................
# Lsub-NDARINVBN0GRJ6R.arg does not exist
#
# Rsub-NDARINVBN0GRJ6R.arg does not exist
#
# Lsub-NDARINVH6FMF28J.arg does not exist
#
# Rsub-NDARINVH6FMF28J.arg does not exist
# ...
# Lsub-NDARINVBFEWTU2N.arg does not exist
#
# Rsub-NDARINVBFEWTU2N.arg does not exist
# ..............................
# Lsub-NDARINV8K2DKV3D.arg does not exist
#
# Rsub-NDARINV8K2DKV3D.arg does not exist
# ..................
# Lsub-NDARINVKK3DUDE5.arg does not exist
#
# Rsub-NDARINVKK3DUDE5.arg does not exist
#
# Lsub-NDARINVJ8XHKKP8.arg does not exist
#
# Rsub-NDARINVJ8XHKKP8.arg does not exist
# ..
# Lsub-NDARINVCBV85UMM.arg does not exist
#
# Rsub-NDARINVCBV85UMM.arg does not exist
# .....
# Lsub-NDARINV9XHNUHUZ.arg does not exist
#
# Rsub-NDARINV9XHNUHUZ.arg does not exist
#
# Lsub-NDARINVF3Y1JRRP.arg does not exist
#
# Rsub-NDARINVF3Y1JRRP.arg does not exist
# ...............
# Lsub-NDARINVL3UTWJGX.arg does not exist
#
# Rsub-NDARINVL3UTWJGX.arg does not exist
# .......
# Lsub-NDARINV25KHTJXZ.arg does not exist
#
# Rsub-NDARINV25KHTJXZ.arg does not exist
# .........
# Lsub-NDARINVDTWEMX2Z.arg does not exist
#
# Rsub-NDARINVDTWEMX2Z.arg does not exist
# .....
# Lsub-NDARINV6FJ7M4F7.arg does not exist
#
# Rsub-NDARINV6FJ7M4F7.arg does not exist
# ............
# Lsub-NDARINVEF0X6LUC.arg does not exist
#
# Rsub-NDARINVEF0X6LUC.arg does not exist
#
# Lsub-NDARINVGP0KJLU3.arg does not exist
#
# Rsub-NDARINVGP0KJLU3.arg does not exist
# ....
# Lsub-NDARINVW01VXPJ7.arg does not exist
#
# Rsub-NDARINVW01VXPJ7.arg does not exist
# ................
# Lsub-NDARINVAF517NF3.arg does not exist
#
# Rsub-NDARINVAF517NF3.arg does not exist
# ..........................
# Lsub-NDARINV9YE4BWY8.arg does not exist
#
# Rsub-NDARINV9YE4BWY8.arg does not exist
# ...............
# Lsub-NDARINV2X040T48.arg does not exist
#
# Rsub-NDARINV2X040T48.arg does not exist
# ..................
# Lsub-NDARINV19ZM2GTU.arg does not exist
#
# Rsub-NDARINV19ZM2GTU.arg does not exist
# ..........
# Lsub-NDARINVBJUB7H8B.arg does not exist
#
# Rsub-NDARINVBJUB7H8B.arg does not exist
# ......
# Lsub-NDARINV8XEPPMAY.arg does not exist
#
# Rsub-NDARINV8XEPPMAY.arg does not exist
# ..
# Lsub-NDARINV0C471G23.arg does not exist
#
# Rsub-NDARINV0C471G23.arg does not exist
# ..........
# Lsub-NDARINVYZGRYL84.arg does not exist
#
# Rsub-NDARINVYZGRYL84.arg does not exist
# ......
# Lsub-NDARINV0EWGP0U5.arg does not exist
#
# Rsub-NDARINV0EWGP0U5.arg does not exist
# ....................................................
# Lsub-NDARINVM862T2XJ.arg does not exist
#
# Rsub-NDARINVM862T2XJ.arg does not exist
# .
# Lsub-NDARINVNUKK77ZR.arg does not exist
#
# Rsub-NDARINVNUKK77ZR.arg does not exist
# ..............
# Lsub-NDARINVM8PMJ7MH.arg does not exist
#
# Rsub-NDARINVM8PMJ7MH.arg does not exist
# ...............
# Lsub-NDARINV2DHY1CHU.arg does not exist
#
# Rsub-NDARINV2DHY1CHU.arg does not exist
# ..
# Lsub-NDARINV09T2EBX4.arg does not exist
#
# Rsub-NDARINV09T2EBX4.arg does not exist
# ...........................
# Lsub-NDARINVRWZV4MWW.arg does not exist
#
# Rsub-NDARINVRWZV4MWW.arg does not exist
# ........
# Lsub-NDARINVXHUFCVMW.arg does not exist
#
# Rsub-NDARINVXHUFCVMW.arg does not exist
# ............
# Lsub-NDARINVT185D4UD.arg does not exist
#
# Rsub-NDARINVT185D4UD.arg does not exist
# .............
# Lsub-NDARINV4JAZBMAX.arg does not exist
#
# Rsub-NDARINV4JAZBMAX.arg does not exist
# ............
# Lsub-NDARINVA067FHRN.arg does not exist
#
# Rsub-NDARINVA067FHRN.arg does not exist
# ........
# Lsub-NDARINVAFZ44PA8.arg does not exist
#
# Rsub-NDARINVAFZ44PA8.arg does not exist
# ................
# Lsub-NDARINV6ZU9NKBV.arg does not exist
#
# Rsub-NDARINV6ZU9NKBV.arg does not exist
# ...............
# Lsub-NDARINV10RNF3BK.arg does not exist
#
# Rsub-NDARINV10RNF3BK.arg does not exist
# ...................
# Lsub-NDARINVK22WXK72.arg does not exist
#
# Rsub-NDARINVK22WXK72.arg does not exist
# ...........................
# Lsub-NDARINV2L40420R.arg does not exist
#
# Rsub-NDARINV2L40420R.arg does not exist
# .
# Lsub-NDARINVG429P74M.arg does not exist
#
# Rsub-NDARINVG429P74M.arg does not exist
# ..................................................
# Lsub-NDARINV4GL2HZC0.arg does not exist
#
# Rsub-NDARINV4GL2HZC0.arg does not exist
# .............................
# Lsub-NDARINV4WA9A9A5.arg does not exist
#
# Rsub-NDARINV4WA9A9A5.arg does not exist
# ................
# Lsub-NDARINV2D07F24X.arg does not exist
#
# Rsub-NDARINV2D07F24X.arg does not exist
# ...........................
# Lsub-NDARINVK1DE6JAR.arg does not exist
#
# Rsub-NDARINVK1DE6JAR.arg does not exist
# ..
# Lsub-NDARINV5VJVZMV6.arg does not exist
#
# Rsub-NDARINV5VJVZMV6.arg does not exist
# .....
# Lsub-NDARINVDN6HKHAW.arg does not exist
#
# Rsub-NDARINVDN6HKHAW.arg does not exist
# ....
# Lsub-NDARINVVJ7A5WBE.arg does not exist
#
# Rsub-NDARINVVJ7A5WBE.arg does not exist
# .........
# Lsub-NDARINVDH2GTB06.arg does not exist
#
# Rsub-NDARINVDH2GTB06.arg does not exist
# ............................
# Lsub-NDARINV4V86FH9A.arg does not exist
#
# Rsub-NDARINV4V86FH9A.arg does not exist
# ....
# Lsub-NDARINV7RH75L3L.arg does not exist
#
# Rsub-NDARINV7RH75L3L.arg does not exist
# ..........................
# Lsub-NDARINV6JA3GMT0.arg does not exist
#
# Rsub-NDARINV6JA3GMT0.arg does not exist
# ...............
# Lsub-NDARINV8LPXJU7B.arg does not exist
#
# Rsub-NDARINV8LPXJU7B.arg does not exist
# ..............
# Lsub-NDARINVCP2K1NFW.arg does not exist
#
# Rsub-NDARINVCP2K1NFW.arg does not exist
# .
# Lsub-NDARINV3WXXPJKW.arg does not exist
#
# Rsub-NDARINV3WXXPJKW.arg does not exist
# ..
# Lsub-NDARINVMDX2NCNW.arg does not exist
#
# Rsub-NDARINVMDX2NCNW.arg does not exist
# .....
# Lsub-NDARINVVAYBMVXD.arg does not exist
#
# Rsub-NDARINVVAYBMVXD.arg does not exist
# ............................
# Lsub-NDARINVX55N9TMK.arg does not exist
#
# Rsub-NDARINVX55N9TMK.arg does not exist
# ....
# Lsub-NDARINV4XYEZ86T.arg does not exist
#
# Rsub-NDARINV4XYEZ86T.arg does not exist
# ...
# Lsub-NDARINV3HC4V43B.arg does not exist
#
# Rsub-NDARINV3HC4V43B.arg does not exist
# ...............
# Lsub-NDARINVLRAEA45M.arg does not exist
#
# Rsub-NDARINVLRAEA45M.arg does not exist
# .................
# Lsub-NDARINV097LUBWX.arg does not exist
#
# Rsub-NDARINV097LUBWX.arg does not exist
# ...............................
# Lsub-NDARINV8KDDNHZY.arg does not exist
#
# Rsub-NDARINV8KDDNHZY.arg does not exist
# .
# Lsub-NDARINV73J1L7TG.arg does not exist
#
# Rsub-NDARINV73J1L7TG.arg does not exist
# ...
# Lsub-NDARINVW2RNZLMD.arg does not exist
#
# Rsub-NDARINVW2RNZLMD.arg does not exist
# ...............
# Lsub-NDARINVAUGA1ZYM.arg does not exist
#
# Rsub-NDARINVAUGA1ZYM.arg does not exist
# ....................
# Lsub-NDARINVXTC184P0.arg does not exist
#
# Rsub-NDARINVXTC184P0.arg does not exist
# .
# Lsub-NDARINVEJHM574R.arg does not exist
#
# Rsub-NDARINVEJHM574R.arg does not exist
# ......
# Lsub-NDARINV02UVMTY7.arg does not exist
#
# Rsub-NDARINV02UVMTY7.arg does not exist
# ...............
# Lsub-NDARINVL5W5CDJU.arg does not exist
#
# Rsub-NDARINVL5W5CDJU.arg does not exist
# ....
# Lsub-NDARINVYEH878VD.arg does not exist
#
# Rsub-NDARINVYEH878VD.arg does not exist
# ...
# Lsub-NDARINVAJJKFU1C.arg does not exist
#
# Rsub-NDARINVAJJKFU1C.arg does not exist
# .....
# Lsub-NDARINVCAL4W4CW.arg does not exist
#
# Rsub-NDARINVCAL4W4CW.arg does not exist
# ...
# Lsub-NDARINV93Y14TG4.arg does not exist
#
# Rsub-NDARINV93Y14TG4.arg does not exist
#
# Lsub-NDARINVDP5670V4.arg does not exist
#
# Rsub-NDARINVDP5670V4.arg does not exist
# ................
# Lsub-NDARINVJ5B6E6MK.arg does not exist
#
# Rsub-NDARINVJ5B6E6MK.arg does not exist
# .
# Lsub-NDARINVNBTG8FF5.arg does not exist
#
# Rsub-NDARINVNBTG8FF5.arg does not exist
# ..
# Lsub-NDARINVPPTGWLKJ.arg does not exist
#
# Rsub-NDARINVPPTGWLKJ.arg does not exist
# .............
# Lsub-NDARINVWAFKK7PK.arg does not exist
#
# Rsub-NDARINVWAFKK7PK.arg does not exist
# ......
# Lsub-NDARINV3DMNEA3Z.arg does not exist
#
# Rsub-NDARINV3DMNEA3Z.arg does not exist
# ............
# Lsub-NDARINVREBJBCWX.arg does not exist
#
# Rsub-NDARINVREBJBCWX.arg does not exist
# ..
# Lsub-NDARINVL9L2X47R.arg does not exist
#
# Rsub-NDARINVL9L2X47R.arg does not exist
# ..........................
# Lsub-NDARINVYW440F27.arg does not exist
#
# Rsub-NDARINVYW440F27.arg does not exist
# ....
# Lsub-NDARINVBDZFGJ3V.arg does not exist
#
# Rsub-NDARINVBDZFGJ3V.arg does not exist
# ..
# Lsub-NDARINVW236WLM5.arg does not exist
#
# Rsub-NDARINVW236WLM5.arg does not exist
# ....
# Lsub-NDARINVF3EWHDJR.arg does not exist
#
# Rsub-NDARINVF3EWHDJR.arg does not exist
# .......
# Lsub-NDARINV963N6B2W.arg does not exist
#
# Rsub-NDARINV963N6B2W.arg does not exist
# ..
# Lsub-NDARINVPLP1WVXM.arg does not exist
#
# Rsub-NDARINVPLP1WVXM.arg does not exist
# .....................
# Lsub-NDARINVEGCADPBF.arg does not exist
#
# Rsub-NDARINVEGCADPBF.arg does not exist
# ................
# Lsub-NDARINV9AD6NWVN.arg does not exist
#
# Rsub-NDARINV9AD6NWVN.arg does not exist
# .................
# Lsub-NDARINVTFUHVAVZ.arg does not exist
#
# Rsub-NDARINVTFUHVAVZ.arg does not exist
# .
# Lsub-NDARINV3UW7BCN8.arg does not exist
#
# Rsub-NDARINV3UW7BCN8.arg does not exist
# .
# Lsub-NDARINVT0JW7H6Z.arg does not exist
#
# Rsub-NDARINVT0JW7H6Z.arg does not exist
# .............
# Lsub-NDARINV8D7K7HYL.arg does not exist
#
# Rsub-NDARINV8D7K7HYL.arg does not exist
# .
# Lsub-NDARINVRTRHCP02.arg does not exist
#
# Rsub-NDARINVRTRHCP02.arg does not exist
# ..........
# Lsub-NDARINVHAL0EPJL.arg does not exist
#
# Rsub-NDARINVHAL0EPJL.arg does not exist
# .....
# Lsub-NDARINVKMVGX7UJ.arg does not exist
#
# Rsub-NDARINVKMVGX7UJ.arg does not exist
# ...
# Lsub-NDARINV8936X8Y5.arg does not exist
#
# Rsub-NDARINV8936X8Y5.arg does not exist
#
# Lsub-NDARINV415U67R2.arg does not exist
#
# Rsub-NDARINV415U67R2.arg does not exist
# ..........
# Lsub-NDARINVGXU8LUL5.arg does not exist
#
# Rsub-NDARINVGXU8LUL5.arg does not exist
#
# Lsub-NDARINVH1DJ48J1.arg does not exist
#
# Rsub-NDARINVH1DJ48J1.arg does not exist
#
# Lsub-NDARINVD8PZ10F0.arg does not exist
#
# Rsub-NDARINVD8PZ10F0.arg does not exist
# ...
# Lsub-NDARINVE6T95560.arg does not exist
#
# Rsub-NDARINVE6T95560.arg does not exist
# ..........
# Lsub-NDARINVMP1NHUFC.arg does not exist
#
# Rsub-NDARINVMP1NHUFC.arg does not exist
# ...
# Lsub-NDARINV1BZ0TUT9.arg does not exist
#
# Rsub-NDARINV1BZ0TUT9.arg does not exist
# .................................
# Lsub-NDARINVFMFM01J8.arg does not exist
#
# Rsub-NDARINVFMFM01J8.arg does not exist
# .....
# Lsub-NDARINV9U32H2E4.arg does not exist
#
# Rsub-NDARINV9U32H2E4.arg does not exist
# ..
# Lsub-NDARINVNNA7JH41.arg does not exist
#
# Rsub-NDARINVNNA7JH41.arg does not exist
# ....
# Lsub-NDARINVLM20BZVZ.arg does not exist
#
# Rsub-NDARINVLM20BZVZ.arg does not exist
# .....
# Lsub-NDARINV94Y93T1G.arg does not exist
#
# Rsub-NDARINV94Y93T1G.arg does not exist
# ...................
# Lsub-NDARINVCY2EFX4V.arg does not exist
#
# Rsub-NDARINVCY2EFX4V.arg does not exist
# ..........
# Lsub-NDARINVLCEYDD0V.arg does not exist
#
# Rsub-NDARINVLCEYDD0V.arg does not exist
# ....
# Lsub-NDARINV21VF36AV.arg does not exist
#
# Rsub-NDARINV21VF36AV.arg does not exist
# .
# Lsub-NDARINV26YB6ZJ9.arg does not exist
#
# Rsub-NDARINV26YB6ZJ9.arg does not exist
#
# Lsub-NDARINVCPT9ZT4B.arg does not exist
#
# Rsub-NDARINVCPT9ZT4B.arg does not exist
# .......................
# Lsub-NDARINVU710KUDX.arg does not exist
#
# Rsub-NDARINVU710KUDX.arg does not exist
# .....
# Lsub-NDARINV7F2WNZ5D.arg does not exist
#
# Rsub-NDARINV7F2WNZ5D.arg does not exist
# ...
# Lsub-NDARINVNJ3MLYLN.arg does not exist
#
# Rsub-NDARINVNJ3MLYLN.arg does not exist
#
# Lsub-NDARINV35PCA3BK.arg does not exist
#
# Rsub-NDARINV35PCA3BK.arg does not exist
# ..
# Lsub-NDARINV5UHHRZBV.arg does not exist
#
# Rsub-NDARINV5UHHRZBV.arg does not exist
# ..........
# Lsub-NDARINVDGABKCP2.arg does not exist
#
# Rsub-NDARINVDGABKCP2.arg does not exist
# ........
# Lsub-NDARINVRE48TR17.arg does not exist
#
# Rsub-NDARINVRE48TR17.arg does not exist
# .....
# Lsub-NDARINVEF5MBMJF.arg does not exist
#
# Rsub-NDARINVEF5MBMJF.arg does not exist
# ...........
# Lsub-NDARINVULZMADF1.arg does not exist
#
# Rsub-NDARINVULZMADF1.arg does not exist
# ......................
# Lsub-NDARINVWF9BVBHA.arg does not exist
#
# Rsub-NDARINVWF9BVBHA.arg does not exist
# ..
# Lsub-NDARINVTEZ4278H.arg does not exist
#
# Rsub-NDARINVTEZ4278H.arg does not exist
# .
# Lsub-NDARINVL9BZ5AF6.arg does not exist
#
# Rsub-NDARINVL9BZ5AF6.arg does not exist
# ......
# Lsub-NDARINVTBDRGNYE.arg does not exist
#
# Rsub-NDARINVTBDRGNYE.arg does not exist
# ......................
# Lsub-NDARINVVP45XG3A.arg does not exist
#
# Rsub-NDARINVVP45XG3A.arg does not exist
# ........
# Lsub-NDARINVATZ3RNRJ.arg does not exist
#
# Rsub-NDARINVATZ3RNRJ.arg does not exist
#
# Lsub-NDARINVMGH9KKCV.arg does not exist
#
# Rsub-NDARINVMGH9KKCV.arg does not exist
# .............
# Lsub-NDARINVCM90UZ9J.arg does not exist
#
# Rsub-NDARINVCM90UZ9J.arg does not exist
#
# Lsub-NDARINVWT40ZG52.arg does not exist
#
# Rsub-NDARINVWT40ZG52.arg does not exist
# ......
# Lsub-NDARINV8WBV631M.arg does not exist
#
# Rsub-NDARINV8WBV631M.arg does not exist
# .......
# Lsub-NDARINV5KTH90ED.arg does not exist
#
# Rsub-NDARINV5KTH90ED.arg does not exist
# ..............................
# Lsub-NDARINVV2R0HB8H.arg does not exist
#
# Rsub-NDARINVV2R0HB8H.arg does not exist
# .
# Lsub-NDARINV5HGRW46V.arg does not exist
#
# Rsub-NDARINV5HGRW46V.arg does not exist
# ..
# Lsub-NDARINVWAN79D4A.arg does not exist
#
# Rsub-NDARINVWAN79D4A.arg does not exist
# .........................
# Lsub-NDARINVEWXFHLKP.arg does not exist
#
# Rsub-NDARINVEWXFHLKP.arg does not exist
# .....
# Lsub-NDARINVALAMYFP6.arg does not exist
#
# Rsub-NDARINVALAMYFP6.arg does not exist
# .......
# Lsub-NDARINV0HL5D3DF.arg does not exist
#
# Rsub-NDARINV0HL5D3DF.arg does not exist
# .
# Lsub-NDARINV08DNLREC.arg does not exist
#
# Rsub-NDARINV08DNLREC.arg does not exist
# .....
# ...
# .........
# Lsub-NDARINVDVEWNJZ1.arg does not exist
#
# Rsub-NDARINVDVEWNJZ1.arg does not exist
# ........................
# Lsub-NDARINVTFL83UPB.arg does not exist
#
# Rsub-NDARINVTFL83UPB.arg does not exist
# ...
# Lsub-NDARINV0ZHHWCMZ.arg does not exist
#
# Rsub-NDARINV0ZHHWCMZ.arg does not exist
# ...
# Lsub-NDARINVYUTY0RGD.arg does not exist
#
# Rsub-NDARINVYUTY0RGD.arg does not exist
# ..
# Lsub-NDARINVXUFCDBP0.arg does not exist
#
# Rsub-NDARINVXUFCDBP0.arg does not exist
#
# Lsub-NDARINVJGFBY8J1.arg does not exist
#
# Rsub-NDARINVJGFBY8J1.arg does not exist
# ...........................................
# Lsub-NDARINV449WT7FF.arg does not exist
#
# Rsub-NDARINV449WT7FF.arg does not exist
# ..........
# Lsub-NDARINVEXB1B45G.arg does not exist
#
# Rsub-NDARINVEXB1B45G.arg does not exist
# .......
# Lsub-NDARINVJBH3AHLP.arg does not exist
#
# Rsub-NDARINVJBH3AHLP.arg does not exist
# ....................................................
# Lsub-NDARINVHFC9FFMD.arg does not exist
#
# Rsub-NDARINVHFC9FFMD.arg does not exist
# ........
# Lsub-NDARINV249R6TFP.arg does not exist
#
# Rsub-NDARINV249R6TFP.arg does not exist
# ........
# Lsub-NDARINVR44LUUEZ.arg does not exist
#
# Rsub-NDARINVR44LUUEZ.arg does not exist
# ..........
# Lsub-NDARINVV7D70A79.arg does not exist
#
# Rsub-NDARINVV7D70A79.arg does not exist
# ..
# Lsub-NDARINVHRUJUH1Y.arg does not exist
#
# Rsub-NDARINVHRUJUH1Y.arg does not exist
# .....
# Lsub-NDARINVK7B15B7Z.arg does not exist
#
# Rsub-NDARINVK7B15B7Z.arg does not exist
# ....
# Lsub-NDARINVBLX310KU.arg does not exist
#
# Rsub-NDARINVBLX310KU.arg does not exist
# ....
# Lsub-NDARINVZXF5C635.arg does not exist
#
# Rsub-NDARINVZXF5C635.arg does not exist
# .
# Lsub-NDARINVRGJHW57A.arg does not exist
#
# Rsub-NDARINVRGJHW57A.arg does not exist
# ...............
# Lsub-NDARINVJUHGFPD3.arg does not exist
#
# Rsub-NDARINVJUHGFPD3.arg does not exist
#
# Lsub-NDARINVATGY6TA4.arg does not exist
#
# Rsub-NDARINVATGY6TA4.arg does not exist
# .........
# Lsub-NDARINVC6KRAHVE.arg does not exist
#
# Rsub-NDARINVC6KRAHVE.arg does not exist
# ..........
# Lsub-NDARINVVV1MH68R.arg does not exist
#
# Rsub-NDARINVVV1MH68R.arg does not exist
# .....
# Lsub-NDARINVH8G09YY7.arg does not exist
#
# Rsub-NDARINVH8G09YY7.arg does not exist
# ......
# Lsub-NDARINVFDUYJP8Z.arg does not exist
#
# Rsub-NDARINVFDUYJP8Z.arg does not exist
# .
# Lsub-NDARINVHK3PFELX.arg does not exist
#
# Rsub-NDARINVHK3PFELX.arg does not exist
# ......
# Lsub-NDARINV85V6822C.arg does not exist
#
# Rsub-NDARINV85V6822C.arg does not exist
# .
# Lsub-NDARINVUCGJ1U8F.arg does not exist
#
# Rsub-NDARINVUCGJ1U8F.arg does not exist
# ............
# Lsub-NDARINV22LW15TV.arg does not exist
#
# Rsub-NDARINV22LW15TV.arg does not exist
# ...........................................
# Lsub-NDARINV9PYFVDC9.arg does not exist
#
# Rsub-NDARINV9PYFVDC9.arg does not exist
# ................
# Lsub-NDARINV493AHEA8.arg does not exist
#
# Rsub-NDARINV493AHEA8.arg does not exist
# ......................
# Lsub-NDARINV7JERJG3Z.arg does not exist
#
# Rsub-NDARINV7JERJG3Z.arg does not exist
# .......................
# Lsub-NDARINV36KR4T19.arg does not exist
#
# Rsub-NDARINV36KR4T19.arg does not exist
# .................
# Lsub-NDARINVAGWWTK4T.arg does not exist
#
# Rsub-NDARINVAGWWTK4T.arg does not exist
# ..
# Lsub-NDARINVTDXY0L82.arg does not exist
#
# Rsub-NDARINVTDXY0L82.arg does not exist
#
# Lsub-NDARINVMUN8FEUL.arg does not exist
#
# Rsub-NDARINVMUN8FEUL.arg does not exist
# ...............
# Lsub-NDARINVT83EVU05.arg does not exist
#
# Rsub-NDARINVT83EVU05.arg does not exist
# ...
# Lsub-NDARINVCGNRE8LG.arg does not exist
#
# Rsub-NDARINVCGNRE8LG.arg does not exist
# ................................
# Lsub-NDARINVR7WBBFTB.arg does not exist
#
# Rsub-NDARINVR7WBBFTB.arg does not exist
# ......
# Lsub-NDARINVE0577FC4.arg does not exist
#
# Rsub-NDARINVE0577FC4.arg does not exist
#
# Lsub-NDARINVBE6KKTH2.arg does not exist
#
# Rsub-NDARINVBE6KKTH2.arg does not exist
# ..........................
# Lsub-NDARINVM8YJ4H0V.arg does not exist
#
# Rsub-NDARINVM8YJ4H0V.arg does not exist
# ...........
# Lsub-NDARINV1CC6HB4A.arg does not exist
#
# Rsub-NDARINV1CC6HB4A.arg does not exist
# .....................
# Lsub-NDARINV28CB48M3.arg does not exist
#
# Rsub-NDARINV28CB48M3.arg does not exist
# ................................
# Lsub-NDARINVDBVY4B8K.arg does not exist
#
# Rsub-NDARINVDBVY4B8K.arg does not exist
# ............
# Lsub-NDARINV04BFG4JM.arg does not exist
#
# Rsub-NDARINV04BFG4JM.arg does not exist
# ........
# Lsub-NDARINVPAXW8WZB.arg does not exist
#
# Rsub-NDARINVPAXW8WZB.arg does not exist
# .............
# Lsub-NDARINVA6N6NV10.arg does not exist
#
# Rsub-NDARINVA6N6NV10.arg does not exist
#
# Lsub-NDARINV61VX090A.arg does not exist
#
# Rsub-NDARINV61VX090A.arg does not exist
# ...
# Lsub-NDARINVZJM8LDU8.arg does not exist
#
# Rsub-NDARINVZJM8LDU8.arg does not exist
# ......
# Lsub-NDARINVH6PKTBWM.arg does not exist
#
# Rsub-NDARINVH6PKTBWM.arg does not exist
# .........
# Lsub-NDARINV14R3MHDX.arg does not exist
#
# Rsub-NDARINV14R3MHDX.arg does not exist
# ........
# Lsub-NDARINV0F82C6R8.arg does not exist
#
# Rsub-NDARINV0F82C6R8.arg does not exist
# ................................
# Lsub-NDARINV592319RL.arg does not exist
#
# Rsub-NDARINV592319RL.arg does not exist
# .
# Lsub-NDARINV9PVR76W7.arg does not exist
#
# Rsub-NDARINV9PVR76W7.arg does not exist
# .................
# Lsub-NDARINV3E2U4BWJ.arg does not exist
#
# Rsub-NDARINV3E2U4BWJ.arg does not exist
# .......
# Lsub-NDARINVPMWGZ7G1.arg does not exist
#
# Rsub-NDARINVPMWGZ7G1.arg does not exist
#
# Lsub-NDARINVAV9564YP.arg does not exist
#
# Rsub-NDARINVAV9564YP.arg does not exist
# ..
# Lsub-NDARINVYACV3T0T.arg does not exist
#
# Rsub-NDARINVYACV3T0T.arg does not exist
# .....
# Lsub-NDARINVRX2KLC0M.arg does not exist
#
# Rsub-NDARINVRX2KLC0M.arg does not exist
# ....
# Lsub-NDARINVAPWWNB9N.arg does not exist
#
# Rsub-NDARINVAPWWNB9N.arg does not exist
# ................................
# Lsub-NDARINVF1JR8615.arg does not exist
#
# Rsub-NDARINVF1JR8615.arg does not exist
# ..........
# Lsub-NDARINVMB01JV9Z.arg does not exist
#
# Rsub-NDARINVMB01JV9Z.arg does not exist
# ...............................
# Lsub-NDARINV40T7TX7X.arg does not exist
#
# Rsub-NDARINV40T7TX7X.arg does not exist
# .................
# Lsub-NDARINV5A4EYCUX.arg does not exist
#
# Rsub-NDARINV5A4EYCUX.arg does not exist
# ....................................................................
# Lsub-NDARINVMMKMFJLN.arg does not exist
#
# Rsub-NDARINVMMKMFJLN.arg does not exist
# ..
# Lsub-NDARINVFY7E3ZGA.arg does not exist
#
# Rsub-NDARINVFY7E3ZGA.arg does not exist
# .......
# Lsub-NDARINV52XG9LJ3.arg does not exist
#
# Rsub-NDARINV52XG9LJ3.arg does not exist
# ......
# Lsub-NDARINV5HJF8AGA.arg does not exist
#
# Rsub-NDARINV5HJF8AGA.arg does not exist
# .......
# Lsub-NDARINVR8NY2TWV.arg does not exist
#
# Rsub-NDARINVR8NY2TWV.arg does not exist
# .......
# Lsub-NDARINVX8CRJYVP.arg does not exist
#
# Rsub-NDARINVX8CRJYVP.arg does not exist
# ...............
# Lsub-NDARINVDAF6VRMG.arg does not exist
#
# Rsub-NDARINVDAF6VRMG.arg does not exist
# ........
# Lsub-NDARINV3AD71HE2.arg does not exist
#
# Rsub-NDARINV3AD71HE2.arg does not exist
#
# Lsub-NDARINV93DMBG2D.arg does not exist
#
# Rsub-NDARINV93DMBG2D.arg does not exist
# ...
# Lsub-NDARINVJ1KCU2LN.arg does not exist
#
# Rsub-NDARINVJ1KCU2LN.arg does not exist
# ...
# Lsub-NDARINVY5RCRU10.arg does not exist
#
# Rsub-NDARINVY5RCRU10.arg does not exist
# .
# Lsub-NDARINV9V9MLV7N.arg does not exist
#
# Rsub-NDARINV9V9MLV7N.arg does not exist
#
# Lsub-NDARINVN2CVFJPN.arg does not exist
#
# Rsub-NDARINVN2CVFJPN.arg does not exist
# ........
# Lsub-NDARINVM1HAJGWE.arg does not exist
#
# Rsub-NDARINVM1HAJGWE.arg does not exist
# ...............................................
# Lsub-NDARINV6KW88EPW.arg does not exist
#
# Rsub-NDARINV6KW88EPW.arg does not exist
# ........
# Lsub-NDARINVF7F6URTR.arg does not exist
#
# Rsub-NDARINVF7F6URTR.arg does not exist
# ....
# Lsub-NDARINVJRFFW8YT.arg does not exist
#
# Rsub-NDARINVJRFFW8YT.arg does not exist
#
# Lsub-NDARINVPVMY2MPT.arg does not exist
#
# Rsub-NDARINVPVMY2MPT.arg does not exist
# ........................
# Lsub-NDARINV5D3CDXCL.arg does not exist
#
# Rsub-NDARINV5D3CDXCL.arg does not exist
# ....
# Lsub-NDARINVA1CW8FGN.arg does not exist
#
# Rsub-NDARINVA1CW8FGN.arg does not exist
# .........
# Lsub-NDARINVMKW7RNZ8.arg does not exist
#
# Rsub-NDARINVMKW7RNZ8.arg does not exist
# ................
# Lsub-NDARINV4EKBZJTW.arg does not exist
#
# Rsub-NDARINV4EKBZJTW.arg does not exist
#
# Lsub-NDARINV0BEPJHU1.arg does not exist
#
# Rsub-NDARINV0BEPJHU1.arg does not exist
# ..
# Lsub-NDARINVPME3AVNG.arg does not exist
#
# Rsub-NDARINVPME3AVNG.arg does not exist
# ...........
# Lsub-NDARINVKL89G2CL.arg does not exist
#
# Rsub-NDARINVKL89G2CL.arg does not exist
# ............
# Lsub-NDARINVTKENUL3C.arg does not exist
#
# Rsub-NDARINVTKENUL3C.arg does not exist
# .
# Lsub-NDARINVF7E957WL.arg does not exist
#
# Rsub-NDARINVF7E957WL.arg does not exist
# .
# Lsub-NDARINV31JTFZ92.arg does not exist
#
# Rsub-NDARINV31JTFZ92.arg does not exist
# ................
# Lsub-NDARINVEAK38TE7.arg does not exist
#
# Rsub-NDARINVEAK38TE7.arg does not exist
# ....
# Lsub-NDARINVJAL1KX4A.arg does not exist
#
# Rsub-NDARINVJAL1KX4A.arg does not exist
# .........
# Lsub-NDARINV7U9JKJT0.arg does not exist
#
# Rsub-NDARINV7U9JKJT0.arg does not exist
# ...
# Lsub-NDARINVPBDB6PBR.arg does not exist
#
# Rsub-NDARINVPBDB6PBR.arg does not exist
# ......
# Lsub-NDARINVG1319K4E.arg does not exist
#
# Rsub-NDARINVG1319K4E.arg does not exist
# .....
# Lsub-NDARINVZH7LD600.arg does not exist
#
# Rsub-NDARINVZH7LD600.arg does not exist
# .......
# Lsub-NDARINVLC2XNHVP.arg does not exist
#
# Rsub-NDARINVLC2XNHVP.arg does not exist
# .........
# Lsub-NDARINVJF3BM0BU.arg does not exist
#
# Rsub-NDARINVJF3BM0BU.arg does not exist
# ...................
# Lsub-NDARINV7JG0B0Y1.arg does not exist
#
# Rsub-NDARINV7JG0B0Y1.arg does not exist
# ..
# Lsub-NDARINV7TJVNX42.arg does not exist
#
# Rsub-NDARINV7TJVNX42.arg does not exist
#
# Lsub-NDARINV0X38WL5R.arg does not exist
#
# Rsub-NDARINV0X38WL5R.arg does not exist
# .....................................
# Lsub-NDARINVR2HJCC0M.arg does not exist
#
# Rsub-NDARINVR2HJCC0M.arg does not exist
# ......
# Lsub-NDARINVC1T4T2DC.arg does not exist
#
# Rsub-NDARINVC1T4T2DC.arg does not exist
# ...............
# Lsub-NDARINVL8XFXVEJ.arg does not exist
#
# Rsub-NDARINVL8XFXVEJ.arg does not exist
# .......
# Lsub-NDARINVALXUBB3W.arg does not exist
#
# Rsub-NDARINVALXUBB3W.arg does not exist
# ............................................
# Lsub-NDARINVZH1A3UUP.arg does not exist
#
# Rsub-NDARINVZH1A3UUP.arg does not exist
# ...................................
# Lsub-NDARINVT5VEMC05.arg does not exist
#
# Rsub-NDARINVT5VEMC05.arg does not exist
#
# Lsub-NDARINVC92BA5NX.arg does not exist
#
# Rsub-NDARINVC92BA5NX.arg does not exist
# ......
# Lsub-NDARINV99J6PWJX.arg does not exist
#
# Rsub-NDARINV99J6PWJX.arg does not exist
# ...........
# Lsub-NDARINVKG5M5RTF.arg does not exist
#
# Rsub-NDARINVKG5M5RTF.arg does not exist
# .
# Lsub-NDARINV72JP5LKF.arg does not exist
#
# Rsub-NDARINV72JP5LKF.arg does not exist
# .........
# Lsub-NDARINVL0M87H37.arg does not exist
#
# Rsub-NDARINVL0M87H37.arg does not exist
# .
# Lsub-NDARINVTTWDRHK8.arg does not exist
#
# Rsub-NDARINVTTWDRHK8.arg does not exist
# .
# Lsub-NDARINVMJFWNECM.arg does not exist
#
# Rsub-NDARINVMJFWNECM.arg does not exist
# .......................
# Lsub-NDARINVYNCHCTAD.arg does not exist
#
# Rsub-NDARINVYNCHCTAD.arg does not exist
# ...................
# Lsub-NDARINVKCW9B4TJ.arg does not exist
#
# Rsub-NDARINVKCW9B4TJ.arg does not exist
# .
# Lsub-NDARINV1VCF7KC6.arg does not exist
#
# Rsub-NDARINV1VCF7KC6.arg does not exist
# ...........
# Lsub-NDARINV0314RN9P.arg does not exist
#
# Rsub-NDARINV0314RN9P.arg does not exist
# .....
# Lsub-NDARINVM0706PEX.arg does not exist
#
# Rsub-NDARINVM0706PEX.arg does not exist
# ..............
# Lsub-NDARINVDHCPMWJD.arg does not exist
#
# Rsub-NDARINVDHCPMWJD.arg does not exist
# ..................
# Lsub-NDARINV2L3VG13G.arg does not exist
#
# Rsub-NDARINV2L3VG13G.arg does not exist
# .................
# Lsub-NDARINVGK9ACPNW.arg does not exist
#
# Rsub-NDARINVGK9ACPNW.arg does not exist
# ............................
# Lsub-NDARINVE5L7WXDY.arg does not exist
#
# Rsub-NDARINVE5L7WXDY.arg does not exist
# ....
# Lsub-NDARINVCK2JFJP6.arg does not exist
#
# Rsub-NDARINVCK2JFJP6.arg does not exist
# ...
# Lsub-NDARINVHGNA569Y.arg does not exist
#
# Rsub-NDARINVHGNA569Y.arg does not exist
#
# Lsub-NDARINVYCMGF947.arg does not exist
#
# Rsub-NDARINVYCMGF947.arg does not exist
# ....
# Lsub-NDARINVPP5NK3LX.arg does not exist
#
# Rsub-NDARINVPP5NK3LX.arg does not exist
# .........
# Lsub-NDARINVX5L1CX2N.arg does not exist
#
# Rsub-NDARINVX5L1CX2N.arg does not exist
# .........................
# Lsub-NDARINVFLPJWCHN.arg does not exist
#
# Rsub-NDARINVFLPJWCHN.arg does not exist
# ...................
# Lsub-NDARINVWVMTXLEH.arg does not exist
#
# Rsub-NDARINVWVMTXLEH.arg does not exist
# .
# Lsub-NDARINV395VW31D.arg does not exist
#
# Rsub-NDARINV395VW31D.arg does not exist
# ...
# Lsub-NDARINV9BGN5Y57.arg does not exist
#
# Rsub-NDARINV9BGN5Y57.arg does not exist
# ..................................
# Lsub-NDARINV24V8FLZ3.arg does not exist
#
# Rsub-NDARINV24V8FLZ3.arg does not exist
# .................
# Lsub-NDARINV3HV5ZJLJ.arg does not exist
#
# Rsub-NDARINV3HV5ZJLJ.arg does not exist
# ......
# Lsub-NDARINVZZ05KY5J.arg does not exist
#
# Rsub-NDARINVZZ05KY5J.arg does not exist
#
# Lsub-NDARINVCV5P454F.arg does not exist
#
# Rsub-NDARINVCV5P454F.arg does not exist
# .......................
# Lsub-NDARINVF3R0FGHL.arg does not exist
#
# Rsub-NDARINVF3R0FGHL.arg does not exist
# ..............
# Lsub-NDARINVDGW9RHNK.arg does not exist
#
# Rsub-NDARINVDGW9RHNK.arg does not exist
# ..
# Lsub-NDARINVDY0X871X.arg does not exist
#
# Rsub-NDARINVDY0X871X.arg does not exist
# .
# Lsub-NDARINVHL80JFPU.arg does not exist
#
# Rsub-NDARINVHL80JFPU.arg does not exist
# .....................
# Lsub-NDARINVCD63NC88.arg does not exist
#
# Rsub-NDARINVCD63NC88.arg does not exist
# ....
# Lsub-NDARINV90MGDTFD.arg does not exist
#
# Rsub-NDARINV90MGDTFD.arg does not exist
# ..........
# Lsub-NDARINVRXX916ZV.arg does not exist
#
# Rsub-NDARINVRXX916ZV.arg does not exist
# ......
# Lsub-NDARINV03KMHMJJ.arg does not exist
#
# Rsub-NDARINV03KMHMJJ.arg does not exist
# ...................
# Lsub-NDARINVL3UBBTCU.arg does not exist
#
# Rsub-NDARINVL3UBBTCU.arg does not exist
# ..
# Lsub-NDARINV54VT5R72.arg does not exist
#
# Rsub-NDARINV54VT5R72.arg does not exist
# ..................................
# Lsub-NDARINV8F1DEP52.arg does not exist
#
# Rsub-NDARINV8F1DEP52.arg does not exist
# .
# Lsub-NDARINVYAVZM6F1.arg does not exist
#
# Rsub-NDARINVYAVZM6F1.arg does not exist
# ...................
# Lsub-NDARINVD1C3Z8TZ.arg does not exist
#
# Rsub-NDARINVD1C3Z8TZ.arg does not exist
# ........
# Lsub-NDARINVJAD86WDH.arg does not exist
#
# Rsub-NDARINVJAD86WDH.arg does not exist
# .......
# Lsub-NDARINV78NACXBB.arg does not exist
#
# Rsub-NDARINV78NACXBB.arg does not exist
# ...
# Lsub-NDARINVJB9K1ZVX.arg does not exist
#
# Rsub-NDARINVJB9K1ZVX.arg does not exist
# ...........
# Lsub-NDARINV0LA6MBBY.arg does not exist
#
# Rsub-NDARINV0LA6MBBY.arg does not exist
# ...........
# Lsub-NDARINVDN453NWJ.arg does not exist
#
# Rsub-NDARINVDN453NWJ.arg does not exist
# ..........
# Lsub-NDARINV1ZY3ZR47.arg does not exist
#
# Rsub-NDARINV1ZY3ZR47.arg does not exist
# .
# Lsub-NDARINVTHHL55VX.arg does not exist
#
# Rsub-NDARINVTHHL55VX.arg does not exist
# .
# Lsub-NDARINVJ218DEYA.arg does not exist
#
# Rsub-NDARINVJ218DEYA.arg does not exist
#
# Lsub-NDARINVBMMEGVWT.arg does not exist
#
# Rsub-NDARINVBMMEGVWT.arg does not exist
# ..............
# Lsub-NDARINVXK4L71C3.arg does not exist
#
# Rsub-NDARINVXK4L71C3.arg does not exist
# ...............
# Lsub-NDARINVBTWHMF8T.arg does not exist
#
# Rsub-NDARINVBTWHMF8T.arg does not exist
# ....
# Lsub-NDARINVMZKNKER7.arg does not exist
#
# Rsub-NDARINVMZKNKER7.arg does not exist
# ....................
# Lsub-NDARINVBT1JM1WA.arg does not exist
#
# Rsub-NDARINVBT1JM1WA.arg does not exist
# .....
# Lsub-NDARINVV1Z15TXB.arg does not exist
#
# Rsub-NDARINVV1Z15TXB.arg does not exist
# ..
# Lsub-NDARINVY62X7UGH.arg does not exist
#
# Rsub-NDARINVY62X7UGH.arg does not exist
# .......
# Lsub-NDARINVY3EWHNRF.arg does not exist
#
# Rsub-NDARINVY3EWHNRF.arg does not exist
# .............
# Lsub-NDARINVFB03XKRE.arg does not exist
#
# Rsub-NDARINVFB03XKRE.arg does not exist
# ....................
# Lsub-NDARINV13BCLD41.arg does not exist
#
# Rsub-NDARINV13BCLD41.arg does not exist
# ..........
# Lsub-NDARINVXFD605G6.arg does not exist
#
# Rsub-NDARINVXFD605G6.arg does not exist
#
# Lsub-NDARINVP9NTMNTN.arg does not exist
#
# Rsub-NDARINVP9NTMNTN.arg does not exist
#
# Lsub-NDARINVG40TP4HF.arg does not exist
#
# Rsub-NDARINVG40TP4HF.arg does not exist
# .......

# %%
graph_file
# Out:
# '/mnt/n4habcd/sub-NDARINVF5R46XKV/ses-1/anat/t1mri/default_acquisition/default_analysis/folds/3.1/Rsub-NDARINVF5R46XKV.arg'

# %%
qc["qc"].sum()
# Out:
# 10194

# %%
len(qc)
# Out:
# 11159

# %%
qc[qc.qc==0].comments.unique()
# Out:
# array(['Right graph does not exist'], dtype=object)

# %%
qc = qc[["qc", "comments"]]

# %%
qc.head()
# Out:
#                      qc comments
# participant_id
# sub-NDARINVLVJNK52B   1
# sub-NDARINVG7B119A0   1
# sub-NDARINVTFPAU4FF   1
# sub-NDARINVZ5G203VB   1
# sub-NDARINVYPZAV10C   1

# %%
qc.to_csv(qc_file, sep='\t')

# %%
len(qc[qc.qc==1])
# Out:
# 10194
