# %%
import glob
import os
import pandas as pd

# %%
path = "/neurospin/dico/data/bv_databases/human/automatically_labeled/htp/database_brainvisa/htp"
subpath = "t1mri/default_acquisition/default_analysis/folds/3.1"
qc_file = "/neurospin/dico/data/deep_folding/current/datasets/htp/qc.tsv"

# %%
list_folders = glob.glob(f"{path}/*/")
list_folders = [x[:-1] for x in list_folders]
list_subjects = [os.path.basename(f) for f in list_folders]

# %%
list_subjects
# Out:
# ['Scan0097',
#  'Scan0456',
#  'Scan0449',
#  'Scan0402',
#  'Scan0043',
#  'Scan0529',
#  'Scan0230',
#  'Scan0415',
#  'Scan0041',
#  'Scan0470',
#  'Scan0309',
#  'Scan0426',
#  'Scan0068',
#  'Scan0492',
#  'Scan0280',
#  'Scan0465',
#  'Scan0486',
#  'Scan0051',
#  'Scan0153',
#  'Scan0137',
#  'Scan0173',
#  'Scan0385',
#  'Scan0351',
#  'Scan0302',
#  'Scan0120',
#  'Scan0048',
#  'Scan0232',
#  'Scan0503',
#  'Scan0490',
#  'Scan0383',
#  'Scan0122',
#  'Scan0265',
#  'Scan0176',
#  'Scan0357',
#  'Scan0183',
#  'Scan0279',
#  'Scan0397',
#  'Scan0066',
#  'Scan0498',
#  'Scan0381',
#  'Scan0489',
#  'Scan0396',
#  'Scan0418',
#  'Scan0164',
#  'Scan0333',
#  'Scan0411',
#  'Scan0466',
#  'Scan0170',
#  'Scan0092',
#  'Scan0398',
#  'Scan0537',
#  'Scan0432',
#  'Scan0187',
#  'Scan0148',
#  'Scan0338',
#  'Scan0147',
#  'Scan0453',
#  'Scan0350',
#  'Scan0543',
#  'Scan0220',
#  'Scan0511',
#  'Scan0551',
#  'Scan0160',
#  'Scan0477',
#  'Scan0243',
#  'Scan0360',
#  'Scan0369',
#  'Scan0099',
#  'Scan0374',
#  'Scan0451',
#  'Scan0293',
#  'Scan0337',
#  'Scan0405',
#  'Scan0348',
#  'Scan0256',
#  'Scan0149',
#  'Scan0181',
#  'Scan0206',
#  'Scan0376',
#  'Scan0101',
#  'Scan0077',
#  'Scan0495',
#  'Scan0119',
#  'Scan0483',
#  'Scan0100',
#  'Scan0152',
#  'Scan0186',
#  'Scan0506',
#  'Scan0430',
#  'Scan0407',
#  'Scan0389',
#  'Scan0423',
#  'Scan0255',
#  'Scan0088',
#  'Scan0512',
#  'Scan0463',
#  'Scan0058',
#  'Scan0163',
#  'Scan0275',
#  'Scan0438',
#  'Scan0324',
#  'Scan0510',
#  'Scan0251',
#  'Scan0145',
#  'Scan0131',
#  'Scan0029',
#  'Scan0193',
#  'Scan0297',
#  'Scan0393',
#  'Scan0439',
#  'Scan0521',
#  'Scan0257',
#  'Scan0118',
#  'Scan0514',
#  'Scan0004',
#  'Scan0023',
#  'Scan0030',
#  'Scan0472',
#  'Scan0002',
#  'Scan0086',
#  'Scan0327',
#  'Scan0263',
#  'Scan0017',
#  'Scan0227',
#  'Scan0289',
#  'Scan0548',
#  'Scan0155',
#  'Scan0003',
#  'Scan0379',
#  'Scan0253',
#  'Scan0199',
#  'Scan0078',
#  'Scan0174',
#  'Scan0223',
#  'Scan0238',
#  'Scan0110',
#  'Scan0520',
#  'Scan0504',
#  'Scan0197',
#  'Scan0496',
#  'Scan0356',
#  'Scan0081',
#  'Scan0532',
#  'Scan0156',
#  'Scan0390',
#  'Scan0012',
#  'Scan0320',
#  'Scan0455',
#  'Scan0497',
#  'Scan0009',
#  'Scan0334',
#  'Scan0323',
#  'Scan0544',
#  'Scan0067',
#  'Scan0054',
#  'Scan0509',
#  'Scan0213',
#  'Scan0194',
#  'Scan0344',
#  'Scan0260',
#  'Scan0005',
#  'Scan0044',
#  'Scan0550',
#  'Scan0446',
#  'Scan0476',
#  'Scan0073',
#  'Scan0276',
#  'Scan0162',
#  'Scan0165',
#  'Scan0427',
#  'Scan0135',
#  'Scan0403',
#  'Scan0288',
#  'Scan0010',
#  'Scan0268',
#  'Scan0063',
#  'Scan0478',
#  'Scan0499',
#  'Scan0392',
#  'Scan0071',
#  'Scan0541',
#  'Scan0215',
#  'Scan0441',
#  'Scan0039',
#  'Scan0198',
#  'Scan0549',
#  'Scan0007',
#  'Scan0340',
#  'Scan0130',
#  'Scan0530',
#  'Scan0151',
#  'Scan0554',
#  'Scan0191',
#  'Scan0139',
#  'Scan0124',
#  'Scan0552',
#  'Scan0175',
#  'Scan0168',
#  'Scan0277',
#  'Scan0271',
#  'Scan0209',
#  'Scan0013',
#  'Scan0056',
#  'Scan0274',
#  'Scan0242',
#  'Scan0462',
#  'Scan0108',
#  'Scan0285',
#  'Scan0524',
#  'Scan0459',
#  'Scan0240',
#  'Scan0395',
#  'Scan0442',
#  'Scan0299',
#  'Scan0212',
#  'Scan0082',
#  'Scan0522',
#  'Scan0219',
#  'Scan0006',
#  'Scan0387',
#  'Scan0065',
#  'Scan0262',
#  'Scan0422',
#  'Scan0538',
#  'Scan0090',
#  'Scan0218',
#  'Scan0287',
#  'Scan0347',
#  'Scan0132',
#  'Scan0014',
#  'Scan0185',
#  'Scan0523',
#  'Scan0436',
#  'Scan0062',
#  'Scan0046',
#  'Scan0001',
#  'Scan0352',
#  'Scan0353',
#  'Scan0461',
#  'Scan0177',
#  'Scan0116',
#  'Scan0517',
#  'Scan0358',
#  'Scan0208',
#  'Scan0190',
#  'Scan0359',
#  'Scan0111',
#  'Scan0055',
#  'Scan0115',
#  'Scan0022',
#  'Scan0134',
#  'Scan0361',
#  'Scan0310',
#  'Scan0226',
#  'Scan0008',
#  'Scan0307',
#  'Scan0098',
#  'Scan0471',
#  'Scan0070',
#  'Scan0545',
#  'Scan0332',
#  'Scan0469',
#  'Scan0087',
#  'Scan0303',
#  'Scan0341',
#  'Scan0443',
#  'Scan0378',
#  'Scan0417',
#  'Scan0412',
#  'Scan0370',
#  'Scan0416',
#  'Scan0406',
#  'Scan0157',
#  'Scan0433',
#  'Scan0454',
#  'Scan0107',
#  'Scan0525',
#  'Scan0339',
#  'Scan0095',
#  'Scan0161',
#  'Scan0201',
#  'Scan0314',
#  'Scan0159',
#  'Scan0468',
#  'Scan0384',
#  'Scan0246',
#  'Scan0531',
#  'Scan0241',
#  'Scan0192',
#  'Scan0343',
#  'Scan0556',
#  'Scan0229',
#  'Scan0210',
#  'Scan0420',
#  'Scan0399',
#  'Scan0021',
#  'Scan0031',
#  'Scan0239',
#  'Scan0093',
#  'Scan0076',
#  'Scan0075',
#  'Scan0150',
#  'Scan0488',
#  'Scan0457',
#  'Scan0437',
#  'Scan0413',
#  'Scan0113',
#  'Scan0143',
#  'Scan0539',
#  'Scan0346',
#  'Scan0047',
#  'Scan0127',
#  'Scan0317',
#  'Scan0233',
#  'Scan0015',
#  'Scan0225',
#  'Scan0349',
#  'Scan0231',
#  'Scan0458',
#  'Scan0074',
#  'Scan0207',
#  'Scan0171',
#  'Scan0195',
#  'Scan0102',
#  'Scan0329',
#  'Scan0019',
#  'Scan0254',
#  'Scan0372',
#  'Scan0409',
#  'Scan0104',
#  'Scan0388',
#  'Scan0259',
#  'Scan0247',
#  'Scan0166',
#  'Scan0311',
#  'Scan0154',
#  'Scan0355',
#  'Scan0542',
#  'Scan0290',
#  'Scan0266',
#  'Scan0072',
#  'Scan0401',
#  'Scan0296',
#  'Scan0367',
#  'Scan0515',
#  'Scan0502',
#  'Scan0335',
#  'Scan0428',
#  'Scan0316',
#  'Scan0306',
#  'Scan0024',
#  'Scan0117',
#  'Scan0126',
#  'Scan0363',
#  'Scan0178',
#  'Scan0519',
#  'Scan0106',
#  'Scan0391',
#  'Scan0533',
#  'Scan0424',
#  'Scan0322',
#  'Scan0112',
#  'Scan0312',
#  'Scan0204',
#  'Scan0026',
#  'Scan0141',
#  'Scan0434',
#  'Scan0129',
#  'Scan0128',
#  'Scan0096',
#  'Scan0474',
#  'Scan0328',
#  'Scan0049',
#  'Scan0331',
#  'Scan0264',
#  'Scan0362',
#  'Scan0342',
#  'Scan0059',
#  'Scan0032',
#  'Scan0295',
#  'Scan0300',
#  'Scan0228',
#  'Scan0091',
#  'Scan0211',
#  'Scan0036',
#  'Scan0083',
#  'Scan0144',
#  'Scan0146',
#  'Scan0373',
#  'Scan0380',
#  'Scan0222',
#  'Scan0429',
#  'Scan0450',
#  'Scan0480',
#  'Scan0035',
#  'Scan0182',
#  'Scan0294',
#  'Scan0501',
#  'Scan0216',
#  'Scan0184',
#  'Scan0064',
#  'Scan0121',
#  'Scan0448',
#  'Scan0179',
#  'Scan0371',
#  'Scan0282',
#  'Scan0491',
#  'Scan0250',
#  'Scan0534',
#  'Scan0018',
#  'Scan0555',
#  'Scan0482',
#  'Scan0052',
#  'Scan0272',
#  'Scan0069',
#  'Scan0394',
#  'Scan0414',
#  'Scan0431',
#  'Scan0526',
#  'Scan0473',
#  'Scan0444',
#  'Scan0037',
#  'Scan0301',
#  'Scan0308',
#  'Scan0410',
#  'Scan0027',
#  'Scan0103',
#  'Scan0345',
#  'Scan0507',
#  'Scan0000',
#  'Scan0447',
#  'Scan0518',
#  'Scan0053',
#  'Scan0061',
#  'Scan0419',
#  'Scan0025',
#  'Scan0375',
#  'Scan0158',
#  'Scan0042',
#  'Scan0494',
#  'Scan0404',
#  'Scan0142',
#  'Scan0278',
#  'Scan0189',
#  'Scan0368',
#  'Scan0467',
#  'Scan0040',
#  'Scan0234',
#  'Scan0237',
#  'Scan0527',
#  'Scan0400',
#  'Scan0292',
#  'Scan0298',
#  'Scan0326',
#  'Scan0094',
#  'Scan0038',
#  'Scan0540',
#  'Scan0330',
#  'Scan0493',
#  'Scan0516',
#  'Scan0133',
#  'Scan0315',
#  'Scan0364',
#  'Scan0114',
#  'Scan0408',
#  'Scan0109',
#  'Scan0440',
#  'Scan0136',
#  'Scan0050',
#  'Scan0336',
#  'Scan0252',
#  'Scan0245',
#  'Scan0079',
#  'Scan0034',
#  'Scan0435',
#  'Scan0169',
#  'Scan0267',
#  'Scan0313',
#  'Scan0249',
#  'Scan0281',
#  'Scan0318',
#  'Scan0283',
#  'Scan0105',
#  'Scan0377',
#  'Scan0354',
#  'Scan0425',
#  'Scan0221',
#  'Scan0535',
#  'Scan0319',
#  'Scan0553',
#  'Scan0286',
#  'Scan0205',
#  'Scan0484',
#  'Scan0460',
#  'Scan0291',
#  'Scan0248',
#  'Scan0386',
#  'Scan0180',
#  'Scan0528',
#  'Scan0224',
#  'Scan0269',
#  'Scan0244',
#  'Scan0513',
#  'Scan0382',
#  'Scan0325',
#  'Scan0016',
#  'Scan0365',
#  'Scan0258',
#  'Scan0421',
#  'Scan0125',
#  'Scan0138',
#  'Scan0188',
#  'Scan0140',
#  'Scan0481',
#  'Scan0089',
#  'Scan0080',
#  'Scan0011',
#  'Scan0261',
#  'Scan0305',
#  'Scan0479',
#  'Scan0203',
#  'Scan0200',
#  'Scan0167',
#  'Scan0304',
#  'Scan0452',
#  'Scan0500',
#  'Scan0284',
#  'Scan0202',
#  'Scan0085',
#  'Scan0236',
#  'Scan0028',
#  'Scan0217']

# %%
qc = pd.DataFrame(list_subjects, columns=["participant_id"]).set_index("participant_id")

# %%
qc["qc"] = 1
qc["comments"] =  ""

# %%
qc.head()
# Out:
#                 qc comments
# participant_id
# Scan0097         1
# Scan0456         1
# Scan0449         1
# Scan0402         1
# Scan0043         1

# %%
for f, s in zip(list_folders, list_subjects):
    path_to_graph = f"{f}/{subpath}"

    # Checks of left graph exists
    graph_file = f"{path_to_graph}/L{s}.arg"
    if not os.path.isfile(graph_file):
        print(f"L{s}.arg does not exist")
        qc.loc[s, "qc"] = 0
        qc.loc[s, "comments"] = "Left graph does not exist"

    
    graph_file = f"{path_to_graph}/R{s}.arg"
    if not os.path.isfile(graph_file):
        print(f"R{s}.arg does not exist")
        qc.loc[s, "qc"] = 0
        qc.loc[s, "comments"] = "Right graph does not exist"
# Out:
# LScan0432.arg does not exist
# RScan0432.arg does not exist
# LScan0147.arg does not exist
# RScan0147.arg does not exist
# RScan0029.arg does not exist
# RScan0023.arg does not exist
# RScan0002.arg does not exist
# RScan0009.arg does not exist
# LScan0299.arg does not exist
# RScan0299.arg does not exist
# RScan0090.arg does not exist
# LScan0412.arg does not exist
# RScan0412.arg does not exist
# LScan0241.arg does not exist
# RScan0241.arg does not exist
# LScan0231.arg does not exist
# RScan0231.arg does not exist
# LScan0380.arg does not exist
# RScan0380.arg does not exist
# LScan0345.arg does not exist
# RScan0345.arg does not exist
# LScan0447.arg does not exist
# RScan0447.arg does not exist
# LScan0237.arg does not exist
# RScan0237.arg does not exist
# LScan0105.arg does not exist
# RScan0105.arg does not exist
# LScan0382.arg does not exist
# RScan0382.arg does not exist

# %%
qc["qc"].sum()
# Out:
# 515

# %%
qc.to_csv(qc_file, sep='\t')
