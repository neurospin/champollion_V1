# %%
import glob
import os
import pandas as pd

# %%
path = "/neurospin/psy_sbox/biobd/derivatives/morphologist-2021/subjects"
subpath = "t1mri/ses-V1_run*/default_analysis/folds/3.1"
qc_file = "/neurospin/dico/data/deep_folding/current/datasets/biobd/qc.tsv"

# %%
list_folders = glob.glob(f"{path}/*/")
list_folders = [x[:-1] for x in list_folders]
list_subjects = [os.path.basename(f) for f in list_folders]

# %%
list_subjects
# Out:
# ['sub-923549587076',
#  'sub-466772340401',
#  'sub-369571672043',
#  'sub-145383788250',
#  'sub-549119165992',
#  'sub-479899164419',
#  'sub-777052856016',
#  'sub-110751979791',
#  'sub-261904584888',
#  'sub-325766870880',
#  'sub-732671920589',
#  'sub-993717392414',
#  'sub-173777432097',
#  'sub-442941756322',
#  'sub-376603713737',
#  'sub-575223115122',
#  'sub-447090187365',
#  'sub-829824818068',
#  'sub-523118532235',
#  'sub-479066377124',
#  'sub-241354542406',
#  'sub-204323898388',
#  'sub-403707311299',
#  'sub-194127316880',
#  'sub-421467138108',
#  'sub-121036883624',
#  'sub-233144107334',
#  'sub-154818129871',
#  'sub-702726089756',
#  'sub-225749967686',
#  'sub-728425079651',
#  'sub-113957195253',
#  'sub-996276907812',
#  'sub-331968608917',
#  'sub-126709232689',
#  'sub-382010708582',
#  'sub-343778783903',
#  'sub-951889446973',
#  'sub-439773393121',
#  'sub-213889059273',
#  'sub-763232165844',
#  'sub-682108027037',
#  'sub-683563576363',
#  'sub-618769103165',
#  'sub-661867727563',
#  'sub-363034423137',
#  'sub-730043165263',
#  'sub-452149001833',
#  'sub-414227669594',
#  'sub-825543506725',
#  'sub-590553460422',
#  'sub-206152431141',
#  'sub-899284978549',
#  'sub-591336493755',
#  'sub-435432648506',
#  'sub-856191562451',
#  'sub-855964697616',
#  'sub-959405007019',
#  'sub-188740168590',
#  'sub-282171272621',
#  'sub-949905437676',
#  'sub-453966003039',
#  'sub-769124677386',
#  'sub-582268889106',
#  'sub-143031618176',
#  'sub-670341504232',
#  'sub-442471695060',
#  'sub-227839945563',
#  'sub-529025138862',
#  'sub-298882272395',
#  'sub-855586554330',
#  'sub-237148475248',
#  'sub-739657365501',
#  'sub-334441624556',
#  'sub-677653416912',
#  'sub-942465208526',
#  'sub-570507941850',
#  'sub-439442868103',
#  'sub-709786418659',
#  'sub-590094412054',
#  'sub-978588239977',
#  'sub-919591058440',
#  'sub-507433636958',
#  'sub-202443709905',
#  'sub-373574784181',
#  'sub-635553991621',
#  'sub-923893917916',
#  'sub-952129964806',
#  'sub-457863894017',
#  'sub-413665319829',
#  'sub-939686012648',
#  'sub-855367051224',
#  'sub-751888909966',
#  'sub-145872605038',
#  'sub-705483781994',
#  'sub-102932873213',
#  'sub-347560816159',
#  'sub-251811404778',
#  'sub-206749871806',
#  'sub-378547053638',
#  'sub-451315195781',
#  'sub-278547663674',
#  'sub-802936931863',
#  'sub-810337287302',
#  'sub-410597889455',
#  'sub-887793946950',
#  'sub-901090611147',
#  'sub-330333336399',
#  'sub-153138320244',
#  'sub-564252676034',
#  'sub-624164690061',
#  'sub-843078021753',
#  'sub-455130107626',
#  'sub-712043565340',
#  'sub-437062817303',
#  'sub-972062114583',
#  'sub-296757780566',
#  'sub-156634941156',
#  'sub-758584017627',
#  'sub-691289515254',
#  'sub-861224180436',
#  'sub-830920633970',
#  'sub-841846687290',
#  'sub-278329144951',
#  'sub-595035600054',
#  'sub-778539871421',
#  'sub-221958174122',
#  'sub-830703191681',
#  'sub-650246865932',
#  'sub-917498871692',
#  'sub-712684480652',
#  'sub-463331195324',
#  'sub-928745839675',
#  'sub-211602391801',
#  'sub-229394564655',
#  'sub-488164116014',
#  'sub-994959841722',
#  'sub-906705846207',
#  'sub-449912321641',
#  'sub-469301346170',
#  'sub-527662668865',
#  'sub-722188139700',
#  'sub-850481494240',
#  'sub-589916690768',
#  'sub-827728998779',
#  'sub-658110173571',
#  'sub-475920710176',
#  'sub-181933970166',
#  'sub-582533069091',
#  'sub-508257043790',
#  'sub-895830825596',
#  'sub-509385648395',
#  'sub-660781444655',
#  'sub-599186268436',
#  'sub-359208842776',
#  'sub-680641528856',
#  'sub-323536868591',
#  'sub-734153538547',
#  'sub-912346827215',
#  'sub-372933076631',
#  'sub-495004796124',
#  'sub-834550980828',
#  'sub-100288468310',
#  'sub-324019355864',
#  'sub-752613686697',
#  'sub-405367219784',
#  'sub-126669411121',
#  'sub-666485940699',
#  'sub-632225023139',
#  'sub-813311935665',
#  'sub-755449777673',
#  'sub-740649847210',
#  'sub-178195150640',
#  'sub-325887746955',
#  'sub-124271346554',
#  'sub-237316076994',
#  'sub-253011261619',
#  'sub-544435731463',
#  'sub-408265753190',
#  'sub-191095579190',
#  'sub-495212402431',
#  'sub-544676456181',
#  'sub-348226732895',
#  'sub-930023532220',
#  'sub-134725465305',
#  'sub-959377018191',
#  'sub-804023421989',
#  'sub-287402509259',
#  'sub-250155618045',
#  'sub-718193833728',
#  'sub-706415700286',
#  'sub-253262424165',
#  'sub-392821437472',
#  'sub-616267213209',
#  'sub-218533366742',
#  'sub-580085047587',
#  'sub-897067533534',
#  'sub-807115709508',
#  'sub-199018354222',
#  'sub-635960650161',
#  'sub-462298708468',
#  'sub-942823165027',
#  'sub-223440356295',
#  'sub-119506348539',
#  'sub-690598193642',
#  'sub-464576291986',
#  'sub-367683888469',
#  'sub-576508027991',
#  'sub-480065838264',
#  'sub-872008893173',
#  'sub-425469006841',
#  'sub-615860660725',
#  'sub-455549998730',
#  'sub-352784971704',
#  'sub-518156570954',
#  'sub-570221845965',
#  'sub-802708704329',
#  'sub-285083324930',
#  'sub-810076655652',
#  'sub-482056349302',
#  'sub-227708197968',
#  'sub-817969608255',
#  'sub-882405630657',
#  'sub-726278928908',
#  'sub-426760919448',
#  'sub-269057420772',
#  'sub-414583180075',
#  'sub-846294895967',
#  'sub-144701534144',
#  'sub-439655331004',
#  'sub-477513193877',
#  'sub-735956124024',
#  'sub-391617528618',
#  'sub-109900783414',
#  'sub-611954003219',
#  'sub-848873044557',
#  'sub-491759210630',
#  'sub-682087772916',
#  'sub-765006196843',
#  'sub-458755288203',
#  'sub-777896850456',
#  'sub-599573292918',
#  'sub-766608514183',
#  'sub-416668156920',
#  'sub-553762721329',
#  'sub-923209778784',
#  'sub-481971693331',
#  'sub-924472189859',
#  'sub-975557055860',
#  'sub-514497366357',
#  'sub-570454937098',
#  'sub-400222907331',
#  'sub-538396116696',
#  'sub-952960207821',
#  'sub-817480741205',
#  'sub-162551112814',
#  'sub-880599202406',
#  'sub-184173668405',
#  'sub-286261781409',
#  'sub-743593077377',
#  'sub-505100410419',
#  'sub-149945412502',
#  'sub-345759614961',
#  'sub-481872801783',
#  'sub-923455449477',
#  'sub-784580211255',
#  'sub-730079180663',
#  'sub-209618666165',
#  'sub-340276711464',
#  'sub-548959647165',
#  'sub-179056268515',
#  'sub-322978470862',
#  'sub-409767059076',
#  'sub-547180525888',
#  'sub-246775756495',
#  'sub-432241582767',
#  'sub-485873784728',
#  'sub-127567692450',
#  'sub-858203474980',
#  'sub-795340025349',
#  'sub-644310410865',
#  'sub-808278982439',
#  'sub-576279300760',
#  'sub-972652377496',
#  'sub-985909166517',
#  'sub-185256805740',
#  'sub-299371703772',
#  'sub-775604560486',
#  'sub-433698787035',
#  'sub-622023340713',
#  'sub-952648940995',
#  'sub-738395626773',
#  'sub-344463774916',
#  'sub-420570850494',
#  'sub-148210353882',
#  'sub-324774735768',
#  'sub-974896563650',
#  'sub-351949560556',
#  'sub-504524359373',
#  'sub-955705356959',
#  'sub-451353327809',
#  'sub-406249203634',
#  'sub-383643561172',
#  'sub-643898613679',
#  'sub-558753042196',
#  'sub-922171135270',
#  'sub-481005075781',
#  'sub-300730525760',
#  'sub-699592893697',
#  'sub-578531065627',
#  'sub-831798332932',
#  'sub-925558369887',
#  'sub-805869849575',
#  'sub-843416536876',
#  'sub-684118623501',
#  'sub-988991873444',
#  'sub-948933402631',
#  'sub-328878196078',
#  'sub-689494922803',
#  'sub-372133480204',
#  'sub-590950588493',
#  'sub-507444321409',
#  'sub-714476111882',
#  'sub-166609304411',
#  'sub-402194646299',
#  'sub-809878713473',
#  'sub-624148090290',
#  'sub-674188420698',
#  'sub-935452301877',
#  'sub-972438199175',
#  'sub-951966631566',
#  'sub-685406867664',
#  'sub-939887150837',
#  'sub-793423816336',
#  'sub-852707825452',
#  'sub-826275897146',
#  'sub-559639625739',
#  'sub-141788537429',
#  'sub-461903006973',
#  'sub-761741762748',
#  'sub-752889809037',
#  'sub-937746166707',
#  'sub-468730767332',
#  'sub-310751097264',
#  'sub-916500524994',
#  'sub-876651563587',
#  'sub-273205424595',
#  'sub-183533398749',
#  'sub-398354908787',
#  'sub-664703775284',
#  'sub-175092425987',
#  'sub-696336395278',
#  'sub-550518162819',
#  'sub-938038137548',
#  'sub-114871667196',
#  'sub-990233772190',
#  'sub-949061980459',
#  'sub-818286826472',
#  'sub-957431374956',
#  'sub-510905297072',
#  'sub-849355164084',
#  'sub-567372919094',
#  'sub-625619428917',
#  'sub-822297995588',
#  'sub-216493943683',
#  'sub-710705155105',
#  'sub-307848008058',
#  'sub-242249996997',
#  'sub-591770760785',
#  'sub-386794747088',
#  'sub-396494923948',
#  'sub-368733591754',
#  'sub-249112076808',
#  'sub-359019930579',
#  'sub-801013457069',
#  'sub-507066821948',
#  'sub-164278662908',
#  'sub-954573121439',
#  'sub-223861657419',
#  'sub-245760568448',
#  'sub-381794766234',
#  'sub-520722852416',
#  'sub-866203430929',
#  'sub-352160641135',
#  'sub-135010770986',
#  'sub-644267207618',
#  'sub-820970233947',
#  'sub-103812902836',
#  'sub-760516633093',
#  'sub-843356817212',
#  'sub-613965897134',
#  'sub-466826361687',
#  'sub-352572019743',
#  'sub-645604123256',
#  'sub-821944316944',
#  'sub-822630244555',
#  'sub-865363600768',
#  'sub-704106494037',
#  'sub-535395286159',
#  'sub-911350678973',
#  'sub-891042378027',
#  'sub-179724720846',
#  'sub-805792194204',
#  'sub-903538867463',
#  'sub-532651523246',
#  'sub-738066844975',
#  'sub-847055227734',
#  'sub-180817793396',
#  'sub-285646148302',
#  'sub-785887214341',
#  'sub-334345139854',
#  'sub-994228162538',
#  'sub-953321722063',
#  'sub-453974447342',
#  'sub-962818477651',
#  'sub-567429878652',
#  'sub-999231381382',
#  'sub-999412570656',
#  'sub-638061097525',
#  'sub-783506400036',
#  'sub-542241441476',
#  'sub-351423011086',
#  'sub-200599916127',
#  'sub-378417388043',
#  'sub-599176503316',
#  'sub-845235462826',
#  'sub-983376923200',
#  'sub-188862939450',
#  'sub-895940602378',
#  'sub-757332157366',
#  'sub-639944271186',
#  'sub-787801395091',
#  'sub-794975442127',
#  'sub-611553851411',
#  'sub-515436777528',
#  'sub-894437259718',
#  'sub-499348575564',
#  'sub-227714303861',
#  'sub-995805135593',
#  'sub-164366841467',
#  'sub-675972214008',
#  'sub-304652614964',
#  'sub-827969257900',
#  'sub-239163922318',
#  'sub-156652209094',
#  'sub-111086374013',
#  'sub-522585187972',
#  'sub-126000013626',
#  'sub-490997656163',
#  'sub-921111812116',
#  'sub-497540203420',
#  'sub-501127836295',
#  'sub-797727246006',
#  'sub-612088060713',
#  'sub-287553238256',
#  'sub-122453692470',
#  'sub-222750414545',
#  'sub-619398697708',
#  'sub-364844427797',
#  'sub-661005540862',
#  'sub-169891069005',
#  'sub-185768600088',
#  'sub-124516203708',
#  'sub-340535641220',
#  'sub-450398240668',
#  'sub-718400641243',
#  'sub-689769735048',
#  'sub-598789027891',
#  'sub-177674489804',
#  'sub-439241375836',
#  'sub-768934649232',
#  'sub-129027390440',
#  'sub-495569627858',
#  'sub-768464354380',
#  'sub-922904438202',
#  'sub-810155504688',
#  'sub-752957422792',
#  'sub-239621838470',
#  'sub-435350291185',
#  'sub-165508945570',
#  'sub-124384751354',
#  'sub-472821532975',
#  'sub-264680277578',
#  'sub-855188231629',
#  'sub-188017867646',
#  'sub-763329468990',
#  'sub-460212973711',
#  'sub-583686146345',
#  'sub-581382763026',
#  'sub-420662820652',
#  'sub-647345883204',
#  'sub-365598649574',
#  'sub-553171825502',
#  'sub-909153253851',
#  'sub-478171713584',
#  'sub-591454556257',
#  'sub-132316401995',
#  'sub-683853218873',
#  'sub-769251696041',
#  'sub-971810649221',
#  'sub-211723697268',
#  'sub-230919874568',
#  'sub-283573877673',
#  'sub-592771308151',
#  'sub-276766278948',
#  'sub-947406335463',
#  'sub-326364953161',
#  'sub-941200471159',
#  'sub-507978780047',
#  'sub-125620032071',
#  'sub-482319289712',
#  'sub-522193615515',
#  'sub-193780787949',
#  'sub-587465861517',
#  'sub-850820275021',
#  'sub-844458387413',
#  'sub-283304676935',
#  'sub-200348608780',
#  'sub-386747285357',
#  'sub-955603267801',
#  'sub-467195136336',
#  'sub-210869874537',
#  'sub-322297931142',
#  'sub-274833697076',
#  'sub-256215855744',
#  'sub-915214804714',
#  'sub-284381397199',
#  'sub-497177329974',
#  'sub-460127580829',
#  'sub-768700035561',
#  'sub-939467895180',
#  'sub-447253236543',
#  'sub-216625071558',
#  'sub-525849992604',
#  'sub-394450054577',
#  'sub-633097661779',
#  'sub-651599076115',
#  'sub-350471680471',
#  'sub-106155619059',
#  'sub-138432854246',
#  'sub-556485353871',
#  'sub-602923639385',
#  'sub-988735955571',
#  'sub-264061571976',
#  'sub-950320507722',
#  'sub-643439998353',
#  'sub-999814964521',
#  'sub-389000287954',
#  'sub-109788596772',
#  'sub-532827940892',
#  'sub-200798213555',
#  'sub-308219362067',
#  'sub-567265336942',
#  'sub-924005209409',
#  'sub-167697591926',
#  'sub-978881310059',
#  'sub-469521415780',
#  'sub-916020870576',
#  'sub-942199679499',
#  'sub-954456566193',
#  'sub-360937080065',
#  'sub-330237239703',
#  'sub-398643941493',
#  'sub-329490042033',
#  'sub-281097869629',
#  'sub-997965250223',
#  'sub-114032795605',
#  'sub-186334059458',
#  'sub-281473986685',
#  'sub-639243967259',
#  'sub-670672783572',
#  'sub-431709856051',
#  'sub-559101860373',
#  'sub-172224188645',
#  'sub-371807228763',
#  'sub-260494631072',
#  'sub-281348708375',
#  'sub-715069339995',
#  'sub-154558208022',
#  'sub-870810930661',
#  'sub-399785599359',
#  'sub-300618298242',
#  'sub-860684893951',
#  'sub-469630853715',
#  'sub-243261544658',
#  'sub-100559026781',
#  'sub-837977466460',
#  'sub-669930775268',
#  'sub-556693625600',
#  'sub-918563591727',
#  'sub-706928832977',
#  'sub-237735334214',
#  'sub-151061697311',
#  'sub-970408525689',
#  'sub-326901880025',
#  'sub-894331948476',
#  'sub-369045637569',
#  'sub-598904549887',
#  'sub-154678540825',
#  'sub-641050341604',
#  'sub-562076160135',
#  'sub-799853514370',
#  'sub-735087172205',
#  'sub-316307760355',
#  'sub-874628637573',
#  'sub-477273291002',
#  'sub-434225074023',
#  'sub-717895898972',
#  'sub-307531837632',
#  'sub-123151337985',
#  'sub-445153175611',
#  'sub-851421204403',
#  'sub-707978728579',
#  'sub-733016656872',
#  'sub-362173619569',
#  'sub-644998096568',
#  'sub-192898140784',
#  'sub-529611432944',
#  'sub-702813177921',
#  'sub-435357232226',
#  'sub-981518352800',
#  'sub-358764900547',
#  'sub-168220503592',
#  'sub-891755849910',
#  'sub-599834722783',
#  'sub-701091303481',
#  'sub-558923763072',
#  'sub-711376631881',
#  'sub-320893106670',
#  'sub-817449215945',
#  'sub-940618084040',
#  'sub-549053952410',
#  'sub-461603906716',
#  'sub-855039352894',
#  'sub-453547059196',
#  'sub-948953888972',
#  'sub-821637832591',
#  'sub-672309999261',
#  'sub-761188702125',
#  'sub-328863593195',
#  'sub-374084688547',
#  'sub-888925968464',
#  'sub-483417553989',
#  'sub-539989861056',
#  'sub-617030174208',
#  'sub-211781592371',
#  'sub-373702396205',
#  'sub-112909606193',
#  'sub-172652831371',
#  'sub-745442823450',
#  'sub-548071925005',
#  'sub-436471089093',
#  'sub-496538911366',
#  'sub-465677076962',
#  'sub-383341727580',
#  'sub-995754625635',
#  'sub-344274489501',
#  'sub-706960799502',
#  'sub-420350438302',
#  'sub-511069557094',
#  'sub-958282404457',
#  'sub-739487676161',
#  'sub-742587813571',
#  'sub-477058218172',
#  'sub-988112511698',
#  'sub-888585476436',
#  'sub-238498124586',
#  'sub-348398062995',
#  'sub-704149041012',
#  'sub-268302807285',
#  'sub-665156683137',
#  'sub-251249398237',
#  'sub-666062890286',
#  'sub-559374704082',
#  'sub-647349621950',
#  'sub-859970990634',
#  'sub-136404206960',
#  'sub-331515837171',
#  'sub-799399693953',
#  'sub-442595775212',
#  'sub-275164281194',
#  'sub-548517158497',
#  'sub-147910853563',
#  'sub-487920321479',
#  'sub-711082429419',
#  'sub-355275456911',
#  'sub-804030304294',
#  'sub-307816755268',
#  'sub-341818747291',
#  'sub-887084973018',
#  'sub-648731909395',
#  'sub-558970209757',
#  'sub-419555247213',
#  'sub-524584503381',
#  'sub-961543931822',
#  'sub-692407274767',
#  'sub-430848744909',
#  'sub-988884617906',
#  'sub-238159074763',
#  'sub-408647420002',
#  'sub-398211043674',
#  'sub-356709490512',
#  'sub-768993708395',
#  'sub-483524013022',
#  'sub-580796945679',
#  'sub-911396422659',
#  'sub-691816535351',
#  'sub-298114911354',
#  'sub-341879365063',
#  'sub-955007208813',
#  'sub-771374424505',
#  'sub-851277363092',
#  'sub-494836664882',
#  'sub-491217343760',
#  'sub-621843091603',
#  'sub-176696214170',
#  'sub-715302051346',
#  'sub-444310441331',
#  'sub-185827977002',
#  'sub-879486445103',
#  'sub-794288333904',
#  'sub-979986513759',
#  'sub-861113606145',
#  'sub-995197582752',
#  'sub-970384589032',
#  'sub-265923823412',
#  'sub-398963991211',
#  'sub-966111759549',
#  'sub-929181306575',
#  'sub-440570817168',
#  'sub-832999096194',
#  'sub-883044608359',
#  'sub-726037078085',
#  'sub-617114481020',
#  'sub-209847849033',
#  'sub-922855811497',
#  'sub-688554667046',
#  'sub-824226059089',
#  'sub-358497785277',
#  'sub-520396982711',
#  'sub-687445065249',
#  'sub-681245347670',
#  'sub-208175577578',
#  'sub-361618524679',
#  'sub-789893791916',
#  'sub-750784860190']

# %%
qc = pd.DataFrame(list_subjects, columns=["participant_id"]).set_index("participant_id")

# %%
qc["qc"] = 1
qc["comments"] =  ""

# %%
qc.head()
# Out:
#                   qc comments
# participant_id
# sub-923549587076   1
# sub-466772340401   1
# sub-369571672043   1
# sub-145383788250   1
# sub-549119165992   1

# %%
for f, s in zip(list_folders, list_subjects):
    path_to_graph = f"{f}/{subpath}"

    # Checks of left graph exists
    graph_files = glob.glob(f"{path_to_graph}/L{s}.arg")
    if len(graph_files) == 0:
        print(f"L{s}.arg does not exist")
        qc.loc[s, "qc"] = 0
        qc.loc[s, "comments"] = "Left graph does not exist"

    
    graph_files = glob.glob(f"{path_to_graph}/R{s}.arg")
    if len(graph_files) == 0:
        print(f"R{s}.arg does not exist")
        qc.loc[s, "qc"] = 0
        qc.loc[s, "comments"] = "Right graph does not exist"
# Out:
# Lsub-400222907331.arg does not exist
# Rsub-400222907331.arg does not exist
# Lsub-352160641135.arg does not exist
# Rsub-352160641135.arg does not exist

# %%
qc["qc"].sum()
# Out:
# 744

# %%
qc.to_csv(qc_file, sep='\t')
