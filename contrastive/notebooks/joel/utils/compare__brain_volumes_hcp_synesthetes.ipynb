# %%
import pandas as pd
import seaborn as sns
import glob
import matplotlib.pyplot as plt

# %%
hcp_volumes_file = "/neurospin/dico/data/bv_databases/human/automatically_labeled/hcp/morphometry/brain_volumes.csv"
synesthetes_file = "/neurospin/dico/data/deep_folding/current/datasets/synesthetes/participants.csv"

# %%
hcp = pd.read_csv(hcp_volumes_file, sep=";", index_col=0)
hcp = hcp[["both.brain_volume"]]

# %%
len(hcp)
# Out:
# 1114

# %%
sns.ecdfplot(data=hcp, x="both.brain_volume")
# Out:
# <Axes: xlabel='both.brain_volume', ylabel='Proportion'>

# %%
syn = pd.read_csv(synesthetes_file, index_col=0)
syn.head()
# Out:
#                                        brain_volume  isSynesthete   NOM  \
# participant_id
# mv_SYNESTHEX_Sujet09_Session1_S2_T1w    1261229.989             0  PECL
# mv_SYNESTHEX_Sujet10_Session2_S14_T1w   1229268.222             0  VIMA
# mv_SYNESTHEX_Sujet11_Session2_S14_T1w   1026066.763             1  SICA
# mv_SYNESTHEX_Sujet12_Session2_S12_T1w   1164323.992             1  HACL
# mv_SYNESTHEX_Sujet13_Session2_S13_T1w   1127962.029             1  HELI
#
#                                              DDN   IRM name   Date IRM  \
# participant_id
# mv_SYNESTHEX_Sujet09_Session1_S2_T1w   12/8/1998  Control02        NaN
# mv_SYNESTHEX_Sujet10_Session2_S14_T1w  18/3/1985  Control27  28/2/2023
# mv_SYNESTHEX_Sujet11_Session2_S14_T1w  17/8/1985    Sujet23   3/3/2023
# mv_SYNESTHEX_Sujet12_Session2_S12_T1w  10/6/1972    Sujet24  29/3/2023
# mv_SYNESTHEX_Sujet13_Session2_S13_T1w  2/11/1966    Sujet25  20/5/2023
#
#                                              Age  Sex  Lateralite  \
# ...

# %%
sns.ecdfplot(data=hcp, x="both.brain_volume", label="hcp")
sns.ecdfplot(data=syn, x="brain_volume", label="synesthetes")
plt.legend()

# %%
sns.histplot(data=syn, x="brain_volume", hue="isSynesthete")
# Out:
# <Axes: xlabel='brain_volume', ylabel='Count'>

# %%
hcp.hist(bins=50)
# Out:
# array([[<Axes: title={'center': 'both.brain_volume'}>]], dtype=object)

# %%
syn.hist(bins=50)
# Out:
# array([[<Axes: title={'center': 'brain_volume'}>,
#         <Axes: title={'center': 'isSynesthete'}>,
#         <Axes: title={'center': 'Age'}>],
#        [<Axes: title={'center': 'Sex'}>,
#         <Axes: title={'center': 'Lateralite'}>,
#         <Axes: title={'center': 'Unnamed: 9'}>],
#        [<Axes: title={'center': '0=femme – 1=homme'}>,
#         <Axes: title={'center': '0=droitier – 1=gaucher'}>, <Axes: >]],
#       dtype=object)

# %%
pd.read_csv?
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols: 'UsecolsArgType' = None,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters: 'Mapping[Hashable, Callable] | None' = None,
#     true_values: 'list | None' = None,
#     false_values: 'list | None' = None,
#     skipinitialspace: 'bool' = False,
#     skiprows: 'list[int] | int | Callable[[Hashable], bool] | None' = None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
#     na_values: 'Hashable | Iterable[Hashable] | Mapping[Hashable, Iterable[Hashable]] | None' = None,
# ...

# %%
hcp.hist(cumulative=True, density=True, histtype='step')
# Out:
# array([[<Axes: title={'center': 'both.brain_volume'}>]], dtype=object)

# %%
hcp.plot.bar()
# Out:
# <Axes: xlabel='subject'>

# %%
len(hcp)
# Out:
# 1114
