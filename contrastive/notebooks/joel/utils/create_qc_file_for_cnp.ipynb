# %%
import glob
import os
import pandas as pd

# %%
path = "/neurospin/psy_sbox/cnp/derivatives/morphologist-2021/subjects"
subpath = "t1mri/ses-1/default_analysis/folds/3.1"
qc_file = "/neurospin/dico/data/deep_folding/current/datasets/cnp/qc.tsv"

# %%
list_folders = glob.glob(f"{path}/*/")
list_folders = [x[:-1] for x in list_folders]
list_subjects = [os.path.basename(f) for f in list_folders]

# %%
list_subjects
# Out:
# ['sub-60043',
#  'sub-70007',
#  'sub-10235',
#  'sub-11142',
#  'sub-10719',
#  'sub-10692',
#  'sub-50027',
#  'sub-11067',
#  'sub-70034',
#  'sub-50051',
#  'sub-10855',
#  'sub-10680',
#  'sub-11128',
#  'sub-50025',
#  'sub-50014',
#  'sub-50067',
#  'sub-10455',
#  'sub-70070',
#  'sub-10429',
#  'sub-70080',
#  'sub-60066',
#  'sub-10788',
#  'sub-60077',
#  'sub-10893',
#  'sub-50083',
#  'sub-70061',
#  'sub-10631',
#  'sub-10527',
#  'sub-70083',
#  'sub-60042',
#  'sub-10987',
#  'sub-60010',
#  'sub-10963',
#  'sub-70029',
#  'sub-10746',
#  'sub-10228',
#  'sub-60073',
#  'sub-11149',
#  'sub-70033',
#  'sub-60072',
#  'sub-11062',
#  'sub-60036',
#  'sub-70081',
#  'sub-10940',
#  'sub-10316',
#  'sub-50035',
#  'sub-50056',
#  'sub-50015',
#  'sub-70068',
#  'sub-10376',
#  'sub-10877',
#  'sub-10707',
#  'sub-10460',
#  'sub-11066',
#  'sub-60005',
#  'sub-60079',
#  'sub-60076',
#  'sub-60062',
#  'sub-11077',
#  'sub-50055',
#  'sub-10290',
#  'sub-10506',
#  'sub-10570',
#  'sub-10193',
#  'sub-10345',
#  'sub-70075',
#  'sub-10708',
#  'sub-70015',
#  'sub-10478',
#  'sub-10565',
#  'sub-60065',
#  'sub-10668',
#  'sub-10686',
#  'sub-70073',
#  'sub-10206',
#  'sub-11059',
#  'sub-70051',
#  'sub-11106',
#  'sub-10217',
#  'sub-50007',
#  'sub-70022',
#  'sub-50060',
#  'sub-10934',
#  'sub-11112',
#  'sub-10968',
#  'sub-60022',
#  'sub-50047',
#  'sub-10517',
#  'sub-10638',
#  'sub-70017',
#  'sub-10325',
#  'sub-10882',
#  'sub-60020',
#  'sub-10356',
#  'sub-10365',
#  'sub-50080',
#  'sub-70072',
#  'sub-60087',
#  'sub-11068',
#  'sub-10912',
#  'sub-50064',
#  'sub-60060',
#  'sub-10678',
#  'sub-50081',
#  'sub-10696',
#  'sub-50085',
#  'sub-10225',
#  'sub-11097',
#  'sub-10388',
#  'sub-60078',
#  'sub-50022',
#  'sub-10271',
#  'sub-60046',
#  'sub-10958',
#  'sub-11050',
#  'sub-11105',
#  'sub-10249',
#  'sub-50061',
#  'sub-60030',
#  'sub-70079',
#  'sub-60008',
#  'sub-10171',
#  'sub-60080',
#  'sub-10377',
#  'sub-10557',
#  'sub-10274',
#  'sub-50033',
#  'sub-10948',
#  'sub-11108',
#  'sub-50034',
#  'sub-10762',
#  'sub-60084',
#  'sub-11104',
#  'sub-10524',
#  'sub-10871',
#  'sub-60016',
#  'sub-60037',
#  'sub-10340',
#  'sub-60011',
#  'sub-60017',
#  'sub-70040',
#  'sub-70055',
#  'sub-70057',
#  'sub-10844',
#  'sub-50049',
#  'sub-60033',
#  'sub-10724',
#  'sub-10159',
#  'sub-50069',
#  'sub-10629',
#  'sub-50048',
#  'sub-10329',
#  'sub-50021',
#  'sub-10624',
#  'sub-50008',
#  'sub-11131',
#  'sub-10998',
#  'sub-60012',
#  'sub-70076',
#  'sub-70026',
#  'sub-10977',
#  'sub-60068',
#  'sub-70065',
#  'sub-50077',
#  'sub-10361',
#  'sub-11156',
#  'sub-10975',
#  'sub-50076',
#  'sub-10227',
#  'sub-50023',
#  'sub-50004',
#  'sub-50073',
#  'sub-10471',
#  'sub-10785',
#  'sub-70002',
#  'sub-50029',
#  'sub-60074',
#  'sub-10492',
#  'sub-50053',
#  'sub-10674',
#  'sub-11019',
#  'sub-11143',
#  'sub-11098',
#  'sub-60049',
#  'sub-60045',
#  'sub-70052',
#  'sub-10189',
#  'sub-70020',
#  'sub-70004',
#  'sub-10273',
#  'sub-10304',
#  'sub-11061',
#  'sub-10280',
#  'sub-10292',
#  'sub-60089',
#  'sub-10438',
#  'sub-50058',
#  'sub-11030',
#  'sub-50052',
#  'sub-60021',
#  'sub-10523',
#  'sub-60048',
#  'sub-10779',
#  'sub-70048',
#  'sub-60051',
#  'sub-10487',
#  'sub-60001',
#  'sub-10339',
#  'sub-11044',
#  'sub-10530',
#  'sub-11088',
#  'sub-50020',
#  'sub-60052',
#  'sub-60006',
#  'sub-10321',
#  'sub-50059',
#  'sub-50005',
#  'sub-70086',
#  'sub-10347',
#  'sub-10949',
#  'sub-11090',
#  'sub-60056',
#  'sub-11122',
#  'sub-70077',
#  'sub-50036',
#  'sub-50054',
#  'sub-50032',
#  'sub-10269',
#  'sub-70046',
#  'sub-70074',
#  'sub-70049',
#  'sub-50016',
#  'sub-50010',
#  'sub-60055',
#  'sub-10525',
#  'sub-50013',
#  'sub-50043',
#  'sub-60014',
#  'sub-70021',
#  'sub-10448',
#  'sub-50038',
#  'sub-70037',
#  'sub-11052',
#  'sub-10672',
#  'sub-70010',
#  'sub-10697',
#  'sub-60015',
#  'sub-70001',
#  'sub-50075',
#  'sub-10440',
#  'sub-10704',
#  'sub-70058',
#  'sub-70060',
#  'sub-50050',
#  'sub-60057',
#  'sub-60053',
#  'sub-50006',
#  'sub-10891',
#  'sub-10575',
#  'sub-50066',
#  'sub-70069',
#  'sub-11082',
#  'sub-60038',
#  'sub-60028',
#  'sub-60070']

# %%
qc = pd.DataFrame(list_subjects, columns=["participant_id"]).set_index("participant_id")

# %%
qc["qc"] = 1
qc["comments"] =  ""

# %%
qc.head()
# Out:
#                 qc comments
# participant_id
# sub-60043        1
# sub-70007        1
# sub-10235        1
# sub-11142        1
# sub-10719        1

# %%
for f, s in zip(list_folders, list_subjects):
    path_to_graph = f"{f}/{subpath}"

    # Checks of left graph exists
    graph_file = f"{path_to_graph}/L{s}.arg"
    if not os.path.isfile(graph_file):
        print(f"L{s}.arg does not exist")
        qc.loc[s, "qc"] = 0
        qc.loc[s, "comments"] = "Left graph does not exist"

    
    graph_file = f"{path_to_graph}/R{s}.arg"
    if not os.path.isfile(graph_file):
        print(f"R{s}.arg does not exist")
        qc.loc[s, "qc"] = 0
        qc.loc[s, "comments"] = "Right graph does not exist"
# Out:
# Lsub-10377.arg does not exist
# Rsub-10377.arg does not exist

# %%
qc["qc"].sum()
# Out:
# 264

# %%
qc.to_csv(qc_file, sep='\t')
